# %%
# Git this output from main.py
# import os
# import cv2
# import natsort
# from LabStretching import lab_stretching
# from RGBStretching import rgb_stretching
# def process_images(input_folder, output_folder, num_images=100):
#     files = os.listdir(input_folder)
#     files = natsort.natsorted(files)
#     for file in files[:num_images]:
#         input_path = os.path.join(input_folder, file)
#         if os.path.isfile(input_path):
#             img = cv2.imread(input_path)
#             img = rgb_stretching(img)
#             img = lab_stretching(img)
#             output_path = os.path.join(output_folder, file)
#             cv2.imwrite(output_path, img)
# if __name__ == "__main__":
#     input_folder = "./Dataset/raw-890"
#     output_folder = "./OutputImages"
#     if not os.path.exists(output_folder):
#         os.makedirs(output_folder)
#     process_images(
#         input_folder, output_folder, num_images=890
#     )  # Process for num_images

# %% [markdown]
# PSNR
#
# - more the better

# %%
import os
import cv2
from sewar import full_ref


# Method 1: using sewar library
def main(processed_folder, ground_reference):
    processed_images = os.listdir(processed_folder)
    total_psnr = 0
    num_images = 0
    for processed_image in processed_images:
        processed_path = os.path.join(processed_folder, processed_image)
        reference_path = os.path.join(ground_reference, processed_image)
        print(processed_path)
        print(reference_path)
        processed_img = cv2.imread(processed_path)
        reference_img = cv2.imread(reference_path)
        psnr = full_ref.psnr(reference_img, processed_img, MAX=None)
        total_psnr += psnr
        num_images += 1
        print(f"PSNR for {processed_image}: {psnr:.2f}")

    overall_psnr = total_psnr / num_images
    print(f"Overall PSNR: {overall_psnr:.2f}")


if __name__ == "__main__":
    # processed_folder = "./OutputImages"
    processed_folder = "./Dataset/raw-890"
    ground_reference = "./Dataset/reference-890"
    main(processed_folder, ground_reference)
# Out:
# ./results\100_img_.png
# ./Dataset/reference-890\100_img_.png
# PSNR for 100_img_.png: 15.78
# ./results\10139.png
# ./Dataset/reference-890\10139.png
# PSNR for 10139.png: 23.38
# ./results\10151.png
# ./Dataset/reference-890\10151.png
# PSNR for 10151.png: 25.08
# ./results\101_img_.png
# ./Dataset/reference-890\101_img_.png
# PSNR for 101_img_.png: 19.93
# ./results\102_img_.png
# ./Dataset/reference-890\102_img_.png
# PSNR for 102_img_.png: 15.00
# ./results\104_img_.png
# ./Dataset/reference-890\104_img_.png
# PSNR for 104_img_.png: 18.56
# ./results\105_img_.png
# ./Dataset/reference-890\105_img_.png
# PSNR for 105_img_.png: 15.86
# ./results\106_img_.png
# ./Dataset/reference-890\106_img_.png
# PSNR for 106_img_.png: 29.99
# ./results\107_img_.png
# ./Dataset/reference-890\107_img_.png
# PSNR for 107_img_.png: 17.02
# ./results\108_img_.png
# ./Dataset/reference-890\108_img_.png
# PSNR for 108_img_.png: 31.22
# ./results\10909.png
# ./Dataset/reference-890\10909.png
# PSNR for 10909.png: 20.78
# ./results\10945.png
# ./Dataset/reference-890\10945.png
# PSNR for 10945.png: 17.51
# ./results\109_img_.png
# ./Dataset/reference-890\109_img_.png
# PSNR for 109_img_.png: 13.01
# ./results\10_img_.png
# ./Dataset/reference-890\10_img_.png
# PSNR for 10_img_.png: 11.07
# ./results\11052.png
# ./Dataset/reference-890\11052.png
# PSNR for 11052.png: 20.46
# ./results\11064.png
# ./Dataset/reference-890\11064.png
# PSNR for 11064.png: 21.71
# ./results\111_img_.png
# ./Dataset/reference-890\111_img_.png
# PSNR for 111_img_.png: 18.46
# ./results\112_img_.png
# ./Dataset/reference-890\112_img_.png
# PSNR for 112_img_.png: 19.30
# ./results\11374.png
# ./Dataset/reference-890\11374.png
# PSNR for 11374.png: 20.39
# ./results\11398.png
# ./Dataset/reference-890\11398.png
# PSNR for 11398.png: 22.06
# ./results\113_img_.png
# ./Dataset/reference-890\113_img_.png
# PSNR for 113_img_.png: 17.27
# ./results\114_img_.png
# ./Dataset/reference-890\114_img_.png
# PSNR for 114_img_.png: 12.90
# ./results\115_img_.png
# ./Dataset/reference-890\115_img_.png
# PSNR for 115_img_.png: 20.32
# ./results\116_img_.png
# ./Dataset/reference-890\116_img_.png
# PSNR for 116_img_.png: 15.89
# ./results\117_img_.png
# ./Dataset/reference-890\117_img_.png
# PSNR for 117_img_.png: 20.58
# ./results\118_img_.png
# ./Dataset/reference-890\118_img_.png
# PSNR for 118_img_.png: 24.30
# ./results\11_img_.png
# ./Dataset/reference-890\11_img_.png
# PSNR for 11_img_.png: 25.24
# ./results\120_img_.png
# ./Dataset/reference-890\120_img_.png
# PSNR for 120_img_.png: 18.97
# ./results\121_img_.png
# ./Dataset/reference-890\121_img_.png
# PSNR for 121_img_.png: 21.47
# ./results\1225.png
# ./Dataset/reference-890\1225.png
# PSNR for 1225.png: 19.43
# ./results\12290.png
# ./Dataset/reference-890\12290.png
# PSNR for 12290.png: 9.47
# ./results\12299.png
# ./Dataset/reference-890\12299.png
# PSNR for 12299.png: 12.05
# ./results\122_img_.png
# ./Dataset/reference-890\122_img_.png
# PSNR for 122_img_.png: 21.93
# ./results\12324.png
# ./Dataset/reference-890\12324.png
# PSNR for 12324.png: 10.74
# ./results\12336.png
# ./Dataset/reference-890\12336.png
# PSNR for 12336.png: 21.53
# ./results\12348.png
# ./Dataset/reference-890\12348.png
# PSNR for 12348.png: 11.29
# ./results\123_img_.png
# ./Dataset/reference-890\123_img_.png
# PSNR for 123_img_.png: 22.15
# ./results\12422.png
# ./Dataset/reference-890\12422.png
# PSNR for 12422.png: 21.59
# ./results\12433.png
# ./Dataset/reference-890\12433.png
# PSNR for 12433.png: 16.51
# ./results\12445.png
# ./Dataset/reference-890\12445.png
# PSNR for 12445.png: 16.62
# ./results\124_img_.png
# ./Dataset/reference-890\124_img_.png
# PSNR for 124_img_.png: 25.62
# ./results\125_img_.png
# ./Dataset/reference-890\125_img_.png
# PSNR for 125_img_.png: 23.14
# ./results\12900.png
# ./Dataset/reference-890\12900.png
# PSNR for 12900.png: 16.87
# ./results\129_img_.png
# ./Dataset/reference-890\129_img_.png
# PSNR for 129_img_.png: 11.21
# ./results\130_img_.png
# ./Dataset/reference-890\130_img_.png
# PSNR for 130_img_.png: 20.99
# ./results\131_img_.png
# ./Dataset/reference-890\131_img_.png
# PSNR for 131_img_.png: 19.07
# ./results\133_img_.png
# ./Dataset/reference-890\133_img_.png
# PSNR for 133_img_.png: 19.86
# ./results\135_img_.png
# ./Dataset/reference-890\135_img_.png
# PSNR for 135_img_.png: 21.89
# ./results\136_img_.png
# ./Dataset/reference-890\136_img_.png
# PSNR for 136_img_.png: 23.82
# ./results\137_img_.png
# ./Dataset/reference-890\137_img_.png
# PSNR for 137_img_.png: 20.18
# ./results\138_img_.png
# ./Dataset/reference-890\138_img_.png
# PSNR for 138_img_.png: 21.69
# ./results\139_img_.png
# ./Dataset/reference-890\139_img_.png
# PSNR for 139_img_.png: 9.43
# ./results\13_img_.png
# ./Dataset/reference-890\13_img_.png
# PSNR for 13_img_.png: 21.71
# ./results\1407.png
# ./Dataset/reference-890\1407.png
# PSNR for 1407.png: 22.58
# ./results\140_img_.png
# ./Dataset/reference-890\140_img_.png
# PSNR for 140_img_.png: 17.36
# ./results\141_img_.png
# ./Dataset/reference-890\141_img_.png
# PSNR for 141_img_.png: 16.66
# ./results\142_img_.png
# ./Dataset/reference-890\142_img_.png
# PSNR for 142_img_.png: 9.52
# ./results\143_img_.png
# ./Dataset/reference-890\143_img_.png
# PSNR for 143_img_.png: 14.48
# ./results\144_img_.png
# ./Dataset/reference-890\144_img_.png
# PSNR for 144_img_.png: 19.53
# ./results\145_img_.png
# ./Dataset/reference-890\145_img_.png
# PSNR for 145_img_.png: 19.95
# ./results\146_img_.png
# ./Dataset/reference-890\146_img_.png
# PSNR for 146_img_.png: 13.56
# ./results\148_img_.png
# ./Dataset/reference-890\148_img_.png
# PSNR for 148_img_.png: 18.68
# ./results\1491.png
# ./Dataset/reference-890\1491.png
# PSNR for 1491.png: 16.87
# ./results\149_img_.png
# ./Dataset/reference-890\149_img_.png
# PSNR for 149_img_.png: 17.25
# ./results\14_img_.png
# ./Dataset/reference-890\14_img_.png
# PSNR for 14_img_.png: 18.09
# ./results\15001.png
# ./Dataset/reference-890\15001.png
# PSNR for 15001.png: 18.61
# ./results\15003.png
# ./Dataset/reference-890\15003.png
# PSNR for 15003.png: 16.83
# ./results\15045.png
# ./Dataset/reference-890\15045.png
# PSNR for 15045.png: 20.55
# ./results\15094.png
# ./Dataset/reference-890\15094.png
# PSNR for 15094.png: 20.44
# ./results\150_img_.png
# ./Dataset/reference-890\150_img_.png
# PSNR for 150_img_.png: 24.00
# ./results\15113.png
# ./Dataset/reference-890\15113.png
# PSNR for 15113.png: 15.99
# ./results\15136.png
# ./Dataset/reference-890\15136.png
# PSNR for 15136.png: 28.01
# ./results\151_img_.png
# ./Dataset/reference-890\151_img_.png
# PSNR for 151_img_.png: 22.39
# ./results\152_img_.png
# ./Dataset/reference-890\152_img_.png
# PSNR for 152_img_.png: 20.65
# ./results\1539.png
# ./Dataset/reference-890\1539.png
# PSNR for 1539.png: 19.70
# ./results\153_img_.png
# ./Dataset/reference-890\153_img_.png
# PSNR for 153_img_.png: 20.21
# ./results\15418.png
# ./Dataset/reference-890\15418.png
# PSNR for 15418.png: 18.90
# ./results\15426.png
# ./Dataset/reference-890\15426.png
# PSNR for 15426.png: 19.38
# ./results\154_img_.png
# ./Dataset/reference-890\154_img_.png
# PSNR for 154_img_.png: 19.59
# ./results\15544.png
# ./Dataset/reference-890\15544.png
# PSNR for 15544.png: 16.82
# ./results\155_img_.png
# ./Dataset/reference-890\155_img_.png
# PSNR for 155_img_.png: 24.43
# ./results\156_img_.png
# ./Dataset/reference-890\156_img_.png
# PSNR for 156_img_.png: 21.22
# ./results\15704.png
# ./Dataset/reference-890\15704.png
# PSNR for 15704.png: 14.69
# ./results\1573.png
# ./Dataset/reference-890\1573.png
# PSNR for 1573.png: 16.71
# ./results\157_img_.png
# ./Dataset/reference-890\157_img_.png
# PSNR for 157_img_.png: 28.59
# ./results\158_img_.png
# ./Dataset/reference-890\158_img_.png
# PSNR for 158_img_.png: 20.84
# ./results\159_img_.png
# ./Dataset/reference-890\159_img_.png
# PSNR for 159_img_.png: 17.69
# ./results\15_img_.png
# ./Dataset/reference-890\15_img_.png
# PSNR for 15_img_.png: 19.33
# ./results\160_img_.png
# ./Dataset/reference-890\160_img_.png
# PSNR for 160_img_.png: 17.15
# ./results\161_img_.png
# ./Dataset/reference-890\161_img_.png
# PSNR for 161_img_.png: 23.89
# ./results\162_img_.png
# ./Dataset/reference-890\162_img_.png
# PSNR for 162_img_.png: 19.98
# ./results\163_img_.png
# ./Dataset/reference-890\163_img_.png
# PSNR for 163_img_.png: 25.41
# ./results\164_img_.png
# ./Dataset/reference-890\164_img_.png
# PSNR for 164_img_.png: 21.43
# ./results\165_img_.png
# ./Dataset/reference-890\165_img_.png
# PSNR for 165_img_.png: 19.52
# ./results\1660.png
# ./Dataset/reference-890\1660.png
# PSNR for 1660.png: 16.61
# ./results\166_img_.png
# ./Dataset/reference-890\166_img_.png
# PSNR for 166_img_.png: 15.69
# ./results\168_img_.png
# ./Dataset/reference-890\168_img_.png
# PSNR for 168_img_.png: 11.99
# ./results\169_img_.png
# ./Dataset/reference-890\169_img_.png
# PSNR for 169_img_.png: 16.59
# ./results\16_img_.png
# ./Dataset/reference-890\16_img_.png
# PSNR for 16_img_.png: 17.40
# ./results\170_img_.png
# ./Dataset/reference-890\170_img_.png
# PSNR for 170_img_.png: 14.08
# ./results\171_img_.png
# ./Dataset/reference-890\171_img_.png
# PSNR for 171_img_.png: 12.94
# ./results\172_img_.png
# ./Dataset/reference-890\172_img_.png
# PSNR for 172_img_.png: 17.56
# ./results\173_img_.png
# ./Dataset/reference-890\173_img_.png
# PSNR for 173_img_.png: 20.18
# ./results\1742.png
# ./Dataset/reference-890\1742.png
# PSNR for 1742.png: 20.13
# ./results\174_img_.png
# ./Dataset/reference-890\174_img_.png
# PSNR for 174_img_.png: 14.38
# ./results\175_img_.png
# ./Dataset/reference-890\175_img_.png
# PSNR for 175_img_.png: 18.82
# ./results\176_img_.png
# ./Dataset/reference-890\176_img_.png
# PSNR for 176_img_.png: 19.65
# ./results\177_img_.png
# ./Dataset/reference-890\177_img_.png
# PSNR for 177_img_.png: 19.23
# ./results\178_img_.png
# ./Dataset/reference-890\178_img_.png
# PSNR for 178_img_.png: 18.48
# ./results\179_img_.png
# ./Dataset/reference-890\179_img_.png
# PSNR for 179_img_.png: 27.79
# ./results\17_img_.png
# ./Dataset/reference-890\17_img_.png
# PSNR for 17_img_.png: 18.30
# ./results\180_img_.png
# ./Dataset/reference-890\180_img_.png
# PSNR for 180_img_.png: 17.98
# ./results\182_img_.png
# ./Dataset/reference-890\182_img_.png
# PSNR for 182_img_.png: 18.64
# ./results\183_img_.png
# ./Dataset/reference-890\183_img_.png
# PSNR for 183_img_.png: 17.27
# ./results\184_img_.png
# ./Dataset/reference-890\184_img_.png
# PSNR for 184_img_.png: 20.25
# ./results\185_img_.png
# ./Dataset/reference-890\185_img_.png
# PSNR for 185_img_.png: 21.17
# ./results\186_img_.png
# ./Dataset/reference-890\186_img_.png
# PSNR for 186_img_.png: 19.67
# ./results\187_img_.png
# ./Dataset/reference-890\187_img_.png
# PSNR for 187_img_.png: 19.61
# ./results\188_img_.png
# ./Dataset/reference-890\188_img_.png
# PSNR for 188_img_.png: 17.92
# ./results\189_img_.png
# ./Dataset/reference-890\189_img_.png
# PSNR for 189_img_.png: 13.76
# ./results\18_img_.png
# ./Dataset/reference-890\18_img_.png
# PSNR for 18_img_.png: 13.52
# ./results\190_img_.png
# ./Dataset/reference-890\190_img_.png
# PSNR for 190_img_.png: 21.21
# ./results\191_img_.png
# ./Dataset/reference-890\191_img_.png
# PSNR for 191_img_.png: 10.98
# ./results\192_img_.png
# ./Dataset/reference-890\192_img_.png
# PSNR for 192_img_.png: 16.65
# ./results\193_img_.png
# ./Dataset/reference-890\193_img_.png
# PSNR for 193_img_.png: 21.21
# ./results\194_img_.png
# ./Dataset/reference-890\194_img_.png
# PSNR for 194_img_.png: 19.44
# ./results\1957.png
# ./Dataset/reference-890\1957.png
# PSNR for 1957.png: 19.41
# ./results\195_img_.png
# ./Dataset/reference-890\195_img_.png
# PSNR for 195_img_.png: 24.81
# ./results\196_img_.png
# ./Dataset/reference-890\196_img_.png
# PSNR for 196_img_.png: 23.64
# ./results\197_img_.png
# ./Dataset/reference-890\197_img_.png
# PSNR for 197_img_.png: 21.33
# ./results\198_img_.png
# ./Dataset/reference-890\198_img_.png
# PSNR for 198_img_.png: 24.05
# ./results\199_img_.png
# ./Dataset/reference-890\199_img_.png
# PSNR for 199_img_.png: 18.00
# ./results\19_img_.png
# ./Dataset/reference-890\19_img_.png
# PSNR for 19_img_.png: 14.94
# ./results\20.png
# ./Dataset/reference-890\20.png
# PSNR for 20.png: 21.00
# ./results\200_img_.png
# ./Dataset/reference-890\200_img_.png
# PSNR for 200_img_.png: 16.63
# ./results\201_img_.png
# ./Dataset/reference-890\201_img_.png
# PSNR for 201_img_.png: 25.67
# ./results\202_img_.png
# ./Dataset/reference-890\202_img_.png
# PSNR for 202_img_.png: 15.23
# ./results\203_img_.png
# ./Dataset/reference-890\203_img_.png
# PSNR for 203_img_.png: 27.90
# ./results\204_img_.png
# ./Dataset/reference-890\204_img_.png
# PSNR for 204_img_.png: 17.25
# ./results\205_img_.png
# ./Dataset/reference-890\205_img_.png
# PSNR for 205_img_.png: 20.06
# ./results\206_img_.png
# ./Dataset/reference-890\206_img_.png
# PSNR for 206_img_.png: 19.51
# ./results\207_img_.png
# ./Dataset/reference-890\207_img_.png
# PSNR for 207_img_.png: 27.10
# ./results\208_img_.png
# ./Dataset/reference-890\208_img_.png
# PSNR for 208_img_.png: 29.42
# ./results\209_img_.png
# ./Dataset/reference-890\209_img_.png
# PSNR for 209_img_.png: 26.56
# ./results\210_img_.png
# ./Dataset/reference-890\210_img_.png
# PSNR for 210_img_.png: 28.46
# ./results\211_img_.png
# ./Dataset/reference-890\211_img_.png
# PSNR for 211_img_.png: 19.95
# ./results\212_img_.png
# ./Dataset/reference-890\212_img_.png
# PSNR for 212_img_.png: 21.90
# ./results\213_img_.png
# ./Dataset/reference-890\213_img_.png
# PSNR for 213_img_.png: 20.37
# ./results\214_img_.png
# ./Dataset/reference-890\214_img_.png
# PSNR for 214_img_.png: 21.40
# ./results\215_img_.png
# ./Dataset/reference-890\215_img_.png
# PSNR for 215_img_.png: 22.23
# ./results\216_img_.png
# ./Dataset/reference-890\216_img_.png
# PSNR for 216_img_.png: 21.25
# ./results\217_img_.png
# ./Dataset/reference-890\217_img_.png
# PSNR for 217_img_.png: 19.63
# ./results\219_img_.png
# ./Dataset/reference-890\219_img_.png
# PSNR for 219_img_.png: 17.15
# ./results\220_img_.png
# ./Dataset/reference-890\220_img_.png
# PSNR for 220_img_.png: 19.38
# ./results\221_img_.png
# ./Dataset/reference-890\221_img_.png
# PSNR for 221_img_.png: 20.60
# ./results\222_img_.png
# ./Dataset/reference-890\222_img_.png
# PSNR for 222_img_.png: 17.97
# ./results\223_img_.png
# ./Dataset/reference-890\223_img_.png
# PSNR for 223_img_.png: 22.59
# ./results\224_img_.png
# ./Dataset/reference-890\224_img_.png
# PSNR for 224_img_.png: 22.47
# ./results\225_img_.png
# ./Dataset/reference-890\225_img_.png
# PSNR for 225_img_.png: 16.85
# ./results\226_img_.png
# ./Dataset/reference-890\226_img_.png
# PSNR for 226_img_.png: 18.26
# ./results\227_img_.png
# ./Dataset/reference-890\227_img_.png
# PSNR for 227_img_.png: 14.84
# ./results\228_img_.png
# ./Dataset/reference-890\228_img_.png
# PSNR for 228_img_.png: 14.52
# ./results\229_img_.png
# ./Dataset/reference-890\229_img_.png
# PSNR for 229_img_.png: 18.79
# ./results\22_img_.png
# ./Dataset/reference-890\22_img_.png
# PSNR for 22_img_.png: 19.39
# ./results\230_img_.png
# ./Dataset/reference-890\230_img_.png
# PSNR for 230_img_.png: 26.89
# ./results\231_img_.png
# ./Dataset/reference-890\231_img_.png
# PSNR for 231_img_.png: 20.56
# ./results\232_img_.png
# ./Dataset/reference-890\232_img_.png
# PSNR for 232_img_.png: 19.94
# ./results\233_img_.png
# ./Dataset/reference-890\233_img_.png
# PSNR for 233_img_.png: 19.94
# ./results\234_img_.png
# ./Dataset/reference-890\234_img_.png
# PSNR for 234_img_.png: 18.19
# ./results\236_img_.png
# ./Dataset/reference-890\236_img_.png
# PSNR for 236_img_.png: 19.02
# ./results\238_img_.png
# ./Dataset/reference-890\238_img_.png
# PSNR for 238_img_.png: 16.99
# ./results\23_img_.png
# ./Dataset/reference-890\23_img_.png
# PSNR for 23_img_.png: 20.29
# ./results\240_img_.png
# ./Dataset/reference-890\240_img_.png
# PSNR for 240_img_.png: 21.67
# ./results\241_img_.png
# ./Dataset/reference-890\241_img_.png
# PSNR for 241_img_.png: 18.17
# ./results\242_img_.png
# ./Dataset/reference-890\242_img_.png
# PSNR for 242_img_.png: 23.37
# ./results\243_img_.png
# ./Dataset/reference-890\243_img_.png
# PSNR for 243_img_.png: 18.80
# ./results\244_img_.png
# ./Dataset/reference-890\244_img_.png
# PSNR for 244_img_.png: 20.19
# ./results\245_img_.png
# ./Dataset/reference-890\245_img_.png
# PSNR for 245_img_.png: 20.46
# ./results\246_img_.png
# ./Dataset/reference-890\246_img_.png
# PSNR for 246_img_.png: 21.65
# ./results\247_img_.png
# ./Dataset/reference-890\247_img_.png
# PSNR for 247_img_.png: 20.19
# ./results\248_img_.png
# ./Dataset/reference-890\248_img_.png
# PSNR for 248_img_.png: 18.92
# ./results\24_img_.png
# ./Dataset/reference-890\24_img_.png
# PSNR for 24_img_.png: 18.96
# ./results\251_img_.png
# ./Dataset/reference-890\251_img_.png
# PSNR for 251_img_.png: 22.49
# ./results\252_img_.png
# ./Dataset/reference-890\252_img_.png
# PSNR for 252_img_.png: 17.70
# ./results\253_img_.png
# ./Dataset/reference-890\253_img_.png
# PSNR for 253_img_.png: 19.96
# ./results\2546.png
# ./Dataset/reference-890\2546.png
# PSNR for 2546.png: 27.18
# ./results\254_img_.png
# ./Dataset/reference-890\254_img_.png
# PSNR for 254_img_.png: 18.69
# ./results\255_img_.png
# ./Dataset/reference-890\255_img_.png
# PSNR for 255_img_.png: 17.84
# ./results\257_img_.png
# ./Dataset/reference-890\257_img_.png
# PSNR for 257_img_.png: 27.06
# ./results\258_img_.png
# ./Dataset/reference-890\258_img_.png
# PSNR for 258_img_.png: 15.46
# ./results\259_img_.png
# ./Dataset/reference-890\259_img_.png
# PSNR for 259_img_.png: 18.48
# ./results\25_img_.png
# ./Dataset/reference-890\25_img_.png
# PSNR for 25_img_.png: 20.70
# ./results\260_img_.png
# ./Dataset/reference-890\260_img_.png
# PSNR for 260_img_.png: 19.66
# ./results\261_img_.png
# ./Dataset/reference-890\261_img_.png
# PSNR for 261_img_.png: 21.72
# ./results\2629.png
# ./Dataset/reference-890\2629.png
# PSNR for 2629.png: 17.88
# ./results\262_img_.png
# ./Dataset/reference-890\262_img_.png
# PSNR for 262_img_.png: 19.56
# ./results\263_img_.png
# ./Dataset/reference-890\263_img_.png
# PSNR for 263_img_.png: 16.05
# ./results\265_img_.png
# ./Dataset/reference-890\265_img_.png
# PSNR for 265_img_.png: 17.89
# ./results\266_img_.png
# ./Dataset/reference-890\266_img_.png
# PSNR for 266_img_.png: 18.95
# ./results\2677.png
# ./Dataset/reference-890\2677.png
# PSNR for 2677.png: 15.77
# ./results\267_img_.png
# ./Dataset/reference-890\267_img_.png
# PSNR for 267_img_.png: 21.15
# ./results\268_img_.png
# ./Dataset/reference-890\268_img_.png
# PSNR for 268_img_.png: 17.34
# ./results\26_img_.png
# ./Dataset/reference-890\26_img_.png
# PSNR for 26_img_.png: 21.09
# ./results\2701.png
# ./Dataset/reference-890\2701.png
# PSNR for 2701.png: 13.67
# ./results\270_img_.png
# ./Dataset/reference-890\270_img_.png
# PSNR for 270_img_.png: 17.48
# ./results\271_img_.png
# ./Dataset/reference-890\271_img_.png
# PSNR for 271_img_.png: 19.21
# ./results\272_img_.png
# ./Dataset/reference-890\272_img_.png
# PSNR for 272_img_.png: 20.86
# ./results\273_img_.png
# ./Dataset/reference-890\273_img_.png
# PSNR for 273_img_.png: 21.37
# ./results\274_img_.png
# ./Dataset/reference-890\274_img_.png
# PSNR for 274_img_.png: 14.91
# ./results\275_img_.png
# ./Dataset/reference-890\275_img_.png
# PSNR for 275_img_.png: 19.10
# ./results\276_img_.png
# ./Dataset/reference-890\276_img_.png
# PSNR for 276_img_.png: 19.02
# ./results\2774.png
# ./Dataset/reference-890\2774.png
# PSNR for 2774.png: 20.11
# ./results\277_img_.png
# ./Dataset/reference-890\277_img_.png
# PSNR for 277_img_.png: 20.55
# ./results\2787.png
# ./Dataset/reference-890\2787.png
# PSNR for 2787.png: 22.16
# ./results\278_img_.png
# ./Dataset/reference-890\278_img_.png
# PSNR for 278_img_.png: 21.47
# ./results\279_img_.png
# ./Dataset/reference-890\279_img_.png
# PSNR for 279_img_.png: 14.97
# ./results\27_img_.png
# ./Dataset/reference-890\27_img_.png
# PSNR for 27_img_.png: 21.06
# ./results\280_img_.png
# ./Dataset/reference-890\280_img_.png
# PSNR for 280_img_.png: 21.31
# ./results\281_img_.png
# ./Dataset/reference-890\281_img_.png
# PSNR for 281_img_.png: 18.45
# ./results\282_img_.png
# ./Dataset/reference-890\282_img_.png
# PSNR for 282_img_.png: 20.74
# ./results\284_img_.png
# ./Dataset/reference-890\284_img_.png
# PSNR for 284_img_.png: 20.15
# ./results\285_img_.png
# ./Dataset/reference-890\285_img_.png
# PSNR for 285_img_.png: 19.39
# ./results\287_img_.png
# ./Dataset/reference-890\287_img_.png
# PSNR for 287_img_.png: 18.21
# ./results\2882.png
# ./Dataset/reference-890\2882.png
# PSNR for 2882.png: 18.34
# ./results\288_img_.png
# ./Dataset/reference-890\288_img_.png
# PSNR for 288_img_.png: 17.76
# ./results\28_img_.png
# ./Dataset/reference-890\28_img_.png
# PSNR for 28_img_.png: 20.95
# ./results\290_img_.png
# ./Dataset/reference-890\290_img_.png
# PSNR for 290_img_.png: 21.37
# ./results\292_img_.png
# ./Dataset/reference-890\292_img_.png
# PSNR for 292_img_.png: 25.01
# ./results\293_img_.png
# ./Dataset/reference-890\293_img_.png
# PSNR for 293_img_.png: 15.35
# ./results\294_img_.png
# ./Dataset/reference-890\294_img_.png
# PSNR for 294_img_.png: 19.65
# ./results\295_img_.png
# ./Dataset/reference-890\295_img_.png
# PSNR for 295_img_.png: 17.29
# ./results\296_img_.png
# ./Dataset/reference-890\296_img_.png
# PSNR for 296_img_.png: 24.81
# ./results\2977.png
# ./Dataset/reference-890\2977.png
# PSNR for 2977.png: 14.71
# ./results\298_img_.png
# ./Dataset/reference-890\298_img_.png
# PSNR for 298_img_.png: 16.14
# ./results\299_img_.png
# ./Dataset/reference-890\299_img_.png
# PSNR for 299_img_.png: 20.27
# ./results\29_img_.png
# ./Dataset/reference-890\29_img_.png
# PSNR for 29_img_.png: 23.86
# ./results\2_img_.png
# ./Dataset/reference-890\2_img_.png
# PSNR for 2_img_.png: 21.54
# ./results\3001.png
# ./Dataset/reference-890\3001.png
# PSNR for 3001.png: 20.42
# ./results\300_img_.png
# ./Dataset/reference-890\300_img_.png
# PSNR for 300_img_.png: 16.76
# ./results\3015.png
# ./Dataset/reference-890\3015.png
# PSNR for 3015.png: 21.43
# ./results\301_img_.png
# ./Dataset/reference-890\301_img_.png
# PSNR for 301_img_.png: 17.36
# ./results\302_img_.png
# ./Dataset/reference-890\302_img_.png
# PSNR for 302_img_.png: 17.59
# ./results\303_img_.png
# ./Dataset/reference-890\303_img_.png
# PSNR for 303_img_.png: 25.98
# ./results\304_img_.png
# ./Dataset/reference-890\304_img_.png
# PSNR for 304_img_.png: 20.18
# ./results\305_img_.png
# ./Dataset/reference-890\305_img_.png
# PSNR for 305_img_.png: 19.69
# ./results\306_img_.png
# ./Dataset/reference-890\306_img_.png
# PSNR for 306_img_.png: 21.76
# ./results\307_img_.png
# ./Dataset/reference-890\307_img_.png
# PSNR for 307_img_.png: 16.96
# ./results\30_img_.png
# ./Dataset/reference-890\30_img_.png
# PSNR for 30_img_.png: 15.50
# ./results\31.png
# ./Dataset/reference-890\31.png
# PSNR for 31.png: 21.04
# ./results\311_img_.png
# ./Dataset/reference-890\311_img_.png
# PSNR for 311_img_.png: 19.35
# ./results\312_img_.png
# ./Dataset/reference-890\312_img_.png
# PSNR for 312_img_.png: 24.18
# ./results\313_img_.png
# ./Dataset/reference-890\313_img_.png
# PSNR for 313_img_.png: 19.96
# ./results\314_img_.png
# ./Dataset/reference-890\314_img_.png
# PSNR for 314_img_.png: 21.76
# ./results\315_img_.png
# ./Dataset/reference-890\315_img_.png
# PSNR for 315_img_.png: 16.57
# ./results\316_img_.png
# ./Dataset/reference-890\316_img_.png
# PSNR for 316_img_.png: 17.04
# ./results\317_img_.png
# ./Dataset/reference-890\317_img_.png
# PSNR for 317_img_.png: 17.17
# ./results\318_img_.png
# ./Dataset/reference-890\318_img_.png
# PSNR for 318_img_.png: 28.46
# ./results\3196.png
# ./Dataset/reference-890\3196.png
# PSNR for 3196.png: 21.34
# ./results\319_img_.png
# ./Dataset/reference-890\319_img_.png
# PSNR for 319_img_.png: 14.80
# ./results\3202.png
# ./Dataset/reference-890\3202.png
# PSNR for 3202.png: 22.71
# ./results\320_img_.png
# ./Dataset/reference-890\320_img_.png
# PSNR for 320_img_.png: 21.16
# ./results\322_img_.png
# ./Dataset/reference-890\322_img_.png
# PSNR for 322_img_.png: 11.61
# ./results\323_img_.png
# ./Dataset/reference-890\323_img_.png
# PSNR for 323_img_.png: 18.92
# ./results\324_img_.png
# ./Dataset/reference-890\324_img_.png
# PSNR for 324_img_.png: 19.91
# ./results\325_img_.png
# ./Dataset/reference-890\325_img_.png
# PSNR for 325_img_.png: 12.95
# ./results\326_img_.png
# ./Dataset/reference-890\326_img_.png
# PSNR for 326_img_.png: 14.77
# ./results\327_img_.png
# ./Dataset/reference-890\327_img_.png
# PSNR for 327_img_.png: 22.06
# ./results\328_img_.png
# ./Dataset/reference-890\328_img_.png
# PSNR for 328_img_.png: 22.17
# ./results\32_img_.png
# ./Dataset/reference-890\32_img_.png
# PSNR for 32_img_.png: 17.61
# ./results\330_img_.png
# ./Dataset/reference-890\330_img_.png
# PSNR for 330_img_.png: 17.28
# ./results\332_img_.png
# ./Dataset/reference-890\332_img_.png
# PSNR for 332_img_.png: 28.07
# ./results\3330.png
# ./Dataset/reference-890\3330.png
# PSNR for 3330.png: 18.38
# ./results\334_img_.png
# ./Dataset/reference-890\334_img_.png
# PSNR for 334_img_.png: 15.83
# ./results\336_img_.png
# ./Dataset/reference-890\336_img_.png
# PSNR for 336_img_.png: 21.02
# ./results\337_img_.png
# ./Dataset/reference-890\337_img_.png
# PSNR for 337_img_.png: 20.69
# ./results\338_img_.png
# ./Dataset/reference-890\338_img_.png
# PSNR for 338_img_.png: 20.45
# ./results\340_img_.png
# ./Dataset/reference-890\340_img_.png
# PSNR for 340_img_.png: 20.37
# ./results\341_img_.png
# ./Dataset/reference-890\341_img_.png
# PSNR for 341_img_.png: 19.81
# ./results\342_img_.png
# ./Dataset/reference-890\342_img_.png
# PSNR for 342_img_.png: 14.02
# ./results\343_img_.png
# ./Dataset/reference-890\343_img_.png
# PSNR for 343_img_.png: 26.33
# ./results\345_img_.png
# ./Dataset/reference-890\345_img_.png
# PSNR for 345_img_.png: 19.74
# ./results\346_img_.png
# ./Dataset/reference-890\346_img_.png
# PSNR for 346_img_.png: 21.40
# ./results\347_img_.png
# ./Dataset/reference-890\347_img_.png
# PSNR for 347_img_.png: 17.92
# ./results\348_img_.png
# ./Dataset/reference-890\348_img_.png
# PSNR for 348_img_.png: 13.46
# ./results\35.png
# ./Dataset/reference-890\35.png
# PSNR for 35.png: 21.77
# ./results\350_img_.png
# ./Dataset/reference-890\350_img_.png
# PSNR for 350_img_.png: 21.85
# ./results\351_img_.png
# ./Dataset/reference-890\351_img_.png
# PSNR for 351_img_.png: 25.57
# ./results\353_img_.png
# ./Dataset/reference-890\353_img_.png
# PSNR for 353_img_.png: 14.01
# ./results\355_img_.png
# ./Dataset/reference-890\355_img_.png
# PSNR for 355_img_.png: 22.40
# ./results\356_img_.png
# ./Dataset/reference-890\356_img_.png
# PSNR for 356_img_.png: 13.05
# ./results\359_img_.png
# ./Dataset/reference-890\359_img_.png
# PSNR for 359_img_.png: 20.39
# ./results\360_img_.png
# ./Dataset/reference-890\360_img_.png
# PSNR for 360_img_.png: 15.39
# ./results\361_img_.png
# ./Dataset/reference-890\361_img_.png
# PSNR for 361_img_.png: 16.70
# ./results\362_img_.png
# ./Dataset/reference-890\362_img_.png
# PSNR for 362_img_.png: 18.35
# ./results\363_img_.png
# ./Dataset/reference-890\363_img_.png
# PSNR for 363_img_.png: 20.63
# ./results\364_img_.png
# ./Dataset/reference-890\364_img_.png
# PSNR for 364_img_.png: 21.32
# ./results\3650.png
# ./Dataset/reference-890\3650.png
# PSNR for 3650.png: 22.92
# ./results\365_img_.png
# ./Dataset/reference-890\365_img_.png
# PSNR for 365_img_.png: 15.65
# ./results\366_img_.png
# ./Dataset/reference-890\366_img_.png
# PSNR for 366_img_.png: 21.18
# ./results\367_img_.png
# ./Dataset/reference-890\367_img_.png
# PSNR for 367_img_.png: 14.60
# ./results\369_img_.png
# ./Dataset/reference-890\369_img_.png
# PSNR for 369_img_.png: 26.59
# ./results\370_img_.png
# ./Dataset/reference-890\370_img_.png
# PSNR for 370_img_.png: 25.15
# ./results\371_img_.png
# ./Dataset/reference-890\371_img_.png
# PSNR for 371_img_.png: 16.90
# ./results\3728.png
# ./Dataset/reference-890\3728.png
# PSNR for 3728.png: 22.01
# ./results\372_img_.png
# ./Dataset/reference-890\372_img_.png
# PSNR for 372_img_.png: 15.04
# ./results\373_img_.png
# ./Dataset/reference-890\373_img_.png
# PSNR for 373_img_.png: 23.92
# ./results\374_img_.png
# ./Dataset/reference-890\374_img_.png
# PSNR for 374_img_.png: 12.86
# ./results\375_img_.png
# ./Dataset/reference-890\375_img_.png
# PSNR for 375_img_.png: 21.23
# ./results\376_img_.png
# ./Dataset/reference-890\376_img_.png
# PSNR for 376_img_.png: 18.93
# ./results\377_img_.png
# ./Dataset/reference-890\377_img_.png
# PSNR for 377_img_.png: 17.84
# ./results\378_img_.png
# ./Dataset/reference-890\378_img_.png
# PSNR for 378_img_.png: 20.95
# ./results\379_img_.png
# ./Dataset/reference-890\379_img_.png
# PSNR for 379_img_.png: 15.12
# ./results\37_img_.png
# ./Dataset/reference-890\37_img_.png
# PSNR for 37_img_.png: 17.74
# ./results\380_img_.png
# ./Dataset/reference-890\380_img_.png
# PSNR for 380_img_.png: 15.36
# ./results\381_img_.png
# ./Dataset/reference-890\381_img_.png
# PSNR for 381_img_.png: 14.96
# ./results\382_img_.png
# ./Dataset/reference-890\382_img_.png
# PSNR for 382_img_.png: 15.93
# ./results\383_img_.png
# ./Dataset/reference-890\383_img_.png
# PSNR for 383_img_.png: 19.11
# ./results\384_img_.png
# ./Dataset/reference-890\384_img_.png
# PSNR for 384_img_.png: 17.53
# ./results\385_img_.png
# ./Dataset/reference-890\385_img_.png
# PSNR for 385_img_.png: 12.10
# ./results\386_img_.png
# ./Dataset/reference-890\386_img_.png
# PSNR for 386_img_.png: 30.52
# ./results\387_img_.png
# ./Dataset/reference-890\387_img_.png
# PSNR for 387_img_.png: 20.85
# ./results\389_img_.png
# ./Dataset/reference-890\389_img_.png
# PSNR for 389_img_.png: 13.12
# ./results\391_img_.png
# ./Dataset/reference-890\391_img_.png
# PSNR for 391_img_.png: 13.85
# ./results\3925.png
# ./Dataset/reference-890\3925.png
# PSNR for 3925.png: 22.41
# ./results\392_img_.png
# ./Dataset/reference-890\392_img_.png
# PSNR for 392_img_.png: 14.49
# ./results\393_img_.png
# ./Dataset/reference-890\393_img_.png
# PSNR for 393_img_.png: 17.94
# ./results\3947.png
# ./Dataset/reference-890\3947.png
# PSNR for 3947.png: 24.75
# ./results\394_img_.png
# ./Dataset/reference-890\394_img_.png
# PSNR for 394_img_.png: 18.17
# ./results\395_img_.png
# ./Dataset/reference-890\395_img_.png
# PSNR for 395_img_.png: 22.51
# ./results\39_img_.png
# ./Dataset/reference-890\39_img_.png
# PSNR for 39_img_.png: 20.07
# ./results\3_img_.png
# ./Dataset/reference-890\3_img_.png
# PSNR for 3_img_.png: 21.63
# ./results\4.png
# ./Dataset/reference-890\4.png
# PSNR for 4.png: 17.39
# ./results\400_img_.png
# ./Dataset/reference-890\400_img_.png
# PSNR for 400_img_.png: 19.79
# ./results\401_img_.png
# ./Dataset/reference-890\401_img_.png
# PSNR for 401_img_.png: 20.20
# ./results\402_img_.png
# ./Dataset/reference-890\402_img_.png
# PSNR for 402_img_.png: 18.89
# ./results\403_img_.png
# ./Dataset/reference-890\403_img_.png
# PSNR for 403_img_.png: 15.49
# ./results\404_img_.png
# ./Dataset/reference-890\404_img_.png
# PSNR for 404_img_.png: 16.03
# ./results\405_img_.png
# ./Dataset/reference-890\405_img_.png
# PSNR for 405_img_.png: 11.48
# ./results\406_img_.png
# ./Dataset/reference-890\406_img_.png
# PSNR for 406_img_.png: 17.16
# ./results\4070.png
# ./Dataset/reference-890\4070.png
# PSNR for 4070.png: 29.18
# ./results\407_img_.png
# ./Dataset/reference-890\407_img_.png
# PSNR for 407_img_.png: 10.38
# ./results\408_img_.png
# ./Dataset/reference-890\408_img_.png
# PSNR for 408_img_.png: 25.40
# ./results\409_img_.png
# ./Dataset/reference-890\409_img_.png
# PSNR for 409_img_.png: 16.91
# ./results\410_img_.png
# ./Dataset/reference-890\410_img_.png
# PSNR for 410_img_.png: 16.32
# ./results\411_img_.png
# ./Dataset/reference-890\411_img_.png
# PSNR for 411_img_.png: 19.18
# ./results\412_img_.png
# ./Dataset/reference-890\412_img_.png
# PSNR for 412_img_.png: 17.75
# ./results\413_img_.png
# ./Dataset/reference-890\413_img_.png
# PSNR for 413_img_.png: 14.89
# ./results\415_img_.png
# ./Dataset/reference-890\415_img_.png
# PSNR for 415_img_.png: 20.94
# ./results\416_img_.png
# ./Dataset/reference-890\416_img_.png
# PSNR for 416_img_.png: 20.74
# ./results\417_img_.png
# ./Dataset/reference-890\417_img_.png
# PSNR for 417_img_.png: 17.23
# ./results\418_img_.png
# ./Dataset/reference-890\418_img_.png
# PSNR for 418_img_.png: 16.63
# ./results\419_img_.png
# ./Dataset/reference-890\419_img_.png
# PSNR for 419_img_.png: 18.19
# ./results\41_img_.png
# ./Dataset/reference-890\41_img_.png
# PSNR for 41_img_.png: 15.79
# ./results\420_img_.png
# ./Dataset/reference-890\420_img_.png
# PSNR for 420_img_.png: 17.09
# ./results\421_img_.png
# ./Dataset/reference-890\421_img_.png
# PSNR for 421_img_.png: 21.53
# ./results\422_img_.png
# ./Dataset/reference-890\422_img_.png
# PSNR for 422_img_.png: 19.73
# ./results\423_img_.png
# ./Dataset/reference-890\423_img_.png
# PSNR for 423_img_.png: 17.75
# ./results\424_img_.png
# ./Dataset/reference-890\424_img_.png
# PSNR for 424_img_.png: 22.60
# ./results\425_img_.png
# ./Dataset/reference-890\425_img_.png
# PSNR for 425_img_.png: 21.79
# ./results\428_img_.png
# ./Dataset/reference-890\428_img_.png
# PSNR for 428_img_.png: 20.63
# ./results\429_img_.png
# ./Dataset/reference-890\429_img_.png
# PSNR for 429_img_.png: 20.73
# ./results\42_img_.png
# ./Dataset/reference-890\42_img_.png
# PSNR for 42_img_.png: 13.65
# ./results\432_img_.png
# ./Dataset/reference-890\432_img_.png
# PSNR for 432_img_.png: 19.21
# ./results\433_img_.png
# ./Dataset/reference-890\433_img_.png
# PSNR for 433_img_.png: 17.70
# ./results\435_img_.png
# ./Dataset/reference-890\435_img_.png
# PSNR for 435_img_.png: 16.78
# ./results\436_img_.png
# ./Dataset/reference-890\436_img_.png
# PSNR for 436_img_.png: 23.09
# ./results\437_img_.png
# ./Dataset/reference-890\437_img_.png
# PSNR for 437_img_.png: 20.70
# ./results\438_img_.png
# ./Dataset/reference-890\438_img_.png
# PSNR for 438_img_.png: 9.84
# ./results\439_img_.png
# ./Dataset/reference-890\439_img_.png
# PSNR for 439_img_.png: 26.91
# ./results\43_img_.png
# ./Dataset/reference-890\43_img_.png
# PSNR for 43_img_.png: 21.36
# ./results\440_img_.png
# ./Dataset/reference-890\440_img_.png
# PSNR for 440_img_.png: 13.21
# ./results\441_img_.png
# ./Dataset/reference-890\441_img_.png
# PSNR for 441_img_.png: 13.59
# ./results\442_img_.png
# ./Dataset/reference-890\442_img_.png
# PSNR for 442_img_.png: 15.68
# ./results\443_img_.png
# ./Dataset/reference-890\443_img_.png
# PSNR for 443_img_.png: 14.25
# ./results\444_img_.png
# ./Dataset/reference-890\444_img_.png
# PSNR for 444_img_.png: 20.41
# ./results\445_img_.png
# ./Dataset/reference-890\445_img_.png
# PSNR for 445_img_.png: 19.48
# ./results\446_img_.png
# ./Dataset/reference-890\446_img_.png
# PSNR for 446_img_.png: 14.74
# ./results\447_img_.png
# ./Dataset/reference-890\447_img_.png
# PSNR for 447_img_.png: 15.72
# ./results\448_img_.png
# ./Dataset/reference-890\448_img_.png
# PSNR for 448_img_.png: 21.00
# ./results\449_img_.png
# ./Dataset/reference-890\449_img_.png
# PSNR for 449_img_.png: 19.83
# ./results\44_img_.png
# ./Dataset/reference-890\44_img_.png
# PSNR for 44_img_.png: 16.43
# ./results\450_img_.png
# ./Dataset/reference-890\450_img_.png
# PSNR for 450_img_.png: 21.89
# ./results\451_img_.png
# ./Dataset/reference-890\451_img_.png
# PSNR for 451_img_.png: 21.30
# ./results\452_img_.png
# ./Dataset/reference-890\452_img_.png
# PSNR for 452_img_.png: 19.12
# ./results\453_img_.png
# ./Dataset/reference-890\453_img_.png
# PSNR for 453_img_.png: 22.12
# ./results\454_img_.png
# ./Dataset/reference-890\454_img_.png
# PSNR for 454_img_.png: 17.64
# ./results\455_img_.png
# ./Dataset/reference-890\455_img_.png
# PSNR for 455_img_.png: 16.96
# ./results\457_img_.png
# ./Dataset/reference-890\457_img_.png
# PSNR for 457_img_.png: 17.48
# ./results\458_img_.png
# ./Dataset/reference-890\458_img_.png
# PSNR for 458_img_.png: 24.53
# ./results\459_img_.png
# ./Dataset/reference-890\459_img_.png
# PSNR for 459_img_.png: 12.80
# ./results\45_img_.png
# ./Dataset/reference-890\45_img_.png
# PSNR for 45_img_.png: 17.30
# ./results\460_img_.png
# ./Dataset/reference-890\460_img_.png
# PSNR for 460_img_.png: 21.65
# ./results\461_img_.png
# ./Dataset/reference-890\461_img_.png
# PSNR for 461_img_.png: 19.41
# ./results\462_img_.png
# ./Dataset/reference-890\462_img_.png
# PSNR for 462_img_.png: 19.41
# ./results\463_img_.png
# ./Dataset/reference-890\463_img_.png
# PSNR for 463_img_.png: 21.22
# ./results\464_img_.png
# ./Dataset/reference-890\464_img_.png
# PSNR for 464_img_.png: 18.57
# ./results\465_img_.png
# ./Dataset/reference-890\465_img_.png
# PSNR for 465_img_.png: 18.87
# ./results\466_img_.png
# ./Dataset/reference-890\466_img_.png
# PSNR for 466_img_.png: 15.75
# ./results\467_img_.png
# ./Dataset/reference-890\467_img_.png
# PSNR for 467_img_.png: 18.60
# ./results\468_img_.png
# ./Dataset/reference-890\468_img_.png
# PSNR for 468_img_.png: 19.90
# ./results\469_img_.png
# ./Dataset/reference-890\469_img_.png
# PSNR for 469_img_.png: 21.00
# ./results\46_img_.png
# ./Dataset/reference-890\46_img_.png
# PSNR for 46_img_.png: 22.43
# ./results\470_img_.png
# ./Dataset/reference-890\470_img_.png
# PSNR for 470_img_.png: 13.11
# ./results\471_img_.png
# ./Dataset/reference-890\471_img_.png
# PSNR for 471_img_.png: 20.46
# ./results\472_img_.png
# ./Dataset/reference-890\472_img_.png
# PSNR for 472_img_.png: 16.45
# ./results\473_img_.png
# ./Dataset/reference-890\473_img_.png
# PSNR for 473_img_.png: 19.42
# ./results\476_img_.png
# ./Dataset/reference-890\476_img_.png
# PSNR for 476_img_.png: 21.22
# ./results\477_img_.png
# ./Dataset/reference-890\477_img_.png
# PSNR for 477_img_.png: 19.65
# ./results\478_img_.png
# ./Dataset/reference-890\478_img_.png
# PSNR for 478_img_.png: 18.31
# ./results\479_img_.png
# ./Dataset/reference-890\479_img_.png
# PSNR for 479_img_.png: 19.41
# ./results\480_img_.png
# ./Dataset/reference-890\480_img_.png
# PSNR for 480_img_.png: 15.72
# ./results\481_img_.png
# ./Dataset/reference-890\481_img_.png
# PSNR for 481_img_.png: 18.54
# ./results\482_img_.png
# ./Dataset/reference-890\482_img_.png
# PSNR for 482_img_.png: 16.07
# ./results\483_img_.png
# ./Dataset/reference-890\483_img_.png
# PSNR for 483_img_.png: 20.30
# ./results\484_img_.png
# ./Dataset/reference-890\484_img_.png
# PSNR for 484_img_.png: 18.48
# ./results\485_img_.png
# ./Dataset/reference-890\485_img_.png
# PSNR for 485_img_.png: 19.60
# ./results\486_img_.png
# ./Dataset/reference-890\486_img_.png
# PSNR for 486_img_.png: 17.03
# ./results\487_img_.png
# ./Dataset/reference-890\487_img_.png
# PSNR for 487_img_.png: 18.00
# ./results\488_img_.png
# ./Dataset/reference-890\488_img_.png
# PSNR for 488_img_.png: 20.95
# ./results\489_img_.png
# ./Dataset/reference-890\489_img_.png
# PSNR for 489_img_.png: 20.53
# ./results\48_img_.png
# ./Dataset/reference-890\48_img_.png
# PSNR for 48_img_.png: 25.59
# ./results\490_img_.png
# ./Dataset/reference-890\490_img_.png
# PSNR for 490_img_.png: 13.42
# ./results\491_img_.png
# ./Dataset/reference-890\491_img_.png
# PSNR for 491_img_.png: 19.50
# ./results\492_img_.png
# ./Dataset/reference-890\492_img_.png
# PSNR for 492_img_.png: 22.68
# ./results\493_img_.png
# ./Dataset/reference-890\493_img_.png
# PSNR for 493_img_.png: 19.75
# ./results\494_img_.png
# ./Dataset/reference-890\494_img_.png
# PSNR for 494_img_.png: 18.23
# ./results\495_img_.png
# ./Dataset/reference-890\495_img_.png
# PSNR for 495_img_.png: 18.45
# ./results\496_img_.png
# ./Dataset/reference-890\496_img_.png
# PSNR for 496_img_.png: 14.63
# ./results\497_img_.png
# ./Dataset/reference-890\497_img_.png
# PSNR for 497_img_.png: 16.03
# ./results\498_img_.png
# ./Dataset/reference-890\498_img_.png
# PSNR for 498_img_.png: 16.35
# ./results\499_img_.png
# ./Dataset/reference-890\499_img_.png
# PSNR for 499_img_.png: 17.89
# ./results\49_img_.png
# ./Dataset/reference-890\49_img_.png
# PSNR for 49_img_.png: 20.03
# ./results\4_img_.png
# ./Dataset/reference-890\4_img_.png
# PSNR for 4_img_.png: 25.23
# ./results\501_img_.png
# ./Dataset/reference-890\501_img_.png
# PSNR for 501_img_.png: 17.67
# ./results\502_img_.png
# ./Dataset/reference-890\502_img_.png
# PSNR for 502_img_.png: 21.46
# ./results\503_img_.png
# ./Dataset/reference-890\503_img_.png
# PSNR for 503_img_.png: 19.26
# ./results\504_img_.png
# ./Dataset/reference-890\504_img_.png
# PSNR for 504_img_.png: 18.48
# ./results\505_img_.png
# ./Dataset/reference-890\505_img_.png
# PSNR for 505_img_.png: 19.41
# ./results\506_img_.png
# ./Dataset/reference-890\506_img_.png
# PSNR for 506_img_.png: 23.35
# ./results\507_img_.png
# ./Dataset/reference-890\507_img_.png
# PSNR for 507_img_.png: 30.85
# ./results\508_img_.png
# ./Dataset/reference-890\508_img_.png
# PSNR for 508_img_.png: 16.80
# ./results\509_img_.png
# ./Dataset/reference-890\509_img_.png
# PSNR for 509_img_.png: 19.92
# ./results\50_img_.png
# ./Dataset/reference-890\50_img_.png
# PSNR for 50_img_.png: 20.14
# ./results\510_img_.png
# ./Dataset/reference-890\510_img_.png
# PSNR for 510_img_.png: 17.08
# ./results\511_img_.png
# ./Dataset/reference-890\511_img_.png
# PSNR for 511_img_.png: 20.89
# ./results\512_img_.png
# ./Dataset/reference-890\512_img_.png
# PSNR for 512_img_.png: 24.05
# ./results\513_img_.png
# ./Dataset/reference-890\513_img_.png
# PSNR for 513_img_.png: 18.17
# ./results\515_img_.png
# ./Dataset/reference-890\515_img_.png
# PSNR for 515_img_.png: 17.49
# ./results\516_img_.png
# ./Dataset/reference-890\516_img_.png
# PSNR for 516_img_.png: 20.66
# ./results\517_img_.png
# ./Dataset/reference-890\517_img_.png
# PSNR for 517_img_.png: 23.17
# ./results\518_img_.png
# ./Dataset/reference-890\518_img_.png
# PSNR for 518_img_.png: 11.01
# ./results\519_img_.png
# ./Dataset/reference-890\519_img_.png
# PSNR for 519_img_.png: 13.91
# ./results\51_img_.png
# ./Dataset/reference-890\51_img_.png
# PSNR for 51_img_.png: 19.77
# ./results\524_img_.png
# ./Dataset/reference-890\524_img_.png
# PSNR for 524_img_.png: 16.27
# ./results\526_img_.png
# ./Dataset/reference-890\526_img_.png
# PSNR for 526_img_.png: 12.44
# ./results\527_img_.png
# ./Dataset/reference-890\527_img_.png
# PSNR for 527_img_.png: 17.72
# ./results\528_img_.png
# ./Dataset/reference-890\528_img_.png
# PSNR for 528_img_.png: 10.72
# ./results\52_img_.png
# ./Dataset/reference-890\52_img_.png
# PSNR for 52_img_.png: 17.42
# ./results\530_img_.png
# ./Dataset/reference-890\530_img_.png
# PSNR for 530_img_.png: 19.93
# ./results\531_img_.png
# ./Dataset/reference-890\531_img_.png
# PSNR for 531_img_.png: 31.31
# ./results\532_img_.png
# ./Dataset/reference-890\532_img_.png
# PSNR for 532_img_.png: 16.18
# ./results\533_img_.png
# ./Dataset/reference-890\533_img_.png
# PSNR for 533_img_.png: 16.24
# ./results\534_img_.png
# ./Dataset/reference-890\534_img_.png
# PSNR for 534_img_.png: 16.05
# ./results\535_img_.png
# ./Dataset/reference-890\535_img_.png
# PSNR for 535_img_.png: 13.00
# ./results\536_img_.png
# ./Dataset/reference-890\536_img_.png
# PSNR for 536_img_.png: 21.87
# ./results\537_img_.png
# ./Dataset/reference-890\537_img_.png
# PSNR for 537_img_.png: 21.34
# ./results\538_img_.png
# ./Dataset/reference-890\538_img_.png
# PSNR for 538_img_.png: 18.46
# ./results\539.png
# ./Dataset/reference-890\539.png
# PSNR for 539.png: 17.80
# ./results\539_img_.png
# ./Dataset/reference-890\539_img_.png
# PSNR for 539_img_.png: 16.63
# ./results\53_img_.png
# ./Dataset/reference-890\53_img_.png
# PSNR for 53_img_.png: 12.90
# ./results\540_img_.png
# ./Dataset/reference-890\540_img_.png
# PSNR for 540_img_.png: 19.78
# ./results\541_img_.png
# ./Dataset/reference-890\541_img_.png
# PSNR for 541_img_.png: 18.62
# ./results\542_img_.png
# ./Dataset/reference-890\542_img_.png
# PSNR for 542_img_.png: 14.23
# ./results\543_img_.png
# ./Dataset/reference-890\543_img_.png
# PSNR for 543_img_.png: 15.53
# ./results\544_img_.png
# ./Dataset/reference-890\544_img_.png
# PSNR for 544_img_.png: 10.94
# ./results\545_img_.png
# ./Dataset/reference-890\545_img_.png
# PSNR for 545_img_.png: 12.64
# ./results\546_img_.png
# ./Dataset/reference-890\546_img_.png
# PSNR for 546_img_.png: 15.47
# ./results\547_img_.png
# ./Dataset/reference-890\547_img_.png
# PSNR for 547_img_.png: 21.64
# ./results\549_img_.png
# ./Dataset/reference-890\549_img_.png
# PSNR for 549_img_.png: 15.99
# ./results\550_img_.png
# ./Dataset/reference-890\550_img_.png
# PSNR for 550_img_.png: 18.31
# ./results\551_img_.png
# ./Dataset/reference-890\551_img_.png
# PSNR for 551_img_.png: 15.17
# ./results\552_img_.png
# ./Dataset/reference-890\552_img_.png
# PSNR for 552_img_.png: 18.88
# ./results\554_img_.png
# ./Dataset/reference-890\554_img_.png
# PSNR for 554_img_.png: 21.17
# ./results\5554.png
# ./Dataset/reference-890\5554.png
# PSNR for 5554.png: 22.26
# ./results\555_img_.png
# ./Dataset/reference-890\555_img_.png
# PSNR for 555_img_.png: 12.11
# ./results\556_img_.png
# ./Dataset/reference-890\556_img_.png
# PSNR for 556_img_.png: 16.54
# ./results\557.png
# ./Dataset/reference-890\557.png
# PSNR for 557.png: 21.49
# ./results\557_img_.png
# ./Dataset/reference-890\557_img_.png
# PSNR for 557_img_.png: 15.92
# ./results\558_img_.png
# ./Dataset/reference-890\558_img_.png
# PSNR for 558_img_.png: 16.61
# ./results\559.png
# ./Dataset/reference-890\559.png
# PSNR for 559.png: 16.52
# ./results\55_img_.png
# ./Dataset/reference-890\55_img_.png
# PSNR for 55_img_.png: 20.50
# ./results\560_img_.png
# ./Dataset/reference-890\560_img_.png
# PSNR for 560_img_.png: 21.11
# ./results\561_img_.png
# ./Dataset/reference-890\561_img_.png
# PSNR for 561_img_.png: 21.09
# ./results\562_img_.png
# ./Dataset/reference-890\562_img_.png
# PSNR for 562_img_.png: 16.88
# ./results\563.png
# ./Dataset/reference-890\563.png
# PSNR for 563.png: 26.52
# ./results\563_img_.png
# ./Dataset/reference-890\563_img_.png
# PSNR for 563_img_.png: 11.37
# ./results\564_img_.png
# ./Dataset/reference-890\564_img_.png
# PSNR for 564_img_.png: 14.19
# ./results\566_img_.png
# ./Dataset/reference-890\566_img_.png
# PSNR for 566_img_.png: 21.38
# ./results\567.png
# ./Dataset/reference-890\567.png
# PSNR for 567.png: 23.11
# ./results\567_img_.png
# ./Dataset/reference-890\567_img_.png
# PSNR for 567_img_.png: 14.55
# ./results\568_img_.png
# ./Dataset/reference-890\568_img_.png
# PSNR for 568_img_.png: 15.13
# ./results\569_img_.png
# ./Dataset/reference-890\569_img_.png
# PSNR for 569_img_.png: 13.35
# ./results\56_img_.png
# ./Dataset/reference-890\56_img_.png
# PSNR for 56_img_.png: 22.44
# ./results\570_img_.png
# ./Dataset/reference-890\570_img_.png
# PSNR for 570_img_.png: 17.69
# ./results\571_img_.png
# ./Dataset/reference-890\571_img_.png
# PSNR for 571_img_.png: 19.60
# ./results\572_img_.png
# ./Dataset/reference-890\572_img_.png
# PSNR for 572_img_.png: 24.66
# ./results\573_img_.png
# ./Dataset/reference-890\573_img_.png
# PSNR for 573_img_.png: 15.53
# ./results\574_img_.png
# ./Dataset/reference-890\574_img_.png
# PSNR for 574_img_.png: 12.77
# ./results\575_img_.png
# ./Dataset/reference-890\575_img_.png
# PSNR for 575_img_.png: 14.54
# ./results\576_img_.png
# ./Dataset/reference-890\576_img_.png
# PSNR for 576_img_.png: 14.02
# ./results\577_img_.png
# ./Dataset/reference-890\577_img_.png
# PSNR for 577_img_.png: 14.01
# ./results\578_img_.png
# ./Dataset/reference-890\578_img_.png
# PSNR for 578_img_.png: 22.33
# ./results\579_img_.png
# ./Dataset/reference-890\579_img_.png
# PSNR for 579_img_.png: 15.84
# ./results\57_img_.png
# ./Dataset/reference-890\57_img_.png
# PSNR for 57_img_.png: 15.74
# ./results\580_img_.png
# ./Dataset/reference-890\580_img_.png
# PSNR for 580_img_.png: 15.26
# ./results\5818.png
# ./Dataset/reference-890\5818.png
# PSNR for 5818.png: 19.98
# ./results\581_img_.png
# ./Dataset/reference-890\581_img_.png
# PSNR for 581_img_.png: 17.12
# ./results\582_img_.png
# ./Dataset/reference-890\582_img_.png
# PSNR for 582_img_.png: 16.95
# ./results\5830.png
# ./Dataset/reference-890\5830.png
# PSNR for 5830.png: 21.83
# ./results\583_img_.png
# ./Dataset/reference-890\583_img_.png
# PSNR for 583_img_.png: 25.09
# ./results\584_img_.png
# ./Dataset/reference-890\584_img_.png
# PSNR for 584_img_.png: 18.48
# ./results\585_img_.png
# ./Dataset/reference-890\585_img_.png
# PSNR for 585_img_.png: 20.67
# ./results\586_img_.png
# ./Dataset/reference-890\586_img_.png
# PSNR for 586_img_.png: 20.75
# ./results\587_img_.png
# ./Dataset/reference-890\587_img_.png
# PSNR for 587_img_.png: 20.29
# ./results\588_img_.png
# ./Dataset/reference-890\588_img_.png
# PSNR for 588_img_.png: 17.20
# ./results\589_img_.png
# ./Dataset/reference-890\589_img_.png
# PSNR for 589_img_.png: 15.07
# ./results\58_img_.png
# ./Dataset/reference-890\58_img_.png
# PSNR for 58_img_.png: 17.77
# ./results\590_img_.png
# ./Dataset/reference-890\590_img_.png
# PSNR for 590_img_.png: 16.83
# ./results\591_img_.png
# ./Dataset/reference-890\591_img_.png
# PSNR for 591_img_.png: 16.04
# ./results\592_img_.png
# ./Dataset/reference-890\592_img_.png
# PSNR for 592_img_.png: 24.58
# ./results\593_img_.png
# ./Dataset/reference-890\593_img_.png
# PSNR for 593_img_.png: 16.06
# ./results\594_img_.png
# ./Dataset/reference-890\594_img_.png
# PSNR for 594_img_.png: 16.66
# ./results\595_img_.png
# ./Dataset/reference-890\595_img_.png
# PSNR for 595_img_.png: 15.19
# ./results\596_img_.png
# ./Dataset/reference-890\596_img_.png
# PSNR for 596_img_.png: 16.35
# ./results\597_img_.png
# ./Dataset/reference-890\597_img_.png
# PSNR for 597_img_.png: 22.57
# ./results\598.png
# ./Dataset/reference-890\598.png
# PSNR for 598.png: 25.47
# ./results\598_img_.png
# ./Dataset/reference-890\598_img_.png
# PSNR for 598_img_.png: 14.71
# ./results\599_img_.png
# ./Dataset/reference-890\599_img_.png
# PSNR for 599_img_.png: 17.22
# ./results\59_img_.png
# ./Dataset/reference-890\59_img_.png
# PSNR for 59_img_.png: 19.83
# ./results\600_img_.png
# ./Dataset/reference-890\600_img_.png
# PSNR for 600_img_.png: 21.60
# ./results\601_img_.png
# ./Dataset/reference-890\601_img_.png
# PSNR for 601_img_.png: 17.27
# ./results\602_img_.png
# ./Dataset/reference-890\602_img_.png
# PSNR for 602_img_.png: 20.13
# ./results\603_img_.png
# ./Dataset/reference-890\603_img_.png
# PSNR for 603_img_.png: 19.95
# ./results\604_img_.png
# ./Dataset/reference-890\604_img_.png
# PSNR for 604_img_.png: 25.78
# ./results\605_img_.png
# ./Dataset/reference-890\605_img_.png
# PSNR for 605_img_.png: 19.06
# ./results\6062.png
# ./Dataset/reference-890\6062.png
# PSNR for 6062.png: 21.71
# ./results\606_img_.png
# ./Dataset/reference-890\606_img_.png
# PSNR for 606_img_.png: 19.56
# ./results\607_img_.png
# ./Dataset/reference-890\607_img_.png
# PSNR for 607_img_.png: 15.24
# ./results\6082.png
# ./Dataset/reference-890\6082.png
# PSNR for 6082.png: 20.17
# ./results\608_img_.png
# ...
# ./results\760_img_.png
# ./Dataset/reference-890\760_img_.png
# PSNR for 760_img_.png: 14.37
# ./results\762_img_.png
# ./Dataset/reference-890\762_img_.png
# PSNR for 762_img_.png: 14.00
# ./results\763_img_.png
# ./Dataset/reference-890\763_img_.png
# PSNR for 763_img_.png: 17.89
# ./results\7643.png
# ./Dataset/reference-890\7643.png
# PSNR for 7643.png: 11.72
# ./results\764_img_.png
# ./Dataset/reference-890\764_img_.png
# PSNR for 764_img_.png: 16.05
# ./results\7654.png
# ./Dataset/reference-890\7654.png
# PSNR for 7654.png: 10.68
# ./results\765_img_.png
# ./Dataset/reference-890\765_img_.png
# PSNR for 765_img_.png: 17.33
# ./results\766_img_.png
# ./Dataset/reference-890\766_img_.png
# PSNR for 766_img_.png: 16.50
# ./results\767_img_.png
# ./Dataset/reference-890\767_img_.png
# PSNR for 767_img_.png: 21.55
# ./results\768_img_.png
# ./Dataset/reference-890\768_img_.png
# PSNR for 768_img_.png: 13.43
# ./results\769_img_.png
# ./Dataset/reference-890\769_img_.png
# PSNR for 769_img_.png: 12.34
# ./results\76_img_.png
# ./Dataset/reference-890\76_img_.png
# PSNR for 76_img_.png: 18.44
# ./results\770_img_.png
# ./Dataset/reference-890\770_img_.png
# PSNR for 770_img_.png: 19.92
# ./results\771_img_.png
# ./Dataset/reference-890\771_img_.png
# PSNR for 771_img_.png: 20.34
# ./results\772_img_.png
# ./Dataset/reference-890\772_img_.png
# PSNR for 772_img_.png: 24.95
# ./results\773_img_.png
# ./Dataset/reference-890\773_img_.png
# PSNR for 773_img_.png: 20.83
# ./results\775_img_.png
# ./Dataset/reference-890\775_img_.png
# PSNR for 775_img_.png: 27.29
# ./results\776_img_.png
# ./Dataset/reference-890\776_img_.png
# PSNR for 776_img_.png: 19.92
# ./results\777_img_.png
# ./Dataset/reference-890\777_img_.png
# PSNR for 777_img_.png: 20.81
# ./results\778_img_.png
# ./Dataset/reference-890\778_img_.png
# PSNR for 778_img_.png: 20.34
# ./results\779_img_.png
# ./Dataset/reference-890\779_img_.png
# PSNR for 779_img_.png: 20.23
# ./results\77_img_.png
# ./Dataset/reference-890\77_img_.png
# PSNR for 77_img_.png: 14.49
# ./results\780_img_.png
# ./Dataset/reference-890\780_img_.png
# PSNR for 780_img_.png: 17.17
# ./results\781_img_.png
# ./Dataset/reference-890\781_img_.png
# PSNR for 781_img_.png: 20.29
# ./results\782_img_.png
# ./Dataset/reference-890\782_img_.png
# PSNR for 782_img_.png: 27.03
# ./results\783_img_.png
# ./Dataset/reference-890\783_img_.png
# PSNR for 783_img_.png: 19.01
# ./results\784_img_.png
# ./Dataset/reference-890\784_img_.png
# PSNR for 784_img_.png: 23.39
# ./results\785_img_.png
# ./Dataset/reference-890\785_img_.png
# PSNR for 785_img_.png: 16.73
# ./results\786_img_.png
# ./Dataset/reference-890\786_img_.png
# PSNR for 786_img_.png: 9.51
# ./results\787_img_.png
# ./Dataset/reference-890\787_img_.png
# PSNR for 787_img_.png: 20.10
# ./results\788_img_.png
# ./Dataset/reference-890\788_img_.png
# PSNR for 788_img_.png: 24.78
# ./results\789_img_.png
# ./Dataset/reference-890\789_img_.png
# PSNR for 789_img_.png: 18.50
# ./results\78_img_.png
# ./Dataset/reference-890\78_img_.png
# PSNR for 78_img_.png: 15.01
# ./results\790_img_.png
# ./Dataset/reference-890\790_img_.png
# PSNR for 790_img_.png: 18.06
# ./results\7916.png
# ./Dataset/reference-890\7916.png
# PSNR for 7916.png: 13.27
# ./results\791_img_.png
# ./Dataset/reference-890\791_img_.png
# PSNR for 791_img_.png: 22.93
# ./results\792_img_.png
# ./Dataset/reference-890\792_img_.png
# PSNR for 792_img_.png: 25.74
# ./results\793_img_.png
# ./Dataset/reference-890\793_img_.png
# PSNR for 793_img_.png: 23.36
# ./results\794_img_.png
# ./Dataset/reference-890\794_img_.png
# PSNR for 794_img_.png: 28.81
# ./results\795_img_.png
# ./Dataset/reference-890\795_img_.png
# PSNR for 795_img_.png: 24.63
# ./results\796_img_.png
# ./Dataset/reference-890\796_img_.png
# PSNR for 796_img_.png: 18.60
# ./results\797_img_.png
# ./Dataset/reference-890\797_img_.png
# PSNR for 797_img_.png: 25.29
# ./results\798_img_.png
# ./Dataset/reference-890\798_img_.png
# PSNR for 798_img_.png: 17.21
# ./results\799_img_.png
# ./Dataset/reference-890\799_img_.png
# PSNR for 799_img_.png: 24.61
# ./results\79_img_.png
# ./Dataset/reference-890\79_img_.png
# PSNR for 79_img_.png: 23.24
# ./results\7_img_.png
# ./Dataset/reference-890\7_img_.png
# PSNR for 7_img_.png: 18.82
# ./results\800_img_.png
# ./Dataset/reference-890\800_img_.png
# PSNR for 800_img_.png: 22.34
# ./results\8010.png
# ./Dataset/reference-890\8010.png
# PSNR for 8010.png: 13.19
# ./results\802_img_.png
# ./Dataset/reference-890\802_img_.png
# PSNR for 802_img_.png: 25.86
# ./results\803_img_.png
# ./Dataset/reference-890\803_img_.png
# PSNR for 803_img_.png: 19.40
# ./results\8046.png
# ./Dataset/reference-890\8046.png
# PSNR for 8046.png: 11.68
# ./results\804_img_.png
# ./Dataset/reference-890\804_img_.png
# PSNR for 804_img_.png: 24.57
# ./results\8056.png
# ./Dataset/reference-890\8056.png
# PSNR for 8056.png: 12.48
# ./results\806_img_.png
# ./Dataset/reference-890\806_img_.png
# PSNR for 806_img_.png: 23.97
# ./results\807_img_.png
# ./Dataset/reference-890\807_img_.png
# PSNR for 807_img_.png: 19.86
# ./results\808_img_.png
# ./Dataset/reference-890\808_img_.png
# PSNR for 808_img_.png: 15.46
# ./results\809_img_.png
# ./Dataset/reference-890\809_img_.png
# PSNR for 809_img_.png: 25.26
# ./results\80_img_.png
# ./Dataset/reference-890\80_img_.png
# PSNR for 80_img_.png: 21.87
# ./results\810_img_.png
# ./Dataset/reference-890\810_img_.png
# PSNR for 810_img_.png: 19.66
# ./results\811_img_.png
# ./Dataset/reference-890\811_img_.png
# PSNR for 811_img_.png: 14.87
# ./results\812_img_.png
# ./Dataset/reference-890\812_img_.png
# PSNR for 812_img_.png: 15.98
# ./results\813_img_.png
# ./Dataset/reference-890\813_img_.png
# PSNR for 813_img_.png: 16.55
# ./results\814_img_.png
# ./Dataset/reference-890\814_img_.png
# PSNR for 814_img_.png: 18.44
# ./results\815_img_.png
# ./Dataset/reference-890\815_img_.png
# PSNR for 815_img_.png: 27.75
# ./results\816_img_.png
# ./Dataset/reference-890\816_img_.png
# PSNR for 816_img_.png: 23.36
# ./results\817_img_.png
# ./Dataset/reference-890\817_img_.png
# PSNR for 817_img_.png: 17.11
# ./results\818_img_.png
# ./Dataset/reference-890\818_img_.png
# PSNR for 818_img_.png: 27.57
# ./results\819_img_.png
# ./Dataset/reference-890\819_img_.png
# PSNR for 819_img_.png: 16.60
# ./results\820_img_.png
# ./Dataset/reference-890\820_img_.png
# PSNR for 820_img_.png: 22.05
# ./results\821_img_.png
# ./Dataset/reference-890\821_img_.png
# PSNR for 821_img_.png: 20.01
# ./results\822_img_.png
# ./Dataset/reference-890\822_img_.png
# PSNR for 822_img_.png: 12.17
# ./results\823_img_.png
# ./Dataset/reference-890\823_img_.png
# PSNR for 823_img_.png: 24.31
# ./results\8262.png
# ./Dataset/reference-890\8262.png
# PSNR for 8262.png: 12.60
# ./results\827_img_.png
# ./Dataset/reference-890\827_img_.png
# PSNR for 827_img_.png: 26.36
# ./results\8288.png
# ./Dataset/reference-890\8288.png
# PSNR for 8288.png: 10.04
# ./results\828_img_.png
# ./Dataset/reference-890\828_img_.png
# PSNR for 828_img_.png: 28.42
# ./results\829_img_.png
# ./Dataset/reference-890\829_img_.png
# PSNR for 829_img_.png: 22.25
# ./results\82_img_.png
# ./Dataset/reference-890\82_img_.png
# PSNR for 82_img_.png: 26.75
# ./results\831_img_.png
# ./Dataset/reference-890\831_img_.png
# PSNR for 831_img_.png: 21.58
# ./results\832_img_.png
# ./Dataset/reference-890\832_img_.png
# PSNR for 832_img_.png: 25.13
# ./results\833_img_.png
# ./Dataset/reference-890\833_img_.png
# PSNR for 833_img_.png: 22.38
# ./results\834_img_.png
# ./Dataset/reference-890\834_img_.png
# PSNR for 834_img_.png: 15.80
# ./results\835_img_.png
# ./Dataset/reference-890\835_img_.png
# PSNR for 835_img_.png: 26.60
# ./results\837.png
# ./Dataset/reference-890\837.png
# PSNR for 837.png: 17.66
# ./results\837_img_.png
# ./Dataset/reference-890\837_img_.png
# PSNR for 837_img_.png: 24.15
# ./results\838_img_.png
# ./Dataset/reference-890\838_img_.png
# PSNR for 838_img_.png: 20.33
# ./results\841.png
# ./Dataset/reference-890\841.png
# PSNR for 841.png: 20.55
# ./results\841_img_.png
# ./Dataset/reference-890\841_img_.png
# PSNR for 841_img_.png: 17.01
# ./results\842_img_.png
# ./Dataset/reference-890\842_img_.png
# PSNR for 842_img_.png: 23.08
# ./results\843_img_.png
# ./Dataset/reference-890\843_img_.png
# PSNR for 843_img_.png: 25.03
# ./results\844_img_.png
# ./Dataset/reference-890\844_img_.png
# PSNR for 844_img_.png: 19.96
# ./results\845_img_.png
# ./Dataset/reference-890\845_img_.png
# PSNR for 845_img_.png: 20.42
# ./results\846_img_.png
# ./Dataset/reference-890\846_img_.png
# PSNR for 846_img_.png: 20.32
# ./results\847_img_.png
# ./Dataset/reference-890\847_img_.png
# PSNR for 847_img_.png: 16.09
# ./results\848_img_.png
# ./Dataset/reference-890\848_img_.png
# PSNR for 848_img_.png: 17.61
# ./results\849_img_.png
# ./Dataset/reference-890\849_img_.png
# PSNR for 849_img_.png: 23.57
# ./results\850_img_.png
# ./Dataset/reference-890\850_img_.png
# PSNR for 850_img_.png: 15.80
# ./results\851_img_.png
# ./Dataset/reference-890\851_img_.png
# PSNR for 851_img_.png: 22.23
# ./results\852_img_.png
# ./Dataset/reference-890\852_img_.png
# PSNR for 852_img_.png: 16.21
# ./results\854_img_.png
# ./Dataset/reference-890\854_img_.png
# PSNR for 854_img_.png: 17.72
# ./results\855_img_.png
# ./Dataset/reference-890\855_img_.png
# PSNR for 855_img_.png: 19.37
# ./results\856_img_.png
# ./Dataset/reference-890\856_img_.png
# PSNR for 856_img_.png: 16.40
# ./results\857_img_.png
# ./Dataset/reference-890\857_img_.png
# PSNR for 857_img_.png: 15.94
# ./results\858_img_.png
# ./Dataset/reference-890\858_img_.png
# PSNR for 858_img_.png: 27.69
# ./results\859_img_.png
# ./Dataset/reference-890\859_img_.png
# PSNR for 859_img_.png: 16.71
# ./results\860_img_.png
# ./Dataset/reference-890\860_img_.png
# PSNR for 860_img_.png: 15.09
# ./results\861_img_.png
# ./Dataset/reference-890\861_img_.png
# PSNR for 861_img_.png: 13.75
# ./results\862_img_.png
# ./Dataset/reference-890\862_img_.png
# PSNR for 862_img_.png: 13.65
# ./results\863_img_.png
# ./Dataset/reference-890\863_img_.png
# PSNR for 863_img_.png: 27.11
# ./results\865_img_.png
# ./Dataset/reference-890\865_img_.png
# PSNR for 865_img_.png: 12.00
# ./results\866_img_.png
# ./Dataset/reference-890\866_img_.png
# PSNR for 866_img_.png: 20.23
# ./results\867_img_.png
# ./Dataset/reference-890\867_img_.png
# PSNR for 867_img_.png: 14.46
# ./results\868_img_.png
# ./Dataset/reference-890\868_img_.png
# PSNR for 868_img_.png: 17.72
# ./results\869_img_.png
# ./Dataset/reference-890\869_img_.png
# PSNR for 869_img_.png: 14.20
# ./results\86_img_.png
# ./Dataset/reference-890\86_img_.png
# PSNR for 86_img_.png: 18.58
# ./results\871_img_.png
# ./Dataset/reference-890\871_img_.png
# PSNR for 871_img_.png: 13.93
# ./results\872_img_.png
# ./Dataset/reference-890\872_img_.png
# PSNR for 872_img_.png: 13.17
# ./results\873_img_.png
# ./Dataset/reference-890\873_img_.png
# PSNR for 873_img_.png: 15.91
# ./results\874_img_.png
# ./Dataset/reference-890\874_img_.png
# PSNR for 874_img_.png: 15.97
# ./results\875_img_.png
# ./Dataset/reference-890\875_img_.png
# PSNR for 875_img_.png: 30.52
# ./results\876_img_.png
# ./Dataset/reference-890\876_img_.png
# PSNR for 876_img_.png: 29.38
# ./results\877_img_.png
# ./Dataset/reference-890\877_img_.png
# PSNR for 877_img_.png: 15.37
# ./results\878_img_.png
# ./Dataset/reference-890\878_img_.png
# PSNR for 878_img_.png: 15.68
# ./results\879_img_.png
# ./Dataset/reference-890\879_img_.png
# PSNR for 879_img_.png: 14.48
# ./results\87_img_.png
# ./Dataset/reference-890\87_img_.png
# PSNR for 87_img_.png: 19.27
# ./results\880_img_.png
# ./Dataset/reference-890\880_img_.png
# PSNR for 880_img_.png: 21.48
# ./results\881_img_.png
# ./Dataset/reference-890\881_img_.png
# PSNR for 881_img_.png: 12.19
# ./results\887_img_.png
# ./Dataset/reference-890\887_img_.png
# PSNR for 887_img_.png: 15.59
# ./results\889_img_.png
# ./Dataset/reference-890\889_img_.png
# PSNR for 889_img_.png: 25.24
# ./results\890.png
# ./Dataset/reference-890\890.png
# PSNR for 890.png: 17.08
# ./results\890_img_.png
# ./Dataset/reference-890\890_img_.png
# PSNR for 890_img_.png: 26.94
# ./results\891_img_.png
# ./Dataset/reference-890\891_img_.png
# PSNR for 891_img_.png: 18.25
# ./results\892_img_.png
# ./Dataset/reference-890\892_img_.png
# PSNR for 892_img_.png: 20.42
# ./results\893_img_.png
# ./Dataset/reference-890\893_img_.png
# PSNR for 893_img_.png: 11.86
# ./results\895_img_.png
# ./Dataset/reference-890\895_img_.png
# PSNR for 895_img_.png: 12.26
# ./results\896_img_.png
# ./Dataset/reference-890\896_img_.png
# PSNR for 896_img_.png: 20.41
# ./results\89_img_.png
# ./Dataset/reference-890\89_img_.png
# PSNR for 89_img_.png: 21.95
# ./results\8_img_.png
# ./Dataset/reference-890\8_img_.png
# PSNR for 8_img_.png: 13.14
# ./results\901_img_.png
# ./Dataset/reference-890\901_img_.png
# PSNR for 901_img_.png: 14.15
# ./results\904_img_.png
# ./Dataset/reference-890\904_img_.png
# PSNR for 904_img_.png: 15.54
# ./results\905_img_.png
# ./Dataset/reference-890\905_img_.png
# PSNR for 905_img_.png: 13.93
# ./results\906_img_.png
# ./Dataset/reference-890\906_img_.png
# PSNR for 906_img_.png: 14.74
# ./results\907_img_.png
# ./Dataset/reference-890\907_img_.png
# PSNR for 907_img_.png: 20.29
# ./results\908_img_.png
# ./Dataset/reference-890\908_img_.png
# PSNR for 908_img_.png: 22.04
# ./results\909_img_.png
# ./Dataset/reference-890\909_img_.png
# PSNR for 909_img_.png: 13.96
# ./results\90_img_.png
# ./Dataset/reference-890\90_img_.png
# PSNR for 90_img_.png: 20.03
# ./results\910_img_.png
# ./Dataset/reference-890\910_img_.png
# PSNR for 910_img_.png: 10.71
# ./results\911_img_.png
# ./Dataset/reference-890\911_img_.png
# PSNR for 911_img_.png: 20.31
# ./results\912_img_.png
# ./Dataset/reference-890\912_img_.png
# PSNR for 912_img_.png: 19.68
# ./results\913_img_.png
# ./Dataset/reference-890\913_img_.png
# PSNR for 913_img_.png: 16.23
# ./results\914_img_.png
# ./Dataset/reference-890\914_img_.png
# PSNR for 914_img_.png: 15.01
# ./results\915_img_.png
# ./Dataset/reference-890\915_img_.png
# PSNR for 915_img_.png: 17.11
# ./results\916_img_.png
# ./Dataset/reference-890\916_img_.png
# PSNR for 916_img_.png: 20.61
# ./results\917_img_.png
# ./Dataset/reference-890\917_img_.png
# PSNR for 917_img_.png: 19.65
# ./results\918_img_.png
# ./Dataset/reference-890\918_img_.png
# PSNR for 918_img_.png: 25.74
# ./results\919_img_.png
# ./Dataset/reference-890\919_img_.png
# PSNR for 919_img_.png: 20.67
# ./results\91_img_.png
# ./Dataset/reference-890\91_img_.png
# PSNR for 91_img_.png: 13.35
# ./results\920_img_.png
# ./Dataset/reference-890\920_img_.png
# PSNR for 920_img_.png: 26.52
# ./results\921_img_.png
# ./Dataset/reference-890\921_img_.png
# PSNR for 921_img_.png: 18.47
# ./results\922_img_.png
# ./Dataset/reference-890\922_img_.png
# PSNR for 922_img_.png: 22.91
# ./results\923_img_.png
# ./Dataset/reference-890\923_img_.png
# PSNR for 923_img_.png: 17.90
# ./results\924_img_.png
# ./Dataset/reference-890\924_img_.png
# PSNR for 924_img_.png: 12.19
# ./results\925_img_.png
# ./Dataset/reference-890\925_img_.png
# PSNR for 925_img_.png: 23.55
# ./results\926_img_.png
# ./Dataset/reference-890\926_img_.png
# PSNR for 926_img_.png: 20.70
# ./results\927_img_.png
# ./Dataset/reference-890\927_img_.png
# PSNR for 927_img_.png: 16.31
# ./results\928_img_.png
# ./Dataset/reference-890\928_img_.png
# PSNR for 928_img_.png: 21.37
# ./results\929_img_.png
# ./Dataset/reference-890\929_img_.png
# PSNR for 929_img_.png: 22.18
# ./results\92_img_.png
# ./Dataset/reference-890\92_img_.png
# PSNR for 92_img_.png: 22.73
# ./results\94_img_.png
# ./Dataset/reference-890\94_img_.png
# PSNR for 94_img_.png: 22.51
# ./results\9547.png
# ./Dataset/reference-890\9547.png
# PSNR for 9547.png: 18.86
# ./results\9554.png
# ./Dataset/reference-890\9554.png
# PSNR for 9554.png: 20.38
# ./results\9557.png
# ./Dataset/reference-890\9557.png
# PSNR for 9557.png: 19.89
# ./results\9567.png
# ./Dataset/reference-890\9567.png
# PSNR for 9567.png: 20.87
# ./results\95_img_.png
# ./Dataset/reference-890\95_img_.png
# PSNR for 95_img_.png: 21.30
# ./results\96_img_.png
# ./Dataset/reference-890\96_img_.png
# PSNR for 96_img_.png: 22.34
# ./results\97_img_.png
# ./Dataset/reference-890\97_img_.png
# PSNR for 97_img_.png: 19.35
# ./results\9896.png
# ./Dataset/reference-890\9896.png
# PSNR for 9896.png: 19.81
# ./results\98_img_.png
# ./Dataset/reference-890\98_img_.png
# PSNR for 98_img_.png: 24.02
# ./results\9900.png
# ./Dataset/reference-890\9900.png
# PSNR for 9900.png: 18.03
# ./results\9907.png
# ./Dataset/reference-890\9907.png
# PSNR for 9907.png: 17.35
# ./results\9947.png
# ./Dataset/reference-890\9947.png
# PSNR for 9947.png: 20.81
# ./results\99_img_.png
# ./Dataset/reference-890\99_img_.png
# PSNR for 99_img_.png: 22.71
# ./results\9_img_.png
# ./Dataset/reference-890\9_img_.png
# PSNR for 9_img_.png: 18.80
# Overall PSNR: 19.18

# %%
from skimage.metrics import peak_signal_noise_ratio
import cv2
import os


# Method 2: Skimage library
def main(processed_folder, ground_reference):
    processed_images = os.listdir(processed_folder)
    total_psnr = 0
    num_images = 0
    for processed_image in processed_images:
        processed_path = os.path.join(processed_folder, processed_image)
        reference_path = os.path.join(ground_reference, processed_image)
        # print(processed_path)
        # print(reference_path)
        processed_img = cv2.imread(processed_path)
        reference_img = cv2.imread(reference_path)
        psnr = peak_signal_noise_ratio(reference_img, processed_img)
        total_psnr += psnr
        num_images += 1
        print(f"PSNR for {processed_image}: {psnr:.2f}")

    overall_psnr = total_psnr / num_images
    print(f"Overall PSNR: {overall_psnr:.2f}")


if __name__ == "__main__":
    # processed_folder = "./OutputImages"
    processed_folder = "./results"
    ground_reference = "./Dataset/reference-890"
    main(processed_folder, ground_reference)
# Out:
# PSNR for 100_img_.png: 15.78
# PSNR for 10139.png: 23.38
# PSNR for 10151.png: 25.08
# PSNR for 101_img_.png: 19.93
# PSNR for 102_img_.png: 15.00
# PSNR for 104_img_.png: 18.56
# PSNR for 105_img_.png: 15.86
# PSNR for 106_img_.png: 29.99
# PSNR for 107_img_.png: 17.02
# PSNR for 108_img_.png: 31.22
# PSNR for 10909.png: 20.78
# PSNR for 10945.png: 17.51
# PSNR for 109_img_.png: 13.01
# PSNR for 10_img_.png: 11.07
# PSNR for 11052.png: 20.46
# PSNR for 11064.png: 21.71
# PSNR for 111_img_.png: 18.46
# PSNR for 112_img_.png: 19.30
# PSNR for 11374.png: 20.39
# PSNR for 11398.png: 22.06
# PSNR for 113_img_.png: 17.27
# PSNR for 114_img_.png: 12.90
# PSNR for 115_img_.png: 20.32
# PSNR for 116_img_.png: 15.89
# PSNR for 117_img_.png: 20.58
# PSNR for 118_img_.png: 24.30
# PSNR for 11_img_.png: 25.24
# PSNR for 120_img_.png: 18.97
# PSNR for 121_img_.png: 21.47
# PSNR for 1225.png: 19.43
# PSNR for 12290.png: 9.47
# PSNR for 12299.png: 12.05
# PSNR for 122_img_.png: 21.93
# PSNR for 12324.png: 10.74
# PSNR for 12336.png: 21.53
# PSNR for 12348.png: 11.29
# PSNR for 123_img_.png: 22.15
# PSNR for 12422.png: 21.59
# PSNR for 12433.png: 16.51
# PSNR for 12445.png: 16.62
# PSNR for 124_img_.png: 25.62
# PSNR for 125_img_.png: 23.14
# PSNR for 12900.png: 16.87
# PSNR for 129_img_.png: 11.21
# PSNR for 130_img_.png: 20.99
# PSNR for 131_img_.png: 19.07
# PSNR for 133_img_.png: 19.86
# PSNR for 135_img_.png: 21.89
# PSNR for 136_img_.png: 23.82
# PSNR for 137_img_.png: 20.18
# PSNR for 138_img_.png: 21.69
# PSNR for 139_img_.png: 9.43
# PSNR for 13_img_.png: 21.71
# PSNR for 1407.png: 22.58
# PSNR for 140_img_.png: 17.36
# PSNR for 141_img_.png: 16.66
# PSNR for 142_img_.png: 9.52
# PSNR for 143_img_.png: 14.48
# PSNR for 144_img_.png: 19.53
# PSNR for 145_img_.png: 19.95
# PSNR for 146_img_.png: 13.56
# PSNR for 148_img_.png: 18.68
# PSNR for 1491.png: 16.87
# PSNR for 149_img_.png: 17.25
# PSNR for 14_img_.png: 18.09
# PSNR for 15001.png: 18.61
# PSNR for 15003.png: 16.83
# PSNR for 15045.png: 20.55
# PSNR for 15094.png: 20.44
# PSNR for 150_img_.png: 24.00
# PSNR for 15113.png: 15.99
# PSNR for 15136.png: 28.01
# PSNR for 151_img_.png: 22.39
# PSNR for 152_img_.png: 20.65
# PSNR for 1539.png: 19.70
# PSNR for 153_img_.png: 20.21
# PSNR for 15418.png: 18.90
# PSNR for 15426.png: 19.38
# PSNR for 154_img_.png: 19.59
# PSNR for 15544.png: 16.82
# PSNR for 155_img_.png: 24.43
# PSNR for 156_img_.png: 21.22
# PSNR for 15704.png: 14.69
# PSNR for 1573.png: 16.71
# PSNR for 157_img_.png: 28.59
# PSNR for 158_img_.png: 20.84
# PSNR for 159_img_.png: 17.69
# PSNR for 15_img_.png: 19.33
# PSNR for 160_img_.png: 17.15
# PSNR for 161_img_.png: 23.89
# PSNR for 162_img_.png: 19.98
# PSNR for 163_img_.png: 25.41
# PSNR for 164_img_.png: 21.43
# PSNR for 165_img_.png: 19.52
# PSNR for 1660.png: 16.61
# PSNR for 166_img_.png: 15.69
# PSNR for 168_img_.png: 11.99
# PSNR for 169_img_.png: 16.59
# PSNR for 16_img_.png: 17.40
# PSNR for 170_img_.png: 14.08
# PSNR for 171_img_.png: 12.94
# PSNR for 172_img_.png: 17.56
# PSNR for 173_img_.png: 20.18
# PSNR for 1742.png: 20.13
# PSNR for 174_img_.png: 14.38
# PSNR for 175_img_.png: 18.82
# PSNR for 176_img_.png: 19.65
# PSNR for 177_img_.png: 19.23
# PSNR for 178_img_.png: 18.48
# PSNR for 179_img_.png: 27.79
# PSNR for 17_img_.png: 18.30
# PSNR for 180_img_.png: 17.98
# PSNR for 182_img_.png: 18.64
# PSNR for 183_img_.png: 17.27
# PSNR for 184_img_.png: 20.25
# PSNR for 185_img_.png: 21.17
# PSNR for 186_img_.png: 19.67
# PSNR for 187_img_.png: 19.61
# PSNR for 188_img_.png: 17.92
# PSNR for 189_img_.png: 13.76
# PSNR for 18_img_.png: 13.52
# PSNR for 190_img_.png: 21.21
# PSNR for 191_img_.png: 10.98
# PSNR for 192_img_.png: 16.65
# PSNR for 193_img_.png: 21.21
# PSNR for 194_img_.png: 19.44
# PSNR for 1957.png: 19.41
# PSNR for 195_img_.png: 24.81
# PSNR for 196_img_.png: 23.64
# PSNR for 197_img_.png: 21.33
# PSNR for 198_img_.png: 24.05
# PSNR for 199_img_.png: 18.00
# PSNR for 19_img_.png: 14.94
# PSNR for 20.png: 21.00
# PSNR for 200_img_.png: 16.63
# PSNR for 201_img_.png: 25.67
# PSNR for 202_img_.png: 15.23
# PSNR for 203_img_.png: 27.90
# PSNR for 204_img_.png: 17.25
# PSNR for 205_img_.png: 20.06
# PSNR for 206_img_.png: 19.51
# PSNR for 207_img_.png: 27.10
# PSNR for 208_img_.png: 29.42
# PSNR for 209_img_.png: 26.56
# PSNR for 210_img_.png: 28.46
# PSNR for 211_img_.png: 19.95
# PSNR for 212_img_.png: 21.90
# PSNR for 213_img_.png: 20.37
# PSNR for 214_img_.png: 21.40
# PSNR for 215_img_.png: 22.23
# PSNR for 216_img_.png: 21.25
# PSNR for 217_img_.png: 19.63
# PSNR for 219_img_.png: 17.15
# PSNR for 220_img_.png: 19.38
# PSNR for 221_img_.png: 20.60
# PSNR for 222_img_.png: 17.97
# PSNR for 223_img_.png: 22.59
# PSNR for 224_img_.png: 22.47
# PSNR for 225_img_.png: 16.85
# PSNR for 226_img_.png: 18.26
# PSNR for 227_img_.png: 14.84
# PSNR for 228_img_.png: 14.52
# PSNR for 229_img_.png: 18.79
# PSNR for 22_img_.png: 19.39
# PSNR for 230_img_.png: 26.89
# PSNR for 231_img_.png: 20.56
# PSNR for 232_img_.png: 19.94
# PSNR for 233_img_.png: 19.94
# PSNR for 234_img_.png: 18.19
# PSNR for 236_img_.png: 19.02
# PSNR for 238_img_.png: 16.99
# PSNR for 23_img_.png: 20.29
# PSNR for 240_img_.png: 21.67
# PSNR for 241_img_.png: 18.17
# PSNR for 242_img_.png: 23.37
# PSNR for 243_img_.png: 18.80
# PSNR for 244_img_.png: 20.19
# PSNR for 245_img_.png: 20.46
# PSNR for 246_img_.png: 21.65
# PSNR for 247_img_.png: 20.19
# PSNR for 248_img_.png: 18.92
# PSNR for 24_img_.png: 18.96
# PSNR for 251_img_.png: 22.49
# PSNR for 252_img_.png: 17.70
# PSNR for 253_img_.png: 19.96
# PSNR for 2546.png: 27.18
# PSNR for 254_img_.png: 18.69
# PSNR for 255_img_.png: 17.84
# PSNR for 257_img_.png: 27.06
# PSNR for 258_img_.png: 15.46
# PSNR for 259_img_.png: 18.48
# PSNR for 25_img_.png: 20.70
# PSNR for 260_img_.png: 19.66
# PSNR for 261_img_.png: 21.72
# PSNR for 2629.png: 17.88
# PSNR for 262_img_.png: 19.56
# PSNR for 263_img_.png: 16.05
# PSNR for 265_img_.png: 17.89
# PSNR for 266_img_.png: 18.95
# PSNR for 2677.png: 15.77
# PSNR for 267_img_.png: 21.15
# PSNR for 268_img_.png: 17.34
# PSNR for 26_img_.png: 21.09
# PSNR for 2701.png: 13.67
# PSNR for 270_img_.png: 17.48
# PSNR for 271_img_.png: 19.21
# PSNR for 272_img_.png: 20.86
# PSNR for 273_img_.png: 21.37
# PSNR for 274_img_.png: 14.91
# PSNR for 275_img_.png: 19.10
# PSNR for 276_img_.png: 19.02
# PSNR for 2774.png: 20.11
# PSNR for 277_img_.png: 20.55
# PSNR for 2787.png: 22.16
# PSNR for 278_img_.png: 21.47
# PSNR for 279_img_.png: 14.97
# PSNR for 27_img_.png: 21.06
# PSNR for 280_img_.png: 21.31
# PSNR for 281_img_.png: 18.45
# PSNR for 282_img_.png: 20.74
# PSNR for 284_img_.png: 20.15
# PSNR for 285_img_.png: 19.39
# PSNR for 287_img_.png: 18.21
# PSNR for 2882.png: 18.34
# PSNR for 288_img_.png: 17.76
# PSNR for 28_img_.png: 20.95
# PSNR for 290_img_.png: 21.37
# PSNR for 292_img_.png: 25.01
# PSNR for 293_img_.png: 15.35
# PSNR for 294_img_.png: 19.65
# PSNR for 295_img_.png: 17.29
# PSNR for 296_img_.png: 24.81
# PSNR for 2977.png: 14.71
# PSNR for 298_img_.png: 16.14
# PSNR for 299_img_.png: 20.27
# PSNR for 29_img_.png: 23.86
# PSNR for 2_img_.png: 21.54
# PSNR for 3001.png: 20.42
# PSNR for 300_img_.png: 16.76
# PSNR for 3015.png: 21.43
# PSNR for 301_img_.png: 17.36
# PSNR for 302_img_.png: 17.59
# PSNR for 303_img_.png: 25.98
# PSNR for 304_img_.png: 20.18
# PSNR for 305_img_.png: 19.69
# PSNR for 306_img_.png: 21.76
# PSNR for 307_img_.png: 16.96
# PSNR for 30_img_.png: 15.50
# PSNR for 31.png: 21.04
# PSNR for 311_img_.png: 19.35
# PSNR for 312_img_.png: 24.18
# PSNR for 313_img_.png: 19.96
# PSNR for 314_img_.png: 21.76
# PSNR for 315_img_.png: 16.57
# PSNR for 316_img_.png: 17.04
# PSNR for 317_img_.png: 17.17
# PSNR for 318_img_.png: 28.46
# PSNR for 3196.png: 21.34
# PSNR for 319_img_.png: 14.80
# PSNR for 3202.png: 22.71
# PSNR for 320_img_.png: 21.16
# PSNR for 322_img_.png: 11.61
# PSNR for 323_img_.png: 18.92
# PSNR for 324_img_.png: 19.91
# PSNR for 325_img_.png: 12.95
# PSNR for 326_img_.png: 14.77
# PSNR for 327_img_.png: 22.06
# PSNR for 328_img_.png: 22.17
# PSNR for 32_img_.png: 17.61
# PSNR for 330_img_.png: 17.28
# PSNR for 332_img_.png: 28.07
# PSNR for 3330.png: 18.38
# PSNR for 334_img_.png: 15.83
# PSNR for 336_img_.png: 21.02
# PSNR for 337_img_.png: 20.69
# PSNR for 338_img_.png: 20.45
# PSNR for 340_img_.png: 20.37
# PSNR for 341_img_.png: 19.81
# PSNR for 342_img_.png: 14.02
# PSNR for 343_img_.png: 26.33
# PSNR for 345_img_.png: 19.74
# PSNR for 346_img_.png: 21.40
# PSNR for 347_img_.png: 17.92
# PSNR for 348_img_.png: 13.46
# PSNR for 35.png: 21.77
# PSNR for 350_img_.png: 21.85
# PSNR for 351_img_.png: 25.57
# PSNR for 353_img_.png: 14.01
# PSNR for 355_img_.png: 22.40
# PSNR for 356_img_.png: 13.05
# PSNR for 359_img_.png: 20.39
# PSNR for 360_img_.png: 15.39
# PSNR for 361_img_.png: 16.70
# PSNR for 362_img_.png: 18.35
# PSNR for 363_img_.png: 20.63
# PSNR for 364_img_.png: 21.32
# PSNR for 3650.png: 22.92
# PSNR for 365_img_.png: 15.65
# PSNR for 366_img_.png: 21.18
# PSNR for 367_img_.png: 14.60
# PSNR for 369_img_.png: 26.59
# PSNR for 370_img_.png: 25.15
# PSNR for 371_img_.png: 16.90
# PSNR for 3728.png: 22.01
# PSNR for 372_img_.png: 15.04
# PSNR for 373_img_.png: 23.92
# PSNR for 374_img_.png: 12.86
# PSNR for 375_img_.png: 21.23
# PSNR for 376_img_.png: 18.93
# PSNR for 377_img_.png: 17.84
# PSNR for 378_img_.png: 20.95
# PSNR for 379_img_.png: 15.12
# PSNR for 37_img_.png: 17.74
# PSNR for 380_img_.png: 15.36
# PSNR for 381_img_.png: 14.96
# PSNR for 382_img_.png: 15.93
# PSNR for 383_img_.png: 19.11
# PSNR for 384_img_.png: 17.53
# PSNR for 385_img_.png: 12.10
# PSNR for 386_img_.png: 30.52
# PSNR for 387_img_.png: 20.85
# PSNR for 389_img_.png: 13.12
# PSNR for 391_img_.png: 13.85
# PSNR for 3925.png: 22.41
# PSNR for 392_img_.png: 14.49
# PSNR for 393_img_.png: 17.94
# PSNR for 3947.png: 24.75
# PSNR for 394_img_.png: 18.17
# PSNR for 395_img_.png: 22.51
# PSNR for 39_img_.png: 20.07
# PSNR for 3_img_.png: 21.63
# PSNR for 4.png: 17.39
# PSNR for 400_img_.png: 19.79
# PSNR for 401_img_.png: 20.20
# PSNR for 402_img_.png: 18.89
# PSNR for 403_img_.png: 15.49
# PSNR for 404_img_.png: 16.03
# PSNR for 405_img_.png: 11.48
# PSNR for 406_img_.png: 17.16
# PSNR for 4070.png: 29.18
# PSNR for 407_img_.png: 10.38
# PSNR for 408_img_.png: 25.40
# PSNR for 409_img_.png: 16.91
# PSNR for 410_img_.png: 16.32
# PSNR for 411_img_.png: 19.18
# PSNR for 412_img_.png: 17.75
# PSNR for 413_img_.png: 14.89
# PSNR for 415_img_.png: 20.94
# PSNR for 416_img_.png: 20.74
# PSNR for 417_img_.png: 17.23
# PSNR for 418_img_.png: 16.63
# PSNR for 419_img_.png: 18.19
# PSNR for 41_img_.png: 15.79
# PSNR for 420_img_.png: 17.09
# PSNR for 421_img_.png: 21.53
# PSNR for 422_img_.png: 19.73
# PSNR for 423_img_.png: 17.75
# PSNR for 424_img_.png: 22.60
# PSNR for 425_img_.png: 21.79
# PSNR for 428_img_.png: 20.63
# PSNR for 429_img_.png: 20.73
# PSNR for 42_img_.png: 13.65
# PSNR for 432_img_.png: 19.21
# PSNR for 433_img_.png: 17.70
# PSNR for 435_img_.png: 16.78
# PSNR for 436_img_.png: 23.09
# PSNR for 437_img_.png: 20.70
# PSNR for 438_img_.png: 9.84
# PSNR for 439_img_.png: 26.91
# PSNR for 43_img_.png: 21.36
# PSNR for 440_img_.png: 13.21
# PSNR for 441_img_.png: 13.59
# PSNR for 442_img_.png: 15.68
# PSNR for 443_img_.png: 14.25
# PSNR for 444_img_.png: 20.41
# PSNR for 445_img_.png: 19.48
# PSNR for 446_img_.png: 14.74
# PSNR for 447_img_.png: 15.72
# PSNR for 448_img_.png: 21.00
# PSNR for 449_img_.png: 19.83
# PSNR for 44_img_.png: 16.43
# PSNR for 450_img_.png: 21.89
# PSNR for 451_img_.png: 21.30
# PSNR for 452_img_.png: 19.12
# PSNR for 453_img_.png: 22.12
# PSNR for 454_img_.png: 17.64
# PSNR for 455_img_.png: 16.96
# PSNR for 457_img_.png: 17.48
# PSNR for 458_img_.png: 24.53
# PSNR for 459_img_.png: 12.80
# PSNR for 45_img_.png: 17.30
# PSNR for 460_img_.png: 21.65
# PSNR for 461_img_.png: 19.41
# PSNR for 462_img_.png: 19.41
# PSNR for 463_img_.png: 21.22
# PSNR for 464_img_.png: 18.57
# PSNR for 465_img_.png: 18.87
# PSNR for 466_img_.png: 15.75
# PSNR for 467_img_.png: 18.60
# PSNR for 468_img_.png: 19.90
# PSNR for 469_img_.png: 21.00
# PSNR for 46_img_.png: 22.43
# PSNR for 470_img_.png: 13.11
# PSNR for 471_img_.png: 20.46
# PSNR for 472_img_.png: 16.45
# PSNR for 473_img_.png: 19.42
# PSNR for 476_img_.png: 21.22
# PSNR for 477_img_.png: 19.65
# PSNR for 478_img_.png: 18.31
# PSNR for 479_img_.png: 19.41
# PSNR for 480_img_.png: 15.72
# PSNR for 481_img_.png: 18.54
# PSNR for 482_img_.png: 16.07
# PSNR for 483_img_.png: 20.30
# PSNR for 484_img_.png: 18.48
# PSNR for 485_img_.png: 19.60
# PSNR for 486_img_.png: 17.03
# PSNR for 487_img_.png: 18.00
# PSNR for 488_img_.png: 20.95
# PSNR for 489_img_.png: 20.53
# PSNR for 48_img_.png: 25.59
# PSNR for 490_img_.png: 13.42
# PSNR for 491_img_.png: 19.50
# PSNR for 492_img_.png: 22.68
# PSNR for 493_img_.png: 19.75
# PSNR for 494_img_.png: 18.23
# PSNR for 495_img_.png: 18.45
# PSNR for 496_img_.png: 14.63
# PSNR for 497_img_.png: 16.03
# PSNR for 498_img_.png: 16.35
# PSNR for 499_img_.png: 17.89
# PSNR for 49_img_.png: 20.03
# PSNR for 4_img_.png: 25.23
# PSNR for 501_img_.png: 17.67
# PSNR for 502_img_.png: 21.46
# PSNR for 503_img_.png: 19.26
# PSNR for 504_img_.png: 18.48
# PSNR for 505_img_.png: 19.41
# PSNR for 506_img_.png: 23.35
# PSNR for 507_img_.png: 30.85
# PSNR for 508_img_.png: 16.80
# PSNR for 509_img_.png: 19.92
# PSNR for 50_img_.png: 20.14
# PSNR for 510_img_.png: 17.08
# PSNR for 511_img_.png: 20.89
# PSNR for 512_img_.png: 24.05
# PSNR for 513_img_.png: 18.17
# PSNR for 515_img_.png: 17.49
# PSNR for 516_img_.png: 20.66
# PSNR for 517_img_.png: 23.17
# PSNR for 518_img_.png: 11.01
# PSNR for 519_img_.png: 13.91
# PSNR for 51_img_.png: 19.77
# PSNR for 524_img_.png: 16.27
# PSNR for 526_img_.png: 12.44
# PSNR for 527_img_.png: 17.72
# PSNR for 528_img_.png: 10.72
# PSNR for 52_img_.png: 17.42
# PSNR for 530_img_.png: 19.93
# PSNR for 531_img_.png: 31.31
# PSNR for 532_img_.png: 16.18
# PSNR for 533_img_.png: 16.24
# PSNR for 534_img_.png: 16.05
# PSNR for 535_img_.png: 13.00
# PSNR for 536_img_.png: 21.87
# PSNR for 537_img_.png: 21.34
# PSNR for 538_img_.png: 18.46
# PSNR for 539.png: 17.80
# PSNR for 539_img_.png: 16.63
# PSNR for 53_img_.png: 12.90
# PSNR for 540_img_.png: 19.78
# PSNR for 541_img_.png: 18.62
# PSNR for 542_img_.png: 14.23
# PSNR for 543_img_.png: 15.53
# PSNR for 544_img_.png: 10.94
# PSNR for 545_img_.png: 12.64
# PSNR for 546_img_.png: 15.47
# PSNR for 547_img_.png: 21.64
# PSNR for 549_img_.png: 15.99
# PSNR for 550_img_.png: 18.31
# PSNR for 551_img_.png: 15.17
# PSNR for 552_img_.png: 18.88
# PSNR for 554_img_.png: 21.17
# PSNR for 5554.png: 22.26
# PSNR for 555_img_.png: 12.11
# PSNR for 556_img_.png: 16.54
# PSNR for 557.png: 21.49
# PSNR for 557_img_.png: 15.92
# PSNR for 558_img_.png: 16.61
# PSNR for 559.png: 16.52
# PSNR for 55_img_.png: 20.50
# PSNR for 560_img_.png: 21.11
# PSNR for 561_img_.png: 21.09
# PSNR for 562_img_.png: 16.88
# PSNR for 563.png: 26.52
# PSNR for 563_img_.png: 11.37
# PSNR for 564_img_.png: 14.19
# PSNR for 566_img_.png: 21.38
# PSNR for 567.png: 23.11
# PSNR for 567_img_.png: 14.55
# PSNR for 568_img_.png: 15.13
# PSNR for 569_img_.png: 13.35
# PSNR for 56_img_.png: 22.44
# PSNR for 570_img_.png: 17.69
# PSNR for 571_img_.png: 19.60
# PSNR for 572_img_.png: 24.66
# PSNR for 573_img_.png: 15.53
# PSNR for 574_img_.png: 12.77
# PSNR for 575_img_.png: 14.54
# PSNR for 576_img_.png: 14.02
# PSNR for 577_img_.png: 14.01
# PSNR for 578_img_.png: 22.33
# PSNR for 579_img_.png: 15.84
# PSNR for 57_img_.png: 15.74
# PSNR for 580_img_.png: 15.26
# PSNR for 5818.png: 19.98
# PSNR for 581_img_.png: 17.12
# PSNR for 582_img_.png: 16.95
# PSNR for 5830.png: 21.83
# PSNR for 583_img_.png: 25.09
# PSNR for 584_img_.png: 18.48
# PSNR for 585_img_.png: 20.67
# PSNR for 586_img_.png: 20.75
# PSNR for 587_img_.png: 20.29
# PSNR for 588_img_.png: 17.20
# PSNR for 589_img_.png: 15.07
# PSNR for 58_img_.png: 17.77
# PSNR for 590_img_.png: 16.83
# PSNR for 591_img_.png: 16.04
# PSNR for 592_img_.png: 24.58
# PSNR for 593_img_.png: 16.06
# PSNR for 594_img_.png: 16.66
# PSNR for 595_img_.png: 15.19
# PSNR for 596_img_.png: 16.35
# PSNR for 597_img_.png: 22.57
# PSNR for 598.png: 25.47
# PSNR for 598_img_.png: 14.71
# PSNR for 599_img_.png: 17.22
# PSNR for 59_img_.png: 19.83
# PSNR for 600_img_.png: 21.60
# PSNR for 601_img_.png: 17.27
# PSNR for 602_img_.png: 20.13
# PSNR for 603_img_.png: 19.95
# PSNR for 604_img_.png: 25.78
# PSNR for 605_img_.png: 19.06
# PSNR for 6062.png: 21.71
# PSNR for 606_img_.png: 19.56
# PSNR for 607_img_.png: 15.24
# PSNR for 6082.png: 20.17
# PSNR for 608_img_.png: 17.88
# PSNR for 609_img_.png: 16.89
# PSNR for 60_img_.png: 19.77
# PSNR for 610_img_.png: 27.30
# PSNR for 611_img_.png: 23.65
# PSNR for 612_img_.png: 22.86
# PSNR for 613_img_.png: 17.56
# PSNR for 614_img_.png: 17.58
# PSNR for 615_img_.png: 15.33
# PSNR for 616_img_.png: 26.79
# PSNR for 617_img_.png: 16.50
# PSNR for 618_img_.png: 31.39
# PSNR for 619_img_.png: 24.99
# PSNR for 61_img_.png: 12.89
# PSNR for 620_img_.png: 20.47
# PSNR for 621_img_.png: 20.02
# PSNR for 622_img_.png: 21.79
# PSNR for 623_img_.png: 19.55
# PSNR for 625_img_.png: 15.37
# PSNR for 626_img_.png: 19.66
# PSNR for 627_img_.png: 17.26
# PSNR for 628_img_.png: 22.83
# PSNR for 629_img_.png: 25.49
# PSNR for 62_img_.png: 18.35
# PSNR for 630_img_.png: 28.03
# PSNR for 631_img_.png: 23.29
# PSNR for 632_img_.png: 20.78
# PSNR for 633_img_.png: 19.45
# PSNR for 634_img_.png: 21.08
# PSNR for 635_img_.png: 20.42
# PSNR for 636_img_.png: 17.74
# PSNR for 637_img_.png: 17.45
# PSNR for 638_img_.png: 18.94
# PSNR for 639_img_.png: 33.85
# PSNR for 63_img_.png: 22.35
# PSNR for 640_img_.png: 17.53
# PSNR for 641_img_.png: 19.03
# PSNR for 642_img_.png: 25.11
# PSNR for 645_img_.png: 16.73
# PSNR for 646_img_.png: 17.98
# PSNR for 647_img_.png: 24.71
# PSNR for 648_img_.png: 23.13
# PSNR for 649_img_.png: 19.83
# PSNR for 64_img_.png: 22.17
# PSNR for 650_img_.png: 16.04
# PSNR for 651.png: 17.35
# PSNR for 651_img_.png: 23.25
# PSNR for 652_img_.png: 17.64
# PSNR for 653_img_.png: 19.18
# PSNR for 654_img_.png: 11.25
# PSNR for 655_img_.png: 13.89
# PSNR for 656_img_.png: 17.56
# PSNR for 657_img_.png: 15.66
# PSNR for 658_img_.png: 16.17
# PSNR for 659_img_.png: 15.21
# PSNR for 65_img_.png: 22.73
# PSNR for 660_img_.png: 27.83
# PSNR for 661_img_.png: 22.46
# PSNR for 662_img_.png: 24.94
# PSNR for 663_img_.png: 15.27
# PSNR for 666_img_.png: 19.10
# PSNR for 668_img_.png: 13.40
# PSNR for 670_img_.png: 16.65
# PSNR for 672_img_.png: 17.17
# PSNR for 673_img_.png: 16.69
# PSNR for 674_img_.png: 20.75
# PSNR for 675_img_.png: 22.68
# PSNR for 676_img_.png: 17.98
# PSNR for 677_img_.png: 21.04
# PSNR for 6788.png: 10.79
# PSNR for 678_img_.png: 18.30
# PSNR for 679_img_.png: 20.41
# PSNR for 67_img_.png: 20.90
# PSNR for 680_img_.png: 20.71
# PSNR for 681_img_.png: 19.28
# PSNR for 6820.png: 16.26
# PSNR for 682_img_.png: 20.45
# PSNR for 683_img_.png: 14.88
# PSNR for 684_img_.png: 19.08
# PSNR for 685_img_.png: 15.26
# PSNR for 686_img_.png: 14.60
# PSNR for 6872.png: 12.89
# PSNR for 687_img_.png: 19.60
# PSNR for 688_img_.png: 15.02
# PSNR for 689_img_.png: 14.11
# PSNR for 690_img_.png: 14.82
# PSNR for 691_img_.png: 21.51
# PSNR for 692_img_.png: 23.57
# PSNR for 694_img_.png: 17.64
# PSNR for 695_img_.png: 19.40
# PSNR for 696_img_.png: 15.45
# PSNR for 697_img_.png: 13.93
# PSNR for 698_img_.png: 24.20
# PSNR for 699_img_.png: 23.90
# PSNR for 6_img_.png: 16.45
# PSNR for 700_img_.png: 21.19
# PSNR for 701_img_.png: 9.51
# PSNR for 7027.png: 12.53
# PSNR for 702_img_.png: 20.60
# PSNR for 703_img_.png: 24.34
# PSNR for 704_img_.png: 15.95
# PSNR for 705_img_.png: 28.64
# PSNR for 706_img_.png: 15.97
# PSNR for 707_img_.png: 19.23
# PSNR for 708_img_.png: 22.25
# PSNR for 709_img_.png: 22.27
# PSNR for 70_img_.png: 16.59
# PSNR for 710_img_.png: 28.13
# PSNR for 711_img_.png: 15.62
# PSNR for 712_img_.png: 18.19
# PSNR for 713_img_.png: 19.10
# PSNR for 714_img_.png: 21.58
# PSNR for 715_img_.png: 16.75
# PSNR for 716_img_.png: 16.97
# PSNR for 718_img_.png: 17.03
# PSNR for 719_img_.png: 11.78
# PSNR for 720_img_.png: 17.59
# PSNR for 721_img_.png: 21.16
# PSNR for 722_img_.png: 23.06
# PSNR for 723_img_.png: 18.57
# PSNR for 724_img_.png: 17.36
# PSNR for 725_img_.png: 28.16
# PSNR for 726_img_.png: 16.92
# PSNR for 727_img_.png: 25.18
# PSNR for 728_img_.png: 23.88
# PSNR for 729_img_.png: 29.89
# PSNR for 72_img_.png: 19.42
# PSNR for 730_img_.png: 23.15
# PSNR for 731_img_.png: 23.54
# PSNR for 732_img_.png: 21.89
# PSNR for 733_img_.png: 16.21
# PSNR for 734_img_.png: 13.31
# PSNR for 735_img_.png: 20.79
# PSNR for 736_img_.png: 20.30
# PSNR for 737_img_.png: 18.61
# PSNR for 738_img_.png: 15.15
# PSNR for 73_img_.png: 19.44
# PSNR for 740_img_.png: 19.10
# PSNR for 741_img_.png: 23.74
# PSNR for 743_img_.png: 18.16
# PSNR for 744_img_.png: 22.67
# PSNR for 745_img_.png: 17.19
# PSNR for 746_img_.png: 18.84
# PSNR for 747_img_.png: 20.17
# PSNR for 748_img_.png: 18.44
# PSNR for 749_img_.png: 23.87
# PSNR for 74_img_.png: 18.40
# PSNR for 750_img_.png: 21.20
# PSNR for 751_img_.png: 19.72
# PSNR for 752_img_.png: 18.79
# PSNR for 753_img_.png: 18.61
# PSNR for 754_img_.png: 19.34
# PSNR for 756.png: 15.91
# PSNR for 756_img_.png: 30.90
# PSNR for 757_img_.png: 18.77
# PSNR for 758.png: 15.09
# PSNR for 758_img_.png: 23.57
# PSNR for 759_img_.png: 20.66
# PSNR for 760_img_.png: 14.37
# PSNR for 762_img_.png: 14.00
# PSNR for 763_img_.png: 17.89
# PSNR for 7643.png: 11.72
# PSNR for 764_img_.png: 16.05
# PSNR for 7654.png: 10.68
# PSNR for 765_img_.png: 17.33
# PSNR for 766_img_.png: 16.50
# PSNR for 767_img_.png: 21.55
# PSNR for 768_img_.png: 13.43
# PSNR for 769_img_.png: 12.34
# PSNR for 76_img_.png: 18.44
# PSNR for 770_img_.png: 19.92
# PSNR for 771_img_.png: 20.34
# PSNR for 772_img_.png: 24.95
# PSNR for 773_img_.png: 20.83
# PSNR for 775_img_.png: 27.29
# PSNR for 776_img_.png: 19.92
# PSNR for 777_img_.png: 20.81
# PSNR for 778_img_.png: 20.34
# PSNR for 779_img_.png: 20.23
# PSNR for 77_img_.png: 14.49
# PSNR for 780_img_.png: 17.17
# PSNR for 781_img_.png: 20.29
# PSNR for 782_img_.png: 27.03
# PSNR for 783_img_.png: 19.01
# PSNR for 784_img_.png: 23.39
# PSNR for 785_img_.png: 16.73
# PSNR for 786_img_.png: 9.51
# PSNR for 787_img_.png: 20.10
# PSNR for 788_img_.png: 24.78
# PSNR for 789_img_.png: 18.50
# PSNR for 78_img_.png: 15.01
# PSNR for 790_img_.png: 18.06
# PSNR for 7916.png: 13.27
# PSNR for 791_img_.png: 22.93
# PSNR for 792_img_.png: 25.74
# PSNR for 793_img_.png: 23.36
# PSNR for 794_img_.png: 28.81
# PSNR for 795_img_.png: 24.63
# PSNR for 796_img_.png: 18.60
# PSNR for 797_img_.png: 25.29
# PSNR for 798_img_.png: 17.21
# PSNR for 799_img_.png: 24.61
# PSNR for 79_img_.png: 23.24
# PSNR for 7_img_.png: 18.82
# PSNR for 800_img_.png: 22.34
# PSNR for 8010.png: 13.19
# PSNR for 802_img_.png: 25.86
# PSNR for 803_img_.png: 19.40
# PSNR for 8046.png: 11.68
# PSNR for 804_img_.png: 24.57
# PSNR for 8056.png: 12.48
# PSNR for 806_img_.png: 23.97
# PSNR for 807_img_.png: 19.86
# PSNR for 808_img_.png: 15.46
# PSNR for 809_img_.png: 25.26
# PSNR for 80_img_.png: 21.87
# PSNR for 810_img_.png: 19.66
# PSNR for 811_img_.png: 14.87
# PSNR for 812_img_.png: 15.98
# PSNR for 813_img_.png: 16.55
# PSNR for 814_img_.png: 18.44
# PSNR for 815_img_.png: 27.75
# PSNR for 816_img_.png: 23.36
# PSNR for 817_img_.png: 17.11
# PSNR for 818_img_.png: 27.57
# PSNR for 819_img_.png: 16.60
# PSNR for 820_img_.png: 22.05
# PSNR for 821_img_.png: 20.01
# PSNR for 822_img_.png: 12.17
# PSNR for 823_img_.png: 24.31
# PSNR for 8262.png: 12.60
# PSNR for 827_img_.png: 26.36
# PSNR for 8288.png: 10.04
# PSNR for 828_img_.png: 28.42
# PSNR for 829_img_.png: 22.25
# PSNR for 82_img_.png: 26.75
# PSNR for 831_img_.png: 21.58
# PSNR for 832_img_.png: 25.13
# PSNR for 833_img_.png: 22.38
# PSNR for 834_img_.png: 15.80
# PSNR for 835_img_.png: 26.60
# PSNR for 837.png: 17.66
# PSNR for 837_img_.png: 24.15
# PSNR for 838_img_.png: 20.33
# PSNR for 841.png: 20.55
# PSNR for 841_img_.png: 17.01
# PSNR for 842_img_.png: 23.08
# PSNR for 843_img_.png: 25.03
# PSNR for 844_img_.png: 19.96
# PSNR for 845_img_.png: 20.42
# PSNR for 846_img_.png: 20.32
# PSNR for 847_img_.png: 16.09
# PSNR for 848_img_.png: 17.61
# PSNR for 849_img_.png: 23.57
# PSNR for 850_img_.png: 15.80
# PSNR for 851_img_.png: 22.23
# PSNR for 852_img_.png: 16.21
# PSNR for 854_img_.png: 17.72
# PSNR for 855_img_.png: 19.37
# PSNR for 856_img_.png: 16.40
# PSNR for 857_img_.png: 15.94
# PSNR for 858_img_.png: 27.69
# PSNR for 859_img_.png: 16.71
# PSNR for 860_img_.png: 15.09
# PSNR for 861_img_.png: 13.75
# PSNR for 862_img_.png: 13.65
# PSNR for 863_img_.png: 27.11
# PSNR for 865_img_.png: 12.00
# PSNR for 866_img_.png: 20.23
# PSNR for 867_img_.png: 14.46
# PSNR for 868_img_.png: 17.72
# PSNR for 869_img_.png: 14.20
# PSNR for 86_img_.png: 18.58
# PSNR for 871_img_.png: 13.93
# PSNR for 872_img_.png: 13.17
# PSNR for 873_img_.png: 15.91
# PSNR for 874_img_.png: 15.97
# PSNR for 875_img_.png: 30.52
# PSNR for 876_img_.png: 29.38
# PSNR for 877_img_.png: 15.37
# PSNR for 878_img_.png: 15.68
# PSNR for 879_img_.png: 14.48
# PSNR for 87_img_.png: 19.27
# PSNR for 880_img_.png: 21.48
# PSNR for 881_img_.png: 12.19
# PSNR for 887_img_.png: 15.59
# PSNR for 889_img_.png: 25.24
# PSNR for 890.png: 17.08
# PSNR for 890_img_.png: 26.94
# PSNR for 891_img_.png: 18.25
# PSNR for 892_img_.png: 20.42
# PSNR for 893_img_.png: 11.86
# PSNR for 895_img_.png: 12.26
# PSNR for 896_img_.png: 20.41
# PSNR for 89_img_.png: 21.95
# PSNR for 8_img_.png: 13.14
# PSNR for 901_img_.png: 14.15
# PSNR for 904_img_.png: 15.54
# PSNR for 905_img_.png: 13.93
# PSNR for 906_img_.png: 14.74
# PSNR for 907_img_.png: 20.29
# PSNR for 908_img_.png: 22.04
# PSNR for 909_img_.png: 13.96
# PSNR for 90_img_.png: 20.03
# PSNR for 910_img_.png: 10.71
# PSNR for 911_img_.png: 20.31
# PSNR for 912_img_.png: 19.68
# PSNR for 913_img_.png: 16.23
# PSNR for 914_img_.png: 15.01
# PSNR for 915_img_.png: 17.11
# PSNR for 916_img_.png: 20.61
# PSNR for 917_img_.png: 19.65
# PSNR for 918_img_.png: 25.74
# PSNR for 919_img_.png: 20.67
# PSNR for 91_img_.png: 13.35
# PSNR for 920_img_.png: 26.52
# PSNR for 921_img_.png: 18.47
# PSNR for 922_img_.png: 22.91
# PSNR for 923_img_.png: 17.90
# PSNR for 924_img_.png: 12.19
# PSNR for 925_img_.png: 23.55
# PSNR for 926_img_.png: 20.70
# PSNR for 927_img_.png: 16.31
# PSNR for 928_img_.png: 21.37
# PSNR for 929_img_.png: 22.18
# PSNR for 92_img_.png: 22.73
# PSNR for 94_img_.png: 22.51
# PSNR for 9547.png: 18.86
# PSNR for 9554.png: 20.38
# PSNR for 9557.png: 19.89
# PSNR for 9567.png: 20.87
# PSNR for 95_img_.png: 21.30
# PSNR for 96_img_.png: 22.34
# PSNR for 97_img_.png: 19.35
# PSNR for 9896.png: 19.81
# PSNR for 98_img_.png: 24.02
# PSNR for 9900.png: 18.03
# PSNR for 9907.png: 17.35
# PSNR for 9947.png: 20.81
# PSNR for 99_img_.png: 22.71
# PSNR for 9_img_.png: 18.80
# Overall PSNR: 19.18

# %%
# using formula
# reference https://medium.com/@jaikochhar06/how-to-evaluate-image-quality-in-python-a-comprehensive-guide-e486a0aa1f60#:~:text=The%20following%204%20evaluation%20metrics,Spectral%20Angle%20Mapper%20(SAM)

import os
import cv2
import numpy as np


def getPSNR(I1, I2):
    s1 = cv2.absdiff(I1, I2)
    s1 = np.float32(s1)
    s1 = s1 * s1
    sse = s1.sum()
    if sse <= 1e-10:
        return 0
    else:
        shape = I1.shape
        mse = 1.0 * sse / (shape[0] * shape[1] * shape[2])
        psnr = 10.0 * np.log10((255 * 255) / mse)
        return psnr


def main(processed_folder, ground_reference):
    processed_images = os.listdir(processed_folder)
    total_psnr = 0
    num_images = 0
    for processed_image in processed_images:
        processed_path = os.path.join(processed_folder, processed_image)
        reference_path = os.path.join(ground_reference, processed_image)
        processed_img = cv2.imread(processed_path)
        reference_img = cv2.imread(reference_path)
        psnr = getPSNR(reference_img, processed_img)
        total_psnr += psnr
        num_images += 1
        # print(f"PSNR for {processed_image}: {psnr:.2f}")
    overall_psnr = total_psnr / num_images
    print(f"Overall PSNR: {overall_psnr:.2f}")


if __name__ == "__main__":
    # processed_folder = "./OutputImages"
    processed_folder = "./results"
    ground_reference = "./Dataset/reference-890"
    main(processed_folder, ground_reference)
# Out:
# Overall PSNR: 19.18

# %% [markdown]
# SSIM
# Same image: ouput=1
# Totally different image output=0

# %%
from skimage.metrics import structural_similarity as ssim
import cv2
import os


def main(processed_folder, ground_reference):
    processed_images = os.listdir(processed_folder)
    total_ssim = 0
    num_images = 0
    for processed_image in processed_images:
        processed_path = os.path.join(processed_folder, processed_image)
        reference_path = os.path.join(ground_reference, processed_image)
        print(processed_path)
        print(reference_path)
        processed_img = cv2.imread(processed_path)
        reference_img = cv2.imread(reference_path)
        ssim_value = ssim(reference_img, processed_img, channel_axis=2)
        total_ssim += ssim_value
        num_images += 1
        print(f"SSIM for {processed_image}: {ssim_value:.4f}")

    overall_ssim = total_ssim / num_images
    print(f"Overall SSIM: {overall_ssim:.4f}")


if __name__ == "__main__":
    # processed_folder = "./OutputImages"
    processed_folder = "./results"
    ground_reference = "./Dataset/reference-890"
    main(processed_folder, ground_reference)
# Out:
# ./results\100_img_.png
# ./Dataset/reference-890\100_img_.png
# SSIM for 100_img_.png: 0.7994
# ./results\10139.png
# ./Dataset/reference-890\10139.png
# SSIM for 10139.png: 0.7979
# ./results\10151.png
# ./Dataset/reference-890\10151.png
# SSIM for 10151.png: 0.9160
# ./results\101_img_.png
# ./Dataset/reference-890\101_img_.png
# SSIM for 101_img_.png: 0.8904
# ./results\102_img_.png
# ./Dataset/reference-890\102_img_.png
# SSIM for 102_img_.png: 0.7509
# ./results\104_img_.png
# ./Dataset/reference-890\104_img_.png
# SSIM for 104_img_.png: 0.7510
# ./results\105_img_.png
# ./Dataset/reference-890\105_img_.png
# SSIM for 105_img_.png: 0.7763
# ./results\106_img_.png
# ./Dataset/reference-890\106_img_.png
# SSIM for 106_img_.png: 0.9402
# ./results\107_img_.png
# ./Dataset/reference-890\107_img_.png
# SSIM for 107_img_.png: 0.6635
# ./results\108_img_.png
# ./Dataset/reference-890\108_img_.png
# SSIM for 108_img_.png: 0.9780
# ./results\10909.png
# ./Dataset/reference-890\10909.png
# SSIM for 10909.png: 0.8548
# ./results\10945.png
# ./Dataset/reference-890\10945.png
# SSIM for 10945.png: 0.8160
# ./results\109_img_.png
# ./Dataset/reference-890\109_img_.png
# SSIM for 109_img_.png: 0.6695
# ./results\10_img_.png
# ./Dataset/reference-890\10_img_.png
# SSIM for 10_img_.png: 0.5591
# ./results\11052.png
# ./Dataset/reference-890\11052.png
# SSIM for 11052.png: 0.8538
# ./results\11064.png
# ./Dataset/reference-890\11064.png
# SSIM for 11064.png: 0.8370
# ./results\111_img_.png
# ./Dataset/reference-890\111_img_.png
# SSIM for 111_img_.png: 0.6333
# ./results\112_img_.png
# ./Dataset/reference-890\112_img_.png
# SSIM for 112_img_.png: 0.8673
# ./results\11374.png
# ./Dataset/reference-890\11374.png
# SSIM for 11374.png: 0.9031
# ./results\11398.png
# ./Dataset/reference-890\11398.png
# SSIM for 11398.png: 0.8538
# ./results\113_img_.png
# ./Dataset/reference-890\113_img_.png
# SSIM for 113_img_.png: 0.6494
# ./results\114_img_.png
# ./Dataset/reference-890\114_img_.png
# SSIM for 114_img_.png: 0.6020
# ./results\115_img_.png
# ./Dataset/reference-890\115_img_.png
# SSIM for 115_img_.png: 0.8720
# ./results\116_img_.png
# ./Dataset/reference-890\116_img_.png
# SSIM for 116_img_.png: 0.7868
# ./results\117_img_.png
# ./Dataset/reference-890\117_img_.png
# SSIM for 117_img_.png: 0.9057
# ./results\118_img_.png
# ./Dataset/reference-890\118_img_.png
# SSIM for 118_img_.png: 0.9200
# ./results\11_img_.png
# ./Dataset/reference-890\11_img_.png
# SSIM for 11_img_.png: 0.8034
# ./results\120_img_.png
# ./Dataset/reference-890\120_img_.png
# SSIM for 120_img_.png: 0.8137
# ./results\121_img_.png
# ./Dataset/reference-890\121_img_.png
# SSIM for 121_img_.png: 0.8810
# ./results\1225.png
# ./Dataset/reference-890\1225.png
# SSIM for 1225.png: 0.8673
# ./results\12290.png
# ./Dataset/reference-890\12290.png
# SSIM for 12290.png: 0.3546
# ./results\12299.png
# ./Dataset/reference-890\12299.png
# SSIM for 12299.png: 0.6203
# ./results\122_img_.png
# ./Dataset/reference-890\122_img_.png
# SSIM for 122_img_.png: 0.8865
# ./results\12324.png
# ./Dataset/reference-890\12324.png
# SSIM for 12324.png: 0.5155
# ./results\12336.png
# ./Dataset/reference-890\12336.png
# SSIM for 12336.png: 0.9029
# ./results\12348.png
# ./Dataset/reference-890\12348.png
# SSIM for 12348.png: 0.5120
# ./results\123_img_.png
# ./Dataset/reference-890\123_img_.png
# SSIM for 123_img_.png: 0.9380
# ./results\12422.png
# ./Dataset/reference-890\12422.png
# SSIM for 12422.png: 0.9424
# ./results\12433.png
# ./Dataset/reference-890\12433.png
# SSIM for 12433.png: 0.7156
# ./results\12445.png
# ./Dataset/reference-890\12445.png
# SSIM for 12445.png: 0.7997
# ./results\124_img_.png
# ./Dataset/reference-890\124_img_.png
# SSIM for 124_img_.png: 0.9011
# ./results\125_img_.png
# ./Dataset/reference-890\125_img_.png
# SSIM for 125_img_.png: 0.9348
# ./results\12900.png
# ./Dataset/reference-890\12900.png
# SSIM for 12900.png: 0.7879
# ./results\129_img_.png
# ./Dataset/reference-890\129_img_.png
# SSIM for 129_img_.png: 0.6389
# ./results\130_img_.png
# ./Dataset/reference-890\130_img_.png
# SSIM for 130_img_.png: 0.8663
# ./results\131_img_.png
# ./Dataset/reference-890\131_img_.png
# SSIM for 131_img_.png: 0.7890
# ./results\133_img_.png
# ./Dataset/reference-890\133_img_.png
# SSIM for 133_img_.png: 0.8889
# ./results\135_img_.png
# ./Dataset/reference-890\135_img_.png
# SSIM for 135_img_.png: 0.8716
# ./results\136_img_.png
# ./Dataset/reference-890\136_img_.png
# SSIM for 136_img_.png: 0.9255
# ./results\137_img_.png
# ./Dataset/reference-890\137_img_.png
# SSIM for 137_img_.png: 0.9087
# ./results\138_img_.png
# ./Dataset/reference-890\138_img_.png
# SSIM for 138_img_.png: 0.8477
# ./results\139_img_.png
# ./Dataset/reference-890\139_img_.png
# SSIM for 139_img_.png: 0.6323
# ./results\13_img_.png
# ./Dataset/reference-890\13_img_.png
# SSIM for 13_img_.png: 0.8245
# ./results\1407.png
# ./Dataset/reference-890\1407.png
# SSIM for 1407.png: 0.9191
# ./results\140_img_.png
# ./Dataset/reference-890\140_img_.png
# SSIM for 140_img_.png: 0.7297
# ./results\141_img_.png
# ./Dataset/reference-890\141_img_.png
# SSIM for 141_img_.png: 0.7646
# ./results\142_img_.png
# ./Dataset/reference-890\142_img_.png
# SSIM for 142_img_.png: 0.6632
# ./results\143_img_.png
# ./Dataset/reference-890\143_img_.png
# SSIM for 143_img_.png: 0.6347
# ./results\144_img_.png
# ./Dataset/reference-890\144_img_.png
# SSIM for 144_img_.png: 0.9094
# ./results\145_img_.png
# ./Dataset/reference-890\145_img_.png
# SSIM for 145_img_.png: 0.8437
# ./results\146_img_.png
# ./Dataset/reference-890\146_img_.png
# SSIM for 146_img_.png: 0.6421
# ./results\148_img_.png
# ./Dataset/reference-890\148_img_.png
# SSIM for 148_img_.png: 0.8834
# ./results\1491.png
# ./Dataset/reference-890\1491.png
# SSIM for 1491.png: 0.8240
# ./results\149_img_.png
# ./Dataset/reference-890\149_img_.png
# SSIM for 149_img_.png: 0.8653
# ./results\14_img_.png
# ./Dataset/reference-890\14_img_.png
# SSIM for 14_img_.png: 0.7601
# ./results\15001.png
# ./Dataset/reference-890\15001.png
# SSIM for 15001.png: 0.7901
# ./results\15003.png
# ./Dataset/reference-890\15003.png
# SSIM for 15003.png: 0.6136
# ./results\15045.png
# ./Dataset/reference-890\15045.png
# SSIM for 15045.png: 0.9503
# ./results\15094.png
# ./Dataset/reference-890\15094.png
# SSIM for 15094.png: 0.9274
# ./results\150_img_.png
# ./Dataset/reference-890\150_img_.png
# SSIM for 150_img_.png: 0.8967
# ./results\15113.png
# ./Dataset/reference-890\15113.png
# SSIM for 15113.png: 0.7914
# ./results\15136.png
# ./Dataset/reference-890\15136.png
# SSIM for 15136.png: 0.9618
# ./results\151_img_.png
# ./Dataset/reference-890\151_img_.png
# SSIM for 151_img_.png: 0.8503
# ./results\152_img_.png
# ./Dataset/reference-890\152_img_.png
# SSIM for 152_img_.png: 0.9417
# ./results\1539.png
# ./Dataset/reference-890\1539.png
# SSIM for 1539.png: 0.8894
# ./results\153_img_.png
# ./Dataset/reference-890\153_img_.png
# SSIM for 153_img_.png: 0.8257
# ./results\15418.png
# ./Dataset/reference-890\15418.png
# SSIM for 15418.png: 0.8334
# ./results\15426.png
# ./Dataset/reference-890\15426.png
# SSIM for 15426.png: 0.7734
# ./results\154_img_.png
# ./Dataset/reference-890\154_img_.png
# SSIM for 154_img_.png: 0.9128
# ./results\15544.png
# ./Dataset/reference-890\15544.png
# SSIM for 15544.png: 0.7473
# ./results\155_img_.png
# ./Dataset/reference-890\155_img_.png
# SSIM for 155_img_.png: 0.9103
# ./results\156_img_.png
# ./Dataset/reference-890\156_img_.png
# SSIM for 156_img_.png: 0.9200
# ./results\15704.png
# ./Dataset/reference-890\15704.png
# SSIM for 15704.png: 0.8152
# ./results\1573.png
# ./Dataset/reference-890\1573.png
# SSIM for 1573.png: 0.7742
# ./results\157_img_.png
# ./Dataset/reference-890\157_img_.png
# SSIM for 157_img_.png: 0.9298
# ./results\158_img_.png
# ./Dataset/reference-890\158_img_.png
# SSIM for 158_img_.png: 0.8984
# ./results\159_img_.png
# ./Dataset/reference-890\159_img_.png
# SSIM for 159_img_.png: 0.8359
# ./results\15_img_.png
# ./Dataset/reference-890\15_img_.png
# SSIM for 15_img_.png: 0.7571
# ./results\160_img_.png
# ./Dataset/reference-890\160_img_.png
# SSIM for 160_img_.png: 0.6791
# ./results\161_img_.png
# ./Dataset/reference-890\161_img_.png
# SSIM for 161_img_.png: 0.9194
# ./results\162_img_.png
# ./Dataset/reference-890\162_img_.png
# SSIM for 162_img_.png: 0.8778
# ./results\163_img_.png
# ./Dataset/reference-890\163_img_.png
# SSIM for 163_img_.png: 0.9441
# ./results\164_img_.png
# ./Dataset/reference-890\164_img_.png
# SSIM for 164_img_.png: 0.8302
# ./results\165_img_.png
# ./Dataset/reference-890\165_img_.png
# SSIM for 165_img_.png: 0.8295
# ./results\1660.png
# ./Dataset/reference-890\1660.png
# SSIM for 1660.png: 0.8485
# ./results\166_img_.png
# ./Dataset/reference-890\166_img_.png
# SSIM for 166_img_.png: 0.8221
# ./results\168_img_.png
# ./Dataset/reference-890\168_img_.png
# SSIM for 168_img_.png: 0.6031
# ./results\169_img_.png
# ./Dataset/reference-890\169_img_.png
# SSIM for 169_img_.png: 0.8298
# ./results\16_img_.png
# ./Dataset/reference-890\16_img_.png
# SSIM for 16_img_.png: 0.7843
# ./results\170_img_.png
# ./Dataset/reference-890\170_img_.png
# SSIM for 170_img_.png: 0.8956
# ./results\171_img_.png
# ./Dataset/reference-890\171_img_.png
# SSIM for 171_img_.png: 0.7003
# ./results\172_img_.png
# ./Dataset/reference-890\172_img_.png
# SSIM for 172_img_.png: 0.8639
# ./results\173_img_.png
# ./Dataset/reference-890\173_img_.png
# SSIM for 173_img_.png: 0.8063
# ./results\1742.png
# ./Dataset/reference-890\1742.png
# SSIM for 1742.png: 0.9364
# ./results\174_img_.png
# ./Dataset/reference-890\174_img_.png
# SSIM for 174_img_.png: 0.7217
# ./results\175_img_.png
# ./Dataset/reference-890\175_img_.png
# SSIM for 175_img_.png: 0.8275
# ./results\176_img_.png
# ./Dataset/reference-890\176_img_.png
# SSIM for 176_img_.png: 0.9238
# ./results\177_img_.png
# ./Dataset/reference-890\177_img_.png
# SSIM for 177_img_.png: 0.8157
# ./results\178_img_.png
# ./Dataset/reference-890\178_img_.png
# SSIM for 178_img_.png: 0.8392
# ./results\179_img_.png
# ./Dataset/reference-890\179_img_.png
# SSIM for 179_img_.png: 0.9650
# ./results\17_img_.png
# ./Dataset/reference-890\17_img_.png
# SSIM for 17_img_.png: 0.8476
# ./results\180_img_.png
# ./Dataset/reference-890\180_img_.png
# SSIM for 180_img_.png: 0.8246
# ./results\182_img_.png
# ./Dataset/reference-890\182_img_.png
# SSIM for 182_img_.png: 0.7796
# ./results\183_img_.png
# ./Dataset/reference-890\183_img_.png
# SSIM for 183_img_.png: 0.8082
# ./results\184_img_.png
# ./Dataset/reference-890\184_img_.png
# SSIM for 184_img_.png: 0.8707
# ./results\185_img_.png
# ./Dataset/reference-890\185_img_.png
# SSIM for 185_img_.png: 0.9059
# ./results\186_img_.png
# ./Dataset/reference-890\186_img_.png
# SSIM for 186_img_.png: 0.8105
# ./results\187_img_.png
# ./Dataset/reference-890\187_img_.png
# SSIM for 187_img_.png: 0.8233
# ./results\188_img_.png
# ./Dataset/reference-890\188_img_.png
# SSIM for 188_img_.png: 0.8828
# ./results\189_img_.png
# ./Dataset/reference-890\189_img_.png
# SSIM for 189_img_.png: 0.7141
# ./results\18_img_.png
# ./Dataset/reference-890\18_img_.png
# SSIM for 18_img_.png: 0.6880
# ./results\190_img_.png
# ./Dataset/reference-890\190_img_.png
# SSIM for 190_img_.png: 0.8846
# ./results\191_img_.png
# ./Dataset/reference-890\191_img_.png
# SSIM for 191_img_.png: 0.7803
# ./results\192_img_.png
# ./Dataset/reference-890\192_img_.png
# SSIM for 192_img_.png: 0.8517
# ./results\193_img_.png
# ./Dataset/reference-890\193_img_.png
# SSIM for 193_img_.png: 0.8926
# ./results\194_img_.png
# ./Dataset/reference-890\194_img_.png
# SSIM for 194_img_.png: 0.8785
# ./results\1957.png
# ./Dataset/reference-890\1957.png
# SSIM for 1957.png: 0.8595
# ./results\195_img_.png
# ./Dataset/reference-890\195_img_.png
# SSIM for 195_img_.png: 0.9145
# ./results\196_img_.png
# ./Dataset/reference-890\196_img_.png
# SSIM for 196_img_.png: 0.9343
# ./results\197_img_.png
# ./Dataset/reference-890\197_img_.png
# SSIM for 197_img_.png: 0.9011
# ./results\198_img_.png
# ./Dataset/reference-890\198_img_.png
# SSIM for 198_img_.png: 0.9241
# ./results\199_img_.png
# ./Dataset/reference-890\199_img_.png
# SSIM for 199_img_.png: 0.8586
# ./results\19_img_.png
# ./Dataset/reference-890\19_img_.png
# SSIM for 19_img_.png: 0.6781
# ./results\20.png
# ./Dataset/reference-890\20.png
# SSIM for 20.png: 0.8934
# ./results\200_img_.png
# ./Dataset/reference-890\200_img_.png
# SSIM for 200_img_.png: 0.8099
# ./results\201_img_.png
# ./Dataset/reference-890\201_img_.png
# SSIM for 201_img_.png: 0.9326
# ./results\202_img_.png
# ./Dataset/reference-890\202_img_.png
# SSIM for 202_img_.png: 0.8288
# ./results\203_img_.png
# ./Dataset/reference-890\203_img_.png
# SSIM for 203_img_.png: 0.8485
# ./results\204_img_.png
# ./Dataset/reference-890\204_img_.png
# SSIM for 204_img_.png: 0.8238
# ./results\205_img_.png
# ./Dataset/reference-890\205_img_.png
# SSIM for 205_img_.png: 0.8797
# ./results\206_img_.png
# ./Dataset/reference-890\206_img_.png
# SSIM for 206_img_.png: 0.8768
# ./results\207_img_.png
# ./Dataset/reference-890\207_img_.png
# SSIM for 207_img_.png: 0.9524
# ./results\208_img_.png
# ./Dataset/reference-890\208_img_.png
# SSIM for 208_img_.png: 0.9789
# ./results\209_img_.png
# ./Dataset/reference-890\209_img_.png
# SSIM for 209_img_.png: 0.9491
# ./results\210_img_.png
# ./Dataset/reference-890\210_img_.png
# SSIM for 210_img_.png: 0.9400
# ./results\211_img_.png
# ./Dataset/reference-890\211_img_.png
# SSIM for 211_img_.png: 0.9191
# ./results\212_img_.png
# ./Dataset/reference-890\212_img_.png
# SSIM for 212_img_.png: 0.9150
# ./results\213_img_.png
# ./Dataset/reference-890\213_img_.png
# SSIM for 213_img_.png: 0.8339
# ./results\214_img_.png
# ./Dataset/reference-890\214_img_.png
# SSIM for 214_img_.png: 0.8612
# ./results\215_img_.png
# ./Dataset/reference-890\215_img_.png
# SSIM for 215_img_.png: 0.9146
# ./results\216_img_.png
# ./Dataset/reference-890\216_img_.png
# SSIM for 216_img_.png: 0.8844
# ./results\217_img_.png
# ./Dataset/reference-890\217_img_.png
# SSIM for 217_img_.png: 0.8841
# ./results\219_img_.png
# ./Dataset/reference-890\219_img_.png
# SSIM for 219_img_.png: 0.8640
# ./results\220_img_.png
# ./Dataset/reference-890\220_img_.png
# SSIM for 220_img_.png: 0.8730
# ./results\221_img_.png
# ./Dataset/reference-890\221_img_.png
# SSIM for 221_img_.png: 0.8049
# ./results\222_img_.png
# ./Dataset/reference-890\222_img_.png
# SSIM for 222_img_.png: 0.8801
# ./results\223_img_.png
# ./Dataset/reference-890\223_img_.png
# SSIM for 223_img_.png: 0.9192
# ./results\224_img_.png
# ./Dataset/reference-890\224_img_.png
# SSIM for 224_img_.png: 0.9123
# ./results\225_img_.png
# ./Dataset/reference-890\225_img_.png
# SSIM for 225_img_.png: 0.7631
# ./results\226_img_.png
# ./Dataset/reference-890\226_img_.png
# SSIM for 226_img_.png: 0.8083
# ./results\227_img_.png
# ./Dataset/reference-890\227_img_.png
# SSIM for 227_img_.png: 0.8008
# ./results\228_img_.png
# ./Dataset/reference-890\228_img_.png
# SSIM for 228_img_.png: 0.6960
# ./results\229_img_.png
# ./Dataset/reference-890\229_img_.png
# SSIM for 229_img_.png: 0.7902
# ./results\22_img_.png
# ./Dataset/reference-890\22_img_.png
# SSIM for 22_img_.png: 0.8529
# ./results\230_img_.png
# ./Dataset/reference-890\230_img_.png
# SSIM for 230_img_.png: 0.9460
# ./results\231_img_.png
# ./Dataset/reference-890\231_img_.png
# SSIM for 231_img_.png: 0.8597
# ./results\232_img_.png
# ./Dataset/reference-890\232_img_.png
# SSIM for 232_img_.png: 0.8610
# ./results\233_img_.png
# ./Dataset/reference-890\233_img_.png
# SSIM for 233_img_.png: 0.8565
# ./results\234_img_.png
# ./Dataset/reference-890\234_img_.png
# SSIM for 234_img_.png: 0.8107
# ./results\236_img_.png
# ./Dataset/reference-890\236_img_.png
# SSIM for 236_img_.png: 0.8463
# ./results\238_img_.png
# ./Dataset/reference-890\238_img_.png
# SSIM for 238_img_.png: 0.7936
# ./results\23_img_.png
# ./Dataset/reference-890\23_img_.png
# SSIM for 23_img_.png: 0.8890
# ./results\240_img_.png
# ./Dataset/reference-890\240_img_.png
# SSIM for 240_img_.png: 0.7634
# ./results\241_img_.png
# ./Dataset/reference-890\241_img_.png
# SSIM for 241_img_.png: 0.8434
# ./results\242_img_.png
# ./Dataset/reference-890\242_img_.png
# SSIM for 242_img_.png: 0.9484
# ./results\243_img_.png
# ./Dataset/reference-890\243_img_.png
# SSIM for 243_img_.png: 0.8573
# ./results\244_img_.png
# ./Dataset/reference-890\244_img_.png
# SSIM for 244_img_.png: 0.8826
# ./results\245_img_.png
# ./Dataset/reference-890\245_img_.png
# SSIM for 245_img_.png: 0.8553
# ./results\246_img_.png
# ./Dataset/reference-890\246_img_.png
# SSIM for 246_img_.png: 0.8481
# ./results\247_img_.png
# ./Dataset/reference-890\247_img_.png
# SSIM for 247_img_.png: 0.8571
# ./results\248_img_.png
# ./Dataset/reference-890\248_img_.png
# SSIM for 248_img_.png: 0.8515
# ./results\24_img_.png
# ./Dataset/reference-890\24_img_.png
# SSIM for 24_img_.png: 0.8464
# ./results\251_img_.png
# ./Dataset/reference-890\251_img_.png
# SSIM for 251_img_.png: 0.9453
# ./results\252_img_.png
# ./Dataset/reference-890\252_img_.png
# SSIM for 252_img_.png: 0.8274
# ./results\253_img_.png
# ./Dataset/reference-890\253_img_.png
# SSIM for 253_img_.png: 0.9170
# ./results\2546.png
# ./Dataset/reference-890\2546.png
# SSIM for 2546.png: 0.9411
# ./results\254_img_.png
# ./Dataset/reference-890\254_img_.png
# SSIM for 254_img_.png: 0.8460
# ./results\255_img_.png
# ./Dataset/reference-890\255_img_.png
# SSIM for 255_img_.png: 0.8974
# ./results\257_img_.png
# ./Dataset/reference-890\257_img_.png
# SSIM for 257_img_.png: 0.9429
# ./results\258_img_.png
# ./Dataset/reference-890\258_img_.png
# SSIM for 258_img_.png: 0.8177
# ./results\259_img_.png
# ./Dataset/reference-890\259_img_.png
# SSIM for 259_img_.png: 0.9000
# ./results\25_img_.png
# ./Dataset/reference-890\25_img_.png
# SSIM for 25_img_.png: 0.8782
# ./results\260_img_.png
# ./Dataset/reference-890\260_img_.png
# SSIM for 260_img_.png: 0.7656
# ./results\261_img_.png
# ./Dataset/reference-890\261_img_.png
# SSIM for 261_img_.png: 0.9030
# ./results\2629.png
# ./Dataset/reference-890\2629.png
# SSIM for 2629.png: 0.7494
# ./results\262_img_.png
# ./Dataset/reference-890\262_img_.png
# SSIM for 262_img_.png: 0.8781
# ./results\263_img_.png
# ./Dataset/reference-890\263_img_.png
# SSIM for 263_img_.png: 0.6158
# ./results\265_img_.png
# ./Dataset/reference-890\265_img_.png
# SSIM for 265_img_.png: 0.8499
# ./results\266_img_.png
# ./Dataset/reference-890\266_img_.png
# SSIM for 266_img_.png: 0.8528
# ./results\2677.png
# ./Dataset/reference-890\2677.png
# SSIM for 2677.png: 0.8587
# ./results\267_img_.png
# ./Dataset/reference-890\267_img_.png
# SSIM for 267_img_.png: 0.8535
# ./results\268_img_.png
# ./Dataset/reference-890\268_img_.png
# SSIM for 268_img_.png: 0.6822
# ./results\26_img_.png
# ./Dataset/reference-890\26_img_.png
# SSIM for 26_img_.png: 0.8829
# ./results\2701.png
# ./Dataset/reference-890\2701.png
# SSIM for 2701.png: 0.6955
# ./results\270_img_.png
# ./Dataset/reference-890\270_img_.png
# SSIM for 270_img_.png: 0.8250
# ./results\271_img_.png
# ./Dataset/reference-890\271_img_.png
# SSIM for 271_img_.png: 0.8783
# ./results\272_img_.png
# ./Dataset/reference-890\272_img_.png
# SSIM for 272_img_.png: 0.8801
# ./results\273_img_.png
# ./Dataset/reference-890\273_img_.png
# SSIM for 273_img_.png: 0.8914
# ./results\274_img_.png
# ./Dataset/reference-890\274_img_.png
# SSIM for 274_img_.png: 0.7120
# ./results\275_img_.png
# ./Dataset/reference-890\275_img_.png
# SSIM for 275_img_.png: 0.8981
# ./results\276_img_.png
# ./Dataset/reference-890\276_img_.png
# SSIM for 276_img_.png: 0.8771
# ./results\2774.png
# ./Dataset/reference-890\2774.png
# SSIM for 2774.png: 0.8762
# ./results\277_img_.png
# ./Dataset/reference-890\277_img_.png
# SSIM for 277_img_.png: 0.8522
# ./results\2787.png
# ./Dataset/reference-890\2787.png
# SSIM for 2787.png: 0.9005
# ./results\278_img_.png
# ./Dataset/reference-890\278_img_.png
# SSIM for 278_img_.png: 0.9167
# ./results\279_img_.png
# ./Dataset/reference-890\279_img_.png
# SSIM for 279_img_.png: 0.6809
# ./results\27_img_.png
# ./Dataset/reference-890\27_img_.png
# SSIM for 27_img_.png: 0.8559
# ./results\280_img_.png
# ./Dataset/reference-890\280_img_.png
# SSIM for 280_img_.png: 0.8518
# ./results\281_img_.png
# ./Dataset/reference-890\281_img_.png
# SSIM for 281_img_.png: 0.8753
# ./results\282_img_.png
# ./Dataset/reference-890\282_img_.png
# SSIM for 282_img_.png: 0.9165
# ./results\284_img_.png
# ./Dataset/reference-890\284_img_.png
# SSIM for 284_img_.png: 0.8297
# ./results\285_img_.png
# ./Dataset/reference-890\285_img_.png
# SSIM for 285_img_.png: 0.6904
# ./results\287_img_.png
# ./Dataset/reference-890\287_img_.png
# SSIM for 287_img_.png: 0.7764
# ./results\2882.png
# ./Dataset/reference-890\2882.png
# SSIM for 2882.png: 0.8410
# ./results\288_img_.png
# ./Dataset/reference-890\288_img_.png
# SSIM for 288_img_.png: 0.8112
# ./results\28_img_.png
# ./Dataset/reference-890\28_img_.png
# SSIM for 28_img_.png: 0.8456
# ./results\290_img_.png
# ./Dataset/reference-890\290_img_.png
# SSIM for 290_img_.png: 0.8060
# ./results\292_img_.png
# ./Dataset/reference-890\292_img_.png
# SSIM for 292_img_.png: 0.9012
# ./results\293_img_.png
# ./Dataset/reference-890\293_img_.png
# SSIM for 293_img_.png: 0.8816
# ./results\294_img_.png
# ./Dataset/reference-890\294_img_.png
# SSIM for 294_img_.png: 0.7805
# ./results\295_img_.png
# ./Dataset/reference-890\295_img_.png
# SSIM for 295_img_.png: 0.7787
# ./results\296_img_.png
# ./Dataset/reference-890\296_img_.png
# SSIM for 296_img_.png: 0.9243
# ./results\2977.png
# ./Dataset/reference-890\2977.png
# SSIM for 2977.png: 0.6935
# ./results\298_img_.png
# ./Dataset/reference-890\298_img_.png
# SSIM for 298_img_.png: 0.7690
# ./results\299_img_.png
# ./Dataset/reference-890\299_img_.png
# SSIM for 299_img_.png: 0.6748
# ./results\29_img_.png
# ./Dataset/reference-890\29_img_.png
# SSIM for 29_img_.png: 0.9641
# ./results\2_img_.png
# ./Dataset/reference-890\2_img_.png
# SSIM for 2_img_.png: 0.9493
# ./results\3001.png
# ./Dataset/reference-890\3001.png
# SSIM for 3001.png: 0.8730
# ./results\300_img_.png
# ./Dataset/reference-890\300_img_.png
# SSIM for 300_img_.png: 0.8107
# ./results\3015.png
# ./Dataset/reference-890\3015.png
# SSIM for 3015.png: 0.9094
# ./results\301_img_.png
# ./Dataset/reference-890\301_img_.png
# SSIM for 301_img_.png: 0.7137
# ./results\302_img_.png
# ./Dataset/reference-890\302_img_.png
# SSIM for 302_img_.png: 0.7468
# ./results\303_img_.png
# ./Dataset/reference-890\303_img_.png
# SSIM for 303_img_.png: 0.9186
# ./results\304_img_.png
# ./Dataset/reference-890\304_img_.png
# SSIM for 304_img_.png: 0.9285
# ./results\305_img_.png
# ./Dataset/reference-890\305_img_.png
# SSIM for 305_img_.png: 0.7854
# ./results\306_img_.png
# ./Dataset/reference-890\306_img_.png
# SSIM for 306_img_.png: 0.9205
# ./results\307_img_.png
# ./Dataset/reference-890\307_img_.png
# SSIM for 307_img_.png: 0.8889
# ./results\30_img_.png
# ./Dataset/reference-890\30_img_.png
# SSIM for 30_img_.png: 0.7325
# ./results\31.png
# ./Dataset/reference-890\31.png
# SSIM for 31.png: 0.8243
# ./results\311_img_.png
# ./Dataset/reference-890\311_img_.png
# SSIM for 311_img_.png: 0.9469
# ./results\312_img_.png
# ./Dataset/reference-890\312_img_.png
# SSIM for 312_img_.png: 0.8576
# ./results\313_img_.png
# ./Dataset/reference-890\313_img_.png
# SSIM for 313_img_.png: 0.8248
# ./results\314_img_.png
# ./Dataset/reference-890\314_img_.png
# SSIM for 314_img_.png: 0.9090
# ./results\315_img_.png
# ./Dataset/reference-890\315_img_.png
# SSIM for 315_img_.png: 0.7826
# ./results\316_img_.png
# ./Dataset/reference-890\316_img_.png
# SSIM for 316_img_.png: 0.7552
# ./results\317_img_.png
# ./Dataset/reference-890\317_img_.png
# SSIM for 317_img_.png: 0.7052
# ./results\318_img_.png
# ./Dataset/reference-890\318_img_.png
# SSIM for 318_img_.png: 0.8593
# ./results\3196.png
# ./Dataset/reference-890\3196.png
# SSIM for 3196.png: 0.8088
# ./results\319_img_.png
# ./Dataset/reference-890\319_img_.png
# SSIM for 319_img_.png: 0.6947
# ./results\3202.png
# ./Dataset/reference-890\3202.png
# SSIM for 3202.png: 0.7825
# ./results\320_img_.png
# ./Dataset/reference-890\320_img_.png
# SSIM for 320_img_.png: 0.8842
# ./results\322_img_.png
# ./Dataset/reference-890\322_img_.png
# SSIM for 322_img_.png: 0.6791
# ./results\323_img_.png
# ./Dataset/reference-890\323_img_.png
# SSIM for 323_img_.png: 0.8476
# ./results\324_img_.png
# ./Dataset/reference-890\324_img_.png
# SSIM for 324_img_.png: 0.7793
# ./results\325_img_.png
# ./Dataset/reference-890\325_img_.png
# SSIM for 325_img_.png: 0.7555
# ./results\326_img_.png
# ./Dataset/reference-890\326_img_.png
# SSIM for 326_img_.png: 0.7109
# ./results\327_img_.png
# ./Dataset/reference-890\327_img_.png
# SSIM for 327_img_.png: 0.7884
# ./results\328_img_.png
# ./Dataset/reference-890\328_img_.png
# SSIM for 328_img_.png: 0.8886
# ./results\32_img_.png
# ./Dataset/reference-890\32_img_.png
# SSIM for 32_img_.png: 0.7837
# ./results\330_img_.png
# ./Dataset/reference-890\330_img_.png
# SSIM for 330_img_.png: 0.5879
# ./results\332_img_.png
# ./Dataset/reference-890\332_img_.png
# SSIM for 332_img_.png: 0.9600
# ./results\3330.png
# ./Dataset/reference-890\3330.png
# SSIM for 3330.png: 0.7515
# ./results\334_img_.png
# ./Dataset/reference-890\334_img_.png
# SSIM for 334_img_.png: 0.8077
# ./results\336_img_.png
# ./Dataset/reference-890\336_img_.png
# SSIM for 336_img_.png: 0.8870
# ./results\337_img_.png
# ./Dataset/reference-890\337_img_.png
# SSIM for 337_img_.png: 0.7185
# ./results\338_img_.png
# ./Dataset/reference-890\338_img_.png
# SSIM for 338_img_.png: 0.8184
# ./results\340_img_.png
# ./Dataset/reference-890\340_img_.png
# SSIM for 340_img_.png: 0.8393
# ./results\341_img_.png
# ./Dataset/reference-890\341_img_.png
# SSIM for 341_img_.png: 0.7877
# ./results\342_img_.png
# ./Dataset/reference-890\342_img_.png
# SSIM for 342_img_.png: 0.7142
# ./results\343_img_.png
# ./Dataset/reference-890\343_img_.png
# SSIM for 343_img_.png: 0.9546
# ./results\345_img_.png
# ./Dataset/reference-890\345_img_.png
# SSIM for 345_img_.png: 0.7154
# ./results\346_img_.png
# ./Dataset/reference-890\346_img_.png
# SSIM for 346_img_.png: 0.9166
# ./results\347_img_.png
# ./Dataset/reference-890\347_img_.png
# SSIM for 347_img_.png: 0.8491
# ./results\348_img_.png
# ./Dataset/reference-890\348_img_.png
# SSIM for 348_img_.png: 0.7027
# ./results\35.png
# ./Dataset/reference-890\35.png
# SSIM for 35.png: 0.8971
# ./results\350_img_.png
# ./Dataset/reference-890\350_img_.png
# SSIM for 350_img_.png: 0.8873
# ./results\351_img_.png
# ./Dataset/reference-890\351_img_.png
# SSIM for 351_img_.png: 0.9278
# ./results\353_img_.png
# ./Dataset/reference-890\353_img_.png
# SSIM for 353_img_.png: 0.7070
# ./results\355_img_.png
# ./Dataset/reference-890\355_img_.png
# SSIM for 355_img_.png: 0.8296
# ./results\356_img_.png
# ./Dataset/reference-890\356_img_.png
# SSIM for 356_img_.png: 0.6628
# ./results\359_img_.png
# ./Dataset/reference-890\359_img_.png
# SSIM for 359_img_.png: 0.7365
# ./results\360_img_.png
# ./Dataset/reference-890\360_img_.png
# SSIM for 360_img_.png: 0.6816
# ./results\361_img_.png
# ./Dataset/reference-890\361_img_.png
# SSIM for 361_img_.png: 0.7170
# ./results\362_img_.png
# ./Dataset/reference-890\362_img_.png
# SSIM for 362_img_.png: 0.8301
# ./results\363_img_.png
# ./Dataset/reference-890\363_img_.png
# SSIM for 363_img_.png: 0.7526
# ./results\364_img_.png
# ./Dataset/reference-890\364_img_.png
# SSIM for 364_img_.png: 0.8860
# ./results\3650.png
# ./Dataset/reference-890\3650.png
# SSIM for 3650.png: 0.9011
# ./results\365_img_.png
# ./Dataset/reference-890\365_img_.png
# SSIM for 365_img_.png: 0.7190
# ./results\366_img_.png
# ./Dataset/reference-890\366_img_.png
# SSIM for 366_img_.png: 0.7866
# ./results\367_img_.png
# ./Dataset/reference-890\367_img_.png
# SSIM for 367_img_.png: 0.7481
# ./results\369_img_.png
# ./Dataset/reference-890\369_img_.png
# SSIM for 369_img_.png: 0.9275
# ./results\370_img_.png
# ./Dataset/reference-890\370_img_.png
# SSIM for 370_img_.png: 0.9580
# ./results\371_img_.png
# ./Dataset/reference-890\371_img_.png
# SSIM for 371_img_.png: 0.8794
# ./results\3728.png
# ./Dataset/reference-890\3728.png
# SSIM for 3728.png: 0.9025
# ./results\372_img_.png
# ./Dataset/reference-890\372_img_.png
# SSIM for 372_img_.png: 0.8394
# ./results\373_img_.png
# ./Dataset/reference-890\373_img_.png
# SSIM for 373_img_.png: 0.7099
# ./results\374_img_.png
# ./Dataset/reference-890\374_img_.png
# SSIM for 374_img_.png: 0.7914
# ./results\375_img_.png
# ./Dataset/reference-890\375_img_.png
# SSIM for 375_img_.png: 0.8758
# ./results\376_img_.png
# ./Dataset/reference-890\376_img_.png
# SSIM for 376_img_.png: 0.8461
# ./results\377_img_.png
# ./Dataset/reference-890\377_img_.png
# SSIM for 377_img_.png: 0.8908
# ./results\378_img_.png
# ./Dataset/reference-890\378_img_.png
# SSIM for 378_img_.png: 0.8945
# ./results\379_img_.png
# ./Dataset/reference-890\379_img_.png
# SSIM for 379_img_.png: 0.7745
# ./results\37_img_.png
# ./Dataset/reference-890\37_img_.png
# SSIM for 37_img_.png: 0.8265
# ./results\380_img_.png
# ./Dataset/reference-890\380_img_.png
# SSIM for 380_img_.png: 0.8796
# ./results\381_img_.png
# ./Dataset/reference-890\381_img_.png
# SSIM for 381_img_.png: 0.6829
# ./results\382_img_.png
# ./Dataset/reference-890\382_img_.png
# SSIM for 382_img_.png: 0.9080
# ./results\383_img_.png
# ./Dataset/reference-890\383_img_.png
# SSIM for 383_img_.png: 0.8563
# ./results\384_img_.png
# ./Dataset/reference-890\384_img_.png
# SSIM for 384_img_.png: 0.6820
# ./results\385_img_.png
# ./Dataset/reference-890\385_img_.png
# SSIM for 385_img_.png: 0.5420
# ./results\386_img_.png
# ./Dataset/reference-890\386_img_.png
# SSIM for 386_img_.png: 0.9771
# ./results\387_img_.png
# ./Dataset/reference-890\387_img_.png
# SSIM for 387_img_.png: 0.9197
# ./results\389_img_.png
# ./Dataset/reference-890\389_img_.png
# SSIM for 389_img_.png: 0.7041
# ./results\391_img_.png
# ./Dataset/reference-890\391_img_.png
# SSIM for 391_img_.png: 0.6641
# ./results\3925.png
# ./Dataset/reference-890\3925.png
# SSIM for 3925.png: 0.9297
# ./results\392_img_.png
# ./Dataset/reference-890\392_img_.png
# SSIM for 392_img_.png: 0.6881
# ./results\393_img_.png
# ./Dataset/reference-890\393_img_.png
# SSIM for 393_img_.png: 0.7637
# ./results\3947.png
# ./Dataset/reference-890\3947.png
# SSIM for 3947.png: 0.9322
# ./results\394_img_.png
# ./Dataset/reference-890\394_img_.png
# SSIM for 394_img_.png: 0.9110
# ./results\395_img_.png
# ./Dataset/reference-890\395_img_.png
# SSIM for 395_img_.png: 0.8140
# ./results\39_img_.png
# ./Dataset/reference-890\39_img_.png
# SSIM for 39_img_.png: 0.7913
# ./results\3_img_.png
# ./Dataset/reference-890\3_img_.png
# SSIM for 3_img_.png: 0.9043
# ./results\4.png
# ./Dataset/reference-890\4.png
# SSIM for 4.png: 0.8417
# ./results\400_img_.png
# ./Dataset/reference-890\400_img_.png
# SSIM for 400_img_.png: 0.6993
# ./results\401_img_.png
# ./Dataset/reference-890\401_img_.png
# SSIM for 401_img_.png: 0.8764
# ./results\402_img_.png
# ./Dataset/reference-890\402_img_.png
# SSIM for 402_img_.png: 0.8777
# ./results\403_img_.png
# ./Dataset/reference-890\403_img_.png
# SSIM for 403_img_.png: 0.6663
# ./results\404_img_.png
# ./Dataset/reference-890\404_img_.png
# SSIM for 404_img_.png: 0.7536
# ./results\405_img_.png
# ./Dataset/reference-890\405_img_.png
# SSIM for 405_img_.png: 0.6388
# ./results\406_img_.png
# ./Dataset/reference-890\406_img_.png
# SSIM for 406_img_.png: 0.7557
# ./results\4070.png
# ./Dataset/reference-890\4070.png
# SSIM for 4070.png: 0.9635
# ./results\407_img_.png
# ./Dataset/reference-890\407_img_.png
# SSIM for 407_img_.png: 0.6535
# ./results\408_img_.png
# ./Dataset/reference-890\408_img_.png
# SSIM for 408_img_.png: 0.9660
# ./results\409_img_.png
# ./Dataset/reference-890\409_img_.png
# SSIM for 409_img_.png: 0.8176
# ./results\410_img_.png
# ./Dataset/reference-890\410_img_.png
# SSIM for 410_img_.png: 0.6863
# ./results\411_img_.png
# ./Dataset/reference-890\411_img_.png
# SSIM for 411_img_.png: 0.7123
# ./results\412_img_.png
# ./Dataset/reference-890\412_img_.png
# SSIM for 412_img_.png: 0.8431
# ./results\413_img_.png
# ./Dataset/reference-890\413_img_.png
# SSIM for 413_img_.png: 0.7024
# ./results\415_img_.png
# ./Dataset/reference-890\415_img_.png
# SSIM for 415_img_.png: 0.9577
# ./results\416_img_.png
# ./Dataset/reference-890\416_img_.png
# SSIM for 416_img_.png: 0.8575
# ./results\417_img_.png
# ./Dataset/reference-890\417_img_.png
# SSIM for 417_img_.png: 0.7758
# ./results\418_img_.png
# ./Dataset/reference-890\418_img_.png
# SSIM for 418_img_.png: 0.6817
# ./results\419_img_.png
# ./Dataset/reference-890\419_img_.png
# SSIM for 419_img_.png: 0.7438
# ./results\41_img_.png
# ./Dataset/reference-890\41_img_.png
# SSIM for 41_img_.png: 0.8005
# ./results\420_img_.png
# ./Dataset/reference-890\420_img_.png
# SSIM for 420_img_.png: 0.7795
# ./results\421_img_.png
# ./Dataset/reference-890\421_img_.png
# SSIM for 421_img_.png: 0.8579
# ./results\422_img_.png
# ./Dataset/reference-890\422_img_.png
# SSIM for 422_img_.png: 0.7858
# ./results\423_img_.png
# ./Dataset/reference-890\423_img_.png
# SSIM for 423_img_.png: 0.6832
# ./results\424_img_.png
# ./Dataset/reference-890\424_img_.png
# SSIM for 424_img_.png: 0.9621
# ./results\425_img_.png
# ./Dataset/reference-890\425_img_.png
# SSIM for 425_img_.png: 0.7530
# ./results\428_img_.png
# ./Dataset/reference-890\428_img_.png
# SSIM for 428_img_.png: 0.8301
# ./results\429_img_.png
# ./Dataset/reference-890\429_img_.png
# SSIM for 429_img_.png: 0.8646
# ./results\42_img_.png
# ./Dataset/reference-890\42_img_.png
# SSIM for 42_img_.png: 0.5724
# ./results\432_img_.png
# ./Dataset/reference-890\432_img_.png
# SSIM for 432_img_.png: 0.8346
# ./results\433_img_.png
# ./Dataset/reference-890\433_img_.png
# SSIM for 433_img_.png: 0.8456
# ./results\435_img_.png
# ./Dataset/reference-890\435_img_.png
# SSIM for 435_img_.png: 0.7606
# ./results\436_img_.png
# ./Dataset/reference-890\436_img_.png
# SSIM for 436_img_.png: 0.9432
# ./results\437_img_.png
# ./Dataset/reference-890\437_img_.png
# SSIM for 437_img_.png: 0.8921
# ./results\438_img_.png
# ./Dataset/reference-890\438_img_.png
# SSIM for 438_img_.png: 0.5132
# ./results\439_img_.png
# ./Dataset/reference-890\439_img_.png
# SSIM for 439_img_.png: 0.9550
# ./results\43_img_.png
# ./Dataset/reference-890\43_img_.png
# SSIM for 43_img_.png: 0.7795
# ./results\440_img_.png
# ./Dataset/reference-890\440_img_.png
# SSIM for 440_img_.png: 0.6996
# ./results\441_img_.png
# ./Dataset/reference-890\441_img_.png
# SSIM for 441_img_.png: 0.7761
# ./results\442_img_.png
# ./Dataset/reference-890\442_img_.png
# SSIM for 442_img_.png: 0.8362
# ./results\443_img_.png
# ./Dataset/reference-890\443_img_.png
# SSIM for 443_img_.png: 0.7420
# ./results\444_img_.png
# ./Dataset/reference-890\444_img_.png
# SSIM for 444_img_.png: 0.8696
# ./results\445_img_.png
# ./Dataset/reference-890\445_img_.png
# SSIM for 445_img_.png: 0.8857
# ./results\446_img_.png
# ./Dataset/reference-890\446_img_.png
# SSIM for 446_img_.png: 0.7347
# ./results\447_img_.png
# ./Dataset/reference-890\447_img_.png
# SSIM for 447_img_.png: 0.7522
# ./results\448_img_.png
# ./Dataset/reference-890\448_img_.png
# SSIM for 448_img_.png: 0.7665
# ./results\449_img_.png
# ./Dataset/reference-890\449_img_.png
# SSIM for 449_img_.png: 0.8934
# ./results\44_img_.png
# ./Dataset/reference-890\44_img_.png
# SSIM for 44_img_.png: 0.6495
# ./results\450_img_.png
# ./Dataset/reference-890\450_img_.png
# SSIM for 450_img_.png: 0.7808
# ./results\451_img_.png
# ./Dataset/reference-890\451_img_.png
# SSIM for 451_img_.png: 0.7679
# ./results\452_img_.png
# ./Dataset/reference-890\452_img_.png
# SSIM for 452_img_.png: 0.8770
# ./results\453_img_.png
# ./Dataset/reference-890\453_img_.png
# SSIM for 453_img_.png: 0.9147
# ./results\454_img_.png
# ./Dataset/reference-890\454_img_.png
# SSIM for 454_img_.png: 0.7730
# ./results\455_img_.png
# ./Dataset/reference-890\455_img_.png
# SSIM for 455_img_.png: 0.8447
# ./results\457_img_.png
# ./Dataset/reference-890\457_img_.png
# SSIM for 457_img_.png: 0.8070
# ./results\458_img_.png
# ./Dataset/reference-890\458_img_.png
# SSIM for 458_img_.png: 0.9049
# ./results\459_img_.png
# ./Dataset/reference-890\459_img_.png
# SSIM for 459_img_.png: 0.5938
# ./results\45_img_.png
# ./Dataset/reference-890\45_img_.png
# SSIM for 45_img_.png: 0.7931
# ./results\460_img_.png
# ./Dataset/reference-890\460_img_.png
# SSIM for 460_img_.png: 0.7860
# ./results\461_img_.png
# ./Dataset/reference-890\461_img_.png
# SSIM for 461_img_.png: 0.7286
# ./results\462_img_.png
# ./Dataset/reference-890\462_img_.png
# SSIM for 462_img_.png: 0.7477
# ./results\463_img_.png
# ./Dataset/reference-890\463_img_.png
# SSIM for 463_img_.png: 0.9013
# ./results\464_img_.png
# ./Dataset/reference-890\464_img_.png
# SSIM for 464_img_.png: 0.7467
# ./results\465_img_.png
# ./Dataset/reference-890\465_img_.png
# SSIM for 465_img_.png: 0.6670
# ./results\466_img_.png
# ./Dataset/reference-890\466_img_.png
# SSIM for 466_img_.png: 0.7510
# ./results\467_img_.png
# ./Dataset/reference-890\467_img_.png
# SSIM for 467_img_.png: 0.7721
# ./results\468_img_.png
# ./Dataset/reference-890\468_img_.png
# SSIM for 468_img_.png: 0.8395
# ./results\469_img_.png
# ./Dataset/reference-890\469_img_.png
# SSIM for 469_img_.png: 0.8975
# ./results\46_img_.png
# ./Dataset/reference-890\46_img_.png
# SSIM for 46_img_.png: 0.7733
# ./results\470_img_.png
# ./Dataset/reference-890\470_img_.png
# SSIM for 470_img_.png: 0.7872
# ./results\471_img_.png
# ./Dataset/reference-890\471_img_.png
# SSIM for 471_img_.png: 0.8528
# ./results\472_img_.png
# ./Dataset/reference-890\472_img_.png
# SSIM for 472_img_.png: 0.8256
# ./results\473_img_.png
# ./Dataset/reference-890\473_img_.png
# SSIM for 473_img_.png: 0.7223
# ./results\476_img_.png
# ./Dataset/reference-890\476_img_.png
# SSIM for 476_img_.png: 0.8976
# ./results\477_img_.png
# ./Dataset/reference-890\477_img_.png
# SSIM for 477_img_.png: 0.8298
# ./results\478_img_.png
# ./Dataset/reference-890\478_img_.png
# SSIM for 478_img_.png: 0.7623
# ./results\479_img_.png
# ./Dataset/reference-890\479_img_.png
# SSIM for 479_img_.png: 0.8896
# ./results\480_img_.png
# ./Dataset/reference-890\480_img_.png
# SSIM for 480_img_.png: 0.6947
# ./results\481_img_.png
# ./Dataset/reference-890\481_img_.png
# SSIM for 481_img_.png: 0.8689
# ./results\482_img_.png
# ./Dataset/reference-890\482_img_.png
# SSIM for 482_img_.png: 0.8166
# ./results\483_img_.png
# ./Dataset/reference-890\483_img_.png
# SSIM for 483_img_.png: 0.8666
# ./results\484_img_.png
# ./Dataset/reference-890\484_img_.png
# SSIM for 484_img_.png: 0.8895
# ./results\485_img_.png
# ./Dataset/reference-890\485_img_.png
# SSIM for 485_img_.png: 0.8924
# ./results\486_img_.png
# ./Dataset/reference-890\486_img_.png
# SSIM for 486_img_.png: 0.7956
# ./results\487_img_.png
# ./Dataset/reference-890\487_img_.png
# SSIM for 487_img_.png: 0.6629
# ./results\488_img_.png
# ./Dataset/reference-890\488_img_.png
# SSIM for 488_img_.png: 0.8338
# ./results\489_img_.png
# ./Dataset/reference-890\489_img_.png
# SSIM for 489_img_.png: 0.9025
# ./results\48_img_.png
# ./Dataset/reference-890\48_img_.png
# SSIM for 48_img_.png: 0.9189
# ./results\490_img_.png
# ./Dataset/reference-890\490_img_.png
# SSIM for 490_img_.png: 0.6546
# ./results\491_img_.png
# ./Dataset/reference-890\491_img_.png
# SSIM for 491_img_.png: 0.8106
# ./results\492_img_.png
# ./Dataset/reference-890\492_img_.png
# SSIM for 492_img_.png: 0.9025
# ./results\493_img_.png
# ./Dataset/reference-890\493_img_.png
# SSIM for 493_img_.png: 0.8813
# ./results\494_img_.png
# ./Dataset/reference-890\494_img_.png
# SSIM for 494_img_.png: 0.8492
# ./results\495_img_.png
# ./Dataset/reference-890\495_img_.png
# SSIM for 495_img_.png: 0.9123
# ./results\496_img_.png
# ./Dataset/reference-890\496_img_.png
# SSIM for 496_img_.png: 0.6845
# ./results\497_img_.png
# ./Dataset/reference-890\497_img_.png
# SSIM for 497_img_.png: 0.8083
# ./results\498_img_.png
# ./Dataset/reference-890\498_img_.png
# SSIM for 498_img_.png: 0.7391
# ./results\499_img_.png
# ./Dataset/reference-890\499_img_.png
# SSIM for 499_img_.png: 0.7439
# ./results\49_img_.png
# ./Dataset/reference-890\49_img_.png
# SSIM for 49_img_.png: 0.7784
# ./results\4_img_.png
# ./Dataset/reference-890\4_img_.png
# SSIM for 4_img_.png: 0.8939
# ./results\501_img_.png
# ./Dataset/reference-890\501_img_.png
# SSIM for 501_img_.png: 0.8240
# ./results\502_img_.png
# ./Dataset/reference-890\502_img_.png
# SSIM for 502_img_.png: 0.9046
# ./results\503_img_.png
# ./Dataset/reference-890\503_img_.png
# SSIM for 503_img_.png: 0.8517
# ./results\504_img_.png
# ./Dataset/reference-890\504_img_.png
# SSIM for 504_img_.png: 0.8273
# ./results\505_img_.png
# ./Dataset/reference-890\505_img_.png
# SSIM for 505_img_.png: 0.8760
# ./results\506_img_.png
# ./Dataset/reference-890\506_img_.png
# SSIM for 506_img_.png: 0.7578
# ./results\507_img_.png
# ./Dataset/reference-890\507_img_.png
# SSIM for 507_img_.png: 0.9618
# ./results\508_img_.png
# ./Dataset/reference-890\508_img_.png
# SSIM for 508_img_.png: 0.8486
# ./results\509_img_.png
# ./Dataset/reference-890\509_img_.png
# SSIM for 509_img_.png: 0.8950
# ./results\50_img_.png
# ./Dataset/reference-890\50_img_.png
# SSIM for 50_img_.png: 0.8211
# ./results\510_img_.png
# ./Dataset/reference-890\510_img_.png
# SSIM for 510_img_.png: 0.7513
# ./results\511_img_.png
# ./Dataset/reference-890\511_img_.png
# SSIM for 511_img_.png: 0.8992
# ./results\512_img_.png
# ./Dataset/reference-890\512_img_.png
# SSIM for 512_img_.png: 0.9120
# ./results\513_img_.png
# ./Dataset/reference-890\513_img_.png
# SSIM for 513_img_.png: 0.8407
# ./results\515_img_.png
# ./Dataset/reference-890\515_img_.png
# SSIM for 515_img_.png: 0.7895
# ./results\516_img_.png
# ./Dataset/reference-890\516_img_.png
# SSIM for 516_img_.png: 0.8485
# ./results\517_img_.png
# ./Dataset/reference-890\517_img_.png
# SSIM for 517_img_.png: 0.8319
# ./results\518_img_.png
# ./Dataset/reference-890\518_img_.png
# SSIM for 518_img_.png: 0.6898
# ./results\519_img_.png
# ./Dataset/reference-890\519_img_.png
# SSIM for 519_img_.png: 0.7027
# ./results\51_img_.png
# ./Dataset/reference-890\51_img_.png
# SSIM for 51_img_.png: 0.8409
# ./results\524_img_.png
# ./Dataset/reference-890\524_img_.png
# SSIM for 524_img_.png: 0.6906
# ./results\526_img_.png
# ./Dataset/reference-890\526_img_.png
# SSIM for 526_img_.png: 0.6690
# ./results\527_img_.png
# ./Dataset/reference-890\527_img_.png
# SSIM for 527_img_.png: 0.8906
# ./results\528_img_.png
# ./Dataset/reference-890\528_img_.png
# SSIM for 528_img_.png: 0.6632
# ./results\52_img_.png
# ./Dataset/reference-890\52_img_.png
# SSIM for 52_img_.png: 0.8280
# ./results\530_img_.png
# ./Dataset/reference-890\530_img_.png
# SSIM for 530_img_.png: 0.8950
# ./results\531_img_.png
# ./Dataset/reference-890\531_img_.png
# SSIM for 531_img_.png: 0.9632
# ./results\532_img_.png
# ./Dataset/reference-890\532_img_.png
# SSIM for 532_img_.png: 0.6511
# ./results\533_img_.png
# ./Dataset/reference-890\533_img_.png
# SSIM for 533_img_.png: 0.7261
# ./results\534_img_.png
# ./Dataset/reference-890\534_img_.png
# SSIM for 534_img_.png: 0.6795
# ./results\535_img_.png
# ./Dataset/reference-890\535_img_.png
# SSIM for 535_img_.png: 0.5851
# ./results\536_img_.png
# ./Dataset/reference-890\536_img_.png
# SSIM for 536_img_.png: 0.8903
# ./results\537_img_.png
# ./Dataset/reference-890\537_img_.png
# SSIM for 537_img_.png: 0.8579
# ./results\538_img_.png
# ./Dataset/reference-890\538_img_.png
# SSIM for 538_img_.png: 0.8264
# ./results\539.png
# ./Dataset/reference-890\539.png
# SSIM for 539.png: 0.8043
# ./results\539_img_.png
# ./Dataset/reference-890\539_img_.png
# SSIM for 539_img_.png: 0.7876
# ./results\53_img_.png
# ./Dataset/reference-890\53_img_.png
# SSIM for 53_img_.png: 0.5624
# ./results\540_img_.png
# ./Dataset/reference-890\540_img_.png
# SSIM for 540_img_.png: 0.8928
# ./results\541_img_.png
# ./Dataset/reference-890\541_img_.png
# SSIM for 541_img_.png: 0.7953
# ./results\542_img_.png
# ./Dataset/reference-890\542_img_.png
# SSIM for 542_img_.png: 0.6710
# ./results\543_img_.png
# ./Dataset/reference-890\543_img_.png
# SSIM for 543_img_.png: 0.7058
# ./results\544_img_.png
# ./Dataset/reference-890\544_img_.png
# SSIM for 544_img_.png: 0.5940
# ./results\545_img_.png
# ./Dataset/reference-890\545_img_.png
# SSIM for 545_img_.png: 0.5513
# ./results\546_img_.png
# ./Dataset/reference-890\546_img_.png
# SSIM for 546_img_.png: 0.6278
# ./results\547_img_.png
# ./Dataset/reference-890\547_img_.png
# SSIM for 547_img_.png: 0.8594
# ./results\549_img_.png
# ./Dataset/reference-890\549_img_.png
# SSIM for 549_img_.png: 0.7497
# ./results\550_img_.png
# ./Dataset/reference-890\550_img_.png
# SSIM for 550_img_.png: 0.8404
# ./results\551_img_.png
# ./Dataset/reference-890\551_img_.png
# SSIM for 551_img_.png: 0.7908
# ./results\552_img_.png
# ./Dataset/reference-890\552_img_.png
# SSIM for 552_img_.png: 0.7800
# ./results\554_img_.png
# ./Dataset/reference-890\554_img_.png
# SSIM for 554_img_.png: 0.8661
# ./results\5554.png
# ./Dataset/reference-890\5554.png
# SSIM for 5554.png: 0.9521
# ./results\555_img_.png
# ./Dataset/reference-890\555_img_.png
# SSIM for 555_img_.png: 0.5411
# ./results\556_img_.png
# ./Dataset/reference-890\556_img_.png
# SSIM for 556_img_.png: 0.6182
# ./results\557.png
# ./Dataset/reference-890\557.png
# SSIM for 557.png: 0.9411
# ./results\557_img_.png
# ./Dataset/reference-890\557_img_.png
# SSIM for 557_img_.png: 0.6520
# ./results\558_img_.png
# ./Dataset/reference-890\558_img_.png
# SSIM for 558_img_.png: 0.7469
# ./results\559.png
# ./Dataset/reference-890\559.png
# SSIM for 559.png: 0.8653
# ./results\55_img_.png
# ./Dataset/reference-890\55_img_.png
# SSIM for 55_img_.png: 0.9212
# ./results\560_img_.png
# ./Dataset/reference-890\560_img_.png
# SSIM for 560_img_.png: 0.7798
# ./results\561_img_.png
# ./Dataset/reference-890\561_img_.png
# SSIM for 561_img_.png: 0.8567
# ./results\562_img_.png
# ./Dataset/reference-890\562_img_.png
# SSIM for 562_img_.png: 0.6816
# ./results\563.png
# ./Dataset/reference-890\563.png
# SSIM for 563.png: 0.9529
# ./results\563_img_.png
# ./Dataset/reference-890\563_img_.png
# SSIM for 563_img_.png: 0.6211
# ./results\564_img_.png
# ./Dataset/reference-890\564_img_.png
# SSIM for 564_img_.png: 0.6607
# ./results\566_img_.png
# ./Dataset/reference-890\566_img_.png
# SSIM for 566_img_.png: 0.9330
# ./results\567.png
# ./Dataset/reference-890\567.png
# SSIM for 567.png: 0.9377
# ./results\567_img_.png
# ./Dataset/reference-890\567_img_.png
# SSIM for 567_img_.png: 0.7395
# ./results\568_img_.png
# ./Dataset/reference-890\568_img_.png
# SSIM for 568_img_.png: 0.6196
# ./results\569_img_.png
# ./Dataset/reference-890\569_img_.png
# SSIM for 569_img_.png: 0.6545
# ./results\56_img_.png
# ./Dataset/reference-890\56_img_.png
# SSIM for 56_img_.png: 0.8443
# ./results\570_img_.png
# ./Dataset/reference-890\570_img_.png
# SSIM for 570_img_.png: 0.8116
# ./results\571_img_.png
# ./Dataset/reference-890\571_img_.png
# SSIM for 571_img_.png: 0.9147
# ./results\572_img_.png
# ./Dataset/reference-890\572_img_.png
# SSIM for 572_img_.png: 0.9458
# ./results\573_img_.png
# ./Dataset/reference-890\573_img_.png
# SSIM for 573_img_.png: 0.7450
# ./results\574_img_.png
# ./Dataset/reference-890\574_img_.png
# SSIM for 574_img_.png: 0.7264
# ./results\575_img_.png
# ./Dataset/reference-890\575_img_.png
# SSIM for 575_img_.png: 0.7431
# ./results\576_img_.png
# ./Dataset/reference-890\576_img_.png
# SSIM for 576_img_.png: 0.8797
# ./results\577_img_.png
# ./Dataset/reference-890\577_img_.png
# SSIM for 577_img_.png: 0.5922
# ./results\578_img_.png
# ./Dataset/reference-890\578_img_.png
# SSIM for 578_img_.png: 0.9402
# ./results\579_img_.png
# ./Dataset/reference-890\579_img_.png
# SSIM for 579_img_.png: 0.7575
# ./results\57_img_.png
# ./Dataset/reference-890\57_img_.png
# SSIM for 57_img_.png: 0.8684
# ./results\580_img_.png
# ./Dataset/reference-890\580_img_.png
# SSIM for 580_img_.png: 0.5778
# ./results\5818.png
# ./Dataset/reference-890\5818.png
# SSIM for 5818.png: 0.9555
# ./results\581_img_.png
# ./Dataset/reference-890\581_img_.png
# SSIM for 581_img_.png: 0.8200
# ./results\582_img_.png
# ./Dataset/reference-890\582_img_.png
# SSIM for 582_img_.png: 0.7784
# ./results\5830.png
# ./Dataset/reference-890\5830.png
# SSIM for 5830.png: 0.9660
# ./results\583_img_.png
# ./Dataset/reference-890\583_img_.png
# SSIM for 583_img_.png: 0.9705
# ./results\584_img_.png
# ./Dataset/reference-890\584_img_.png
# SSIM for 584_img_.png: 0.8340
# ./results\585_img_.png
# ./Dataset/reference-890\585_img_.png
# SSIM for 585_img_.png: 0.9224
# ./results\586_img_.png
# ./Dataset/reference-890\586_img_.png
# SSIM for 586_img_.png: 0.8981
# ./results\587_img_.png
# ./Dataset/reference-890\587_img_.png
# SSIM for 587_img_.png: 0.8881
# ./results\588_img_.png
# ./Dataset/reference-890\588_img_.png
# SSIM for 588_img_.png: 0.8615
# ./results\589_img_.png
# ./Dataset/reference-890\589_img_.png
# SSIM for 589_img_.png: 0.7619
# ./results\58_img_.png
# ./Dataset/reference-890\58_img_.png
# SSIM for 58_img_.png: 0.8278
# ./results\590_img_.png
# ./Dataset/reference-890\590_img_.png
# SSIM for 590_img_.png: 0.8109
# ./results\591_img_.png
# ./Dataset/reference-890\591_img_.png
# SSIM for 591_img_.png: 0.8107
# ./results\592_img_.png
# ./Dataset/reference-890\592_img_.png
# SSIM for 592_img_.png: 0.9549
# ./results\593_img_.png
# ./Dataset/reference-890\593_img_.png
# SSIM for 593_img_.png: 0.8078
# ./results\594_img_.png
# ./Dataset/reference-890\594_img_.png
# SSIM for 594_img_.png: 0.8767
# ./results\595_img_.png
# ./Dataset/reference-890\595_img_.png
# SSIM for 595_img_.png: 0.8066
# ./results\596_img_.png
# ./Dataset/reference-890\596_img_.png
# SSIM for 596_img_.png: 0.8211
# ./results\597_img_.png
# ./Dataset/reference-890\597_img_.png
# SSIM for 597_img_.png: 0.9164
# ./results\598.png
# ./Dataset/reference-890\598.png
# SSIM for 598.png: 0.8868
# ./results\598_img_.png
# ./Dataset/reference-890\598_img_.png
# SSIM for 598_img_.png: 0.7265
# ./results\599_img_.png
# ./Dataset/reference-890\599_img_.png
# SSIM for 599_img_.png: 0.8407
# ./results\59_img_.png
# ./Dataset/reference-890\59_img_.png
# SSIM for 59_img_.png: 0.7875
# ./results\600_img_.png
# ./Dataset/reference-890\600_img_.png
# SSIM for 600_img_.png: 0.8928
# ./results\601_img_.png
# ./Dataset/reference-890\601_img_.png
# SSIM for 601_img_.png: 0.8461
# ./results\602_img_.png
# ./Dataset/reference-890\602_img_.png
# SSIM for 602_img_.png: 0.8883
# ./results\603_img_.png
# ./Dataset/reference-890\603_img_.png
# SSIM for 603_img_.png: 0.8990
# ...
# ./Dataset/reference-890\763_img_.png
# SSIM for 763_img_.png: 0.8725
# ./results\7643.png
# ./Dataset/reference-890\7643.png
# SSIM for 7643.png: 0.7035
# ./results\764_img_.png
# ./Dataset/reference-890\764_img_.png
# SSIM for 764_img_.png: 0.8170
# ./results\7654.png
# ./Dataset/reference-890\7654.png
# SSIM for 7654.png: 0.6976
# ./results\765_img_.png
# ./Dataset/reference-890\765_img_.png
# SSIM for 765_img_.png: 0.8861
# ./results\766_img_.png
# ./Dataset/reference-890\766_img_.png
# SSIM for 766_img_.png: 0.8577
# ./results\767_img_.png
# ./Dataset/reference-890\767_img_.png
# SSIM for 767_img_.png: 0.8084
# ./results\768_img_.png
# ./Dataset/reference-890\768_img_.png
# SSIM for 768_img_.png: 0.8054
# ./results\769_img_.png
# ./Dataset/reference-890\769_img_.png
# SSIM for 769_img_.png: 0.7322
# ./results\76_img_.png
# ./Dataset/reference-890\76_img_.png
# SSIM for 76_img_.png: 0.7696
# ./results\770_img_.png
# ./Dataset/reference-890\770_img_.png
# SSIM for 770_img_.png: 0.9086
# ./results\771_img_.png
# ./Dataset/reference-890\771_img_.png
# SSIM for 771_img_.png: 0.8459
# ./results\772_img_.png
# ./Dataset/reference-890\772_img_.png
# SSIM for 772_img_.png: 0.9019
# ./results\773_img_.png
# ./Dataset/reference-890\773_img_.png
# SSIM for 773_img_.png: 0.8471
# ./results\775_img_.png
# ./Dataset/reference-890\775_img_.png
# SSIM for 775_img_.png: 0.9764
# ./results\776_img_.png
# ./Dataset/reference-890\776_img_.png
# SSIM for 776_img_.png: 0.8722
# ./results\777_img_.png
# ./Dataset/reference-890\777_img_.png
# SSIM for 777_img_.png: 0.9039
# ./results\778_img_.png
# ./Dataset/reference-890\778_img_.png
# SSIM for 778_img_.png: 0.9176
# ./results\779_img_.png
# ./Dataset/reference-890\779_img_.png
# SSIM for 779_img_.png: 0.8748
# ./results\77_img_.png
# ./Dataset/reference-890\77_img_.png
# SSIM for 77_img_.png: 0.6852
# ./results\780_img_.png
# ./Dataset/reference-890\780_img_.png
# SSIM for 780_img_.png: 0.8554
# ./results\781_img_.png
# ./Dataset/reference-890\781_img_.png
# SSIM for 781_img_.png: 0.9152
# ./results\782_img_.png
# ./Dataset/reference-890\782_img_.png
# SSIM for 782_img_.png: 0.9703
# ./results\783_img_.png
# ./Dataset/reference-890\783_img_.png
# SSIM for 783_img_.png: 0.8494
# ./results\784_img_.png
# ./Dataset/reference-890\784_img_.png
# SSIM for 784_img_.png: 0.9028
# ./results\785_img_.png
# ./Dataset/reference-890\785_img_.png
# SSIM for 785_img_.png: 0.8431
# ./results\786_img_.png
# ./Dataset/reference-890\786_img_.png
# SSIM for 786_img_.png: 0.6490
# ./results\787_img_.png
# ./Dataset/reference-890\787_img_.png
# SSIM for 787_img_.png: 0.8846
# ./results\788_img_.png
# ./Dataset/reference-890\788_img_.png
# SSIM for 788_img_.png: 0.9555
# ./results\789_img_.png
# ./Dataset/reference-890\789_img_.png
# SSIM for 789_img_.png: 0.8456
# ./results\78_img_.png
# ./Dataset/reference-890\78_img_.png
# SSIM for 78_img_.png: 0.6789
# ./results\790_img_.png
# ./Dataset/reference-890\790_img_.png
# SSIM for 790_img_.png: 0.8284
# ./results\7916.png
# ./Dataset/reference-890\7916.png
# SSIM for 7916.png: 0.6324
# ./results\791_img_.png
# ./Dataset/reference-890\791_img_.png
# SSIM for 791_img_.png: 0.9195
# ./results\792_img_.png
# ./Dataset/reference-890\792_img_.png
# SSIM for 792_img_.png: 0.9421
# ./results\793_img_.png
# ./Dataset/reference-890\793_img_.png
# SSIM for 793_img_.png: 0.8002
# ./results\794_img_.png
# ./Dataset/reference-890\794_img_.png
# SSIM for 794_img_.png: 0.9621
# ./results\795_img_.png
# ./Dataset/reference-890\795_img_.png
# SSIM for 795_img_.png: 0.8795
# ./results\796_img_.png
# ./Dataset/reference-890\796_img_.png
# SSIM for 796_img_.png: 0.8100
# ./results\797_img_.png
# ./Dataset/reference-890\797_img_.png
# SSIM for 797_img_.png: 0.9614
# ./results\798_img_.png
# ./Dataset/reference-890\798_img_.png
# SSIM for 798_img_.png: 0.7844
# ./results\799_img_.png
# ./Dataset/reference-890\799_img_.png
# SSIM for 799_img_.png: 0.9409
# ./results\79_img_.png
# ./Dataset/reference-890\79_img_.png
# SSIM for 79_img_.png: 0.8870
# ./results\7_img_.png
# ./Dataset/reference-890\7_img_.png
# SSIM for 7_img_.png: 0.6848
# ./results\800_img_.png
# ./Dataset/reference-890\800_img_.png
# SSIM for 800_img_.png: 0.9614
# ./results\8010.png
# ./Dataset/reference-890\8010.png
# SSIM for 8010.png: 0.6482
# ./results\802_img_.png
# ./Dataset/reference-890\802_img_.png
# SSIM for 802_img_.png: 0.9342
# ./results\803_img_.png
# ./Dataset/reference-890\803_img_.png
# SSIM for 803_img_.png: 0.8539
# ./results\8046.png
# ./Dataset/reference-890\8046.png
# SSIM for 8046.png: 0.6813
# ./results\804_img_.png
# ./Dataset/reference-890\804_img_.png
# SSIM for 804_img_.png: 0.9605
# ./results\8056.png
# ./Dataset/reference-890\8056.png
# SSIM for 8056.png: 0.6798
# ./results\806_img_.png
# ./Dataset/reference-890\806_img_.png
# SSIM for 806_img_.png: 0.9240
# ./results\807_img_.png
# ./Dataset/reference-890\807_img_.png
# SSIM for 807_img_.png: 0.8813
# ./results\808_img_.png
# ./Dataset/reference-890\808_img_.png
# SSIM for 808_img_.png: 0.7908
# ./results\809_img_.png
# ./Dataset/reference-890\809_img_.png
# SSIM for 809_img_.png: 0.9675
# ./results\80_img_.png
# ./Dataset/reference-890\80_img_.png
# SSIM for 80_img_.png: 0.9146
# ./results\810_img_.png
# ./Dataset/reference-890\810_img_.png
# SSIM for 810_img_.png: 0.8182
# ./results\811_img_.png
# ./Dataset/reference-890\811_img_.png
# SSIM for 811_img_.png: 0.8504
# ./results\812_img_.png
# ./Dataset/reference-890\812_img_.png
# SSIM for 812_img_.png: 0.8234
# ./results\813_img_.png
# ./Dataset/reference-890\813_img_.png
# SSIM for 813_img_.png: 0.7269
# ./results\814_img_.png
# ./Dataset/reference-890\814_img_.png
# SSIM for 814_img_.png: 0.8822
# ./results\815_img_.png
# ./Dataset/reference-890\815_img_.png
# SSIM for 815_img_.png: 0.9470
# ./results\816_img_.png
# ./Dataset/reference-890\816_img_.png
# SSIM for 816_img_.png: 0.9109
# ./results\817_img_.png
# ./Dataset/reference-890\817_img_.png
# SSIM for 817_img_.png: 0.8397
# ./results\818_img_.png
# ./Dataset/reference-890\818_img_.png
# SSIM for 818_img_.png: 0.9626
# ./results\819_img_.png
# ./Dataset/reference-890\819_img_.png
# SSIM for 819_img_.png: 0.7267
# ./results\820_img_.png
# ./Dataset/reference-890\820_img_.png
# SSIM for 820_img_.png: 0.9076
# ./results\821_img_.png
# ./Dataset/reference-890\821_img_.png
# SSIM for 821_img_.png: 0.8862
# ./results\822_img_.png
# ./Dataset/reference-890\822_img_.png
# SSIM for 822_img_.png: 0.5998
# ./results\823_img_.png
# ./Dataset/reference-890\823_img_.png
# SSIM for 823_img_.png: 0.9182
# ./results\8262.png
# ./Dataset/reference-890\8262.png
# SSIM for 8262.png: 0.6536
# ./results\827_img_.png
# ./Dataset/reference-890\827_img_.png
# SSIM for 827_img_.png: 0.9709
# ./results\8288.png
# ./Dataset/reference-890\8288.png
# SSIM for 8288.png: 0.6981
# ./results\828_img_.png
# ./Dataset/reference-890\828_img_.png
# SSIM for 828_img_.png: 0.9810
# ./results\829_img_.png
# ./Dataset/reference-890\829_img_.png
# SSIM for 829_img_.png: 0.9507
# ./results\82_img_.png
# ./Dataset/reference-890\82_img_.png
# SSIM for 82_img_.png: 0.9547
# ./results\831_img_.png
# ./Dataset/reference-890\831_img_.png
# SSIM for 831_img_.png: 0.9583
# ./results\832_img_.png
# ./Dataset/reference-890\832_img_.png
# SSIM for 832_img_.png: 0.9437
# ./results\833_img_.png
# ./Dataset/reference-890\833_img_.png
# SSIM for 833_img_.png: 0.8668
# ./results\834_img_.png
# ./Dataset/reference-890\834_img_.png
# SSIM for 834_img_.png: 0.8116
# ./results\835_img_.png
# ./Dataset/reference-890\835_img_.png
# SSIM for 835_img_.png: 0.9680
# ./results\837.png
# ./Dataset/reference-890\837.png
# SSIM for 837.png: 0.7981
# ./results\837_img_.png
# ./Dataset/reference-890\837_img_.png
# SSIM for 837_img_.png: 0.9121
# ./results\838_img_.png
# ./Dataset/reference-890\838_img_.png
# SSIM for 838_img_.png: 0.8797
# ./results\841.png
# ./Dataset/reference-890\841.png
# SSIM for 841.png: 0.7682
# ./results\841_img_.png
# ./Dataset/reference-890\841_img_.png
# SSIM for 841_img_.png: 0.8138
# ./results\842_img_.png
# ./Dataset/reference-890\842_img_.png
# SSIM for 842_img_.png: 0.8462
# ./results\843_img_.png
# ./Dataset/reference-890\843_img_.png
# SSIM for 843_img_.png: 0.9378
# ./results\844_img_.png
# ./Dataset/reference-890\844_img_.png
# SSIM for 844_img_.png: 0.8178
# ./results\845_img_.png
# ./Dataset/reference-890\845_img_.png
# SSIM for 845_img_.png: 0.8948
# ./results\846_img_.png
# ./Dataset/reference-890\846_img_.png
# SSIM for 846_img_.png: 0.8903
# ./results\847_img_.png
# ./Dataset/reference-890\847_img_.png
# SSIM for 847_img_.png: 0.7084
# ./results\848_img_.png
# ./Dataset/reference-890\848_img_.png
# SSIM for 848_img_.png: 0.9102
# ./results\849_img_.png
# ./Dataset/reference-890\849_img_.png
# SSIM for 849_img_.png: 0.8638
# ./results\850_img_.png
# ./Dataset/reference-890\850_img_.png
# SSIM for 850_img_.png: 0.5852
# ./results\851_img_.png
# ./Dataset/reference-890\851_img_.png
# SSIM for 851_img_.png: 0.8931
# ./results\852_img_.png
# ./Dataset/reference-890\852_img_.png
# SSIM for 852_img_.png: 0.6526
# ./results\854_img_.png
# ./Dataset/reference-890\854_img_.png
# SSIM for 854_img_.png: 0.7632
# ./results\855_img_.png
# ./Dataset/reference-890\855_img_.png
# SSIM for 855_img_.png: 0.8946
# ./results\856_img_.png
# ./Dataset/reference-890\856_img_.png
# SSIM for 856_img_.png: 0.8314
# ./results\857_img_.png
# ./Dataset/reference-890\857_img_.png
# SSIM for 857_img_.png: 0.7945
# ./results\858_img_.png
# ./Dataset/reference-890\858_img_.png
# SSIM for 858_img_.png: 0.9611
# ./results\859_img_.png
# ./Dataset/reference-890\859_img_.png
# SSIM for 859_img_.png: 0.7362
# ./results\860_img_.png
# ./Dataset/reference-890\860_img_.png
# SSIM for 860_img_.png: 0.7510
# ./results\861_img_.png
# ./Dataset/reference-890\861_img_.png
# SSIM for 861_img_.png: 0.6345
# ./results\862_img_.png
# ./Dataset/reference-890\862_img_.png
# SSIM for 862_img_.png: 0.6786
# ./results\863_img_.png
# ./Dataset/reference-890\863_img_.png
# SSIM for 863_img_.png: 0.9709
# ./results\865_img_.png
# ./Dataset/reference-890\865_img_.png
# SSIM for 865_img_.png: 0.6606
# ./results\866_img_.png
# ./Dataset/reference-890\866_img_.png
# SSIM for 866_img_.png: 0.8778
# ./results\867_img_.png
# ./Dataset/reference-890\867_img_.png
# SSIM for 867_img_.png: 0.7473
# ./results\868_img_.png
# ./Dataset/reference-890\868_img_.png
# SSIM for 868_img_.png: 0.7410
# ./results\869_img_.png
# ./Dataset/reference-890\869_img_.png
# SSIM for 869_img_.png: 0.8123
# ./results\86_img_.png
# ./Dataset/reference-890\86_img_.png
# SSIM for 86_img_.png: 0.8241
# ./results\871_img_.png
# ./Dataset/reference-890\871_img_.png
# SSIM for 871_img_.png: 0.7043
# ./results\872_img_.png
# ./Dataset/reference-890\872_img_.png
# SSIM for 872_img_.png: 0.6245
# ./results\873_img_.png
# ./Dataset/reference-890\873_img_.png
# SSIM for 873_img_.png: 0.8792
# ./results\874_img_.png
# ./Dataset/reference-890\874_img_.png
# SSIM for 874_img_.png: 0.7086
# ./results\875_img_.png
# ./Dataset/reference-890\875_img_.png
# SSIM for 875_img_.png: 0.9851
# ./results\876_img_.png
# ./Dataset/reference-890\876_img_.png
# SSIM for 876_img_.png: 0.9772
# ./results\877_img_.png
# ./Dataset/reference-890\877_img_.png
# SSIM for 877_img_.png: 0.7460
# ./results\878_img_.png
# ./Dataset/reference-890\878_img_.png
# SSIM for 878_img_.png: 0.6860
# ./results\879_img_.png
# ./Dataset/reference-890\879_img_.png
# SSIM for 879_img_.png: 0.7543
# ./results\87_img_.png
# ./Dataset/reference-890\87_img_.png
# SSIM for 87_img_.png: 0.9104
# ./results\880_img_.png
# ./Dataset/reference-890\880_img_.png
# SSIM for 880_img_.png: 0.7710
# ./results\881_img_.png
# ./Dataset/reference-890\881_img_.png
# SSIM for 881_img_.png: 0.7467
# ./results\887_img_.png
# ./Dataset/reference-890\887_img_.png
# SSIM for 887_img_.png: 0.7799
# ./results\889_img_.png
# ./Dataset/reference-890\889_img_.png
# SSIM for 889_img_.png: 0.9557
# ./results\890.png
# ./Dataset/reference-890\890.png
# SSIM for 890.png: 0.8838
# ./results\890_img_.png
# ./Dataset/reference-890\890_img_.png
# SSIM for 890_img_.png: 0.9538
# ./results\891_img_.png
# ./Dataset/reference-890\891_img_.png
# SSIM for 891_img_.png: 0.8565
# ./results\892_img_.png
# ./Dataset/reference-890\892_img_.png
# SSIM for 892_img_.png: 0.8775
# ./results\893_img_.png
# ./Dataset/reference-890\893_img_.png
# SSIM for 893_img_.png: 0.6769
# ./results\895_img_.png
# ./Dataset/reference-890\895_img_.png
# SSIM for 895_img_.png: 0.6276
# ./results\896_img_.png
# ./Dataset/reference-890\896_img_.png
# SSIM for 896_img_.png: 0.8537
# ./results\89_img_.png
# ./Dataset/reference-890\89_img_.png
# SSIM for 89_img_.png: 0.8849
# ./results\8_img_.png
# ./Dataset/reference-890\8_img_.png
# SSIM for 8_img_.png: 0.8228
# ./results\901_img_.png
# ./Dataset/reference-890\901_img_.png
# SSIM for 901_img_.png: 0.8305
# ./results\904_img_.png
# ./Dataset/reference-890\904_img_.png
# SSIM for 904_img_.png: 0.7071
# ./results\905_img_.png
# ./Dataset/reference-890\905_img_.png
# SSIM for 905_img_.png: 0.7596
# ./results\906_img_.png
# ./Dataset/reference-890\906_img_.png
# SSIM for 906_img_.png: 0.6947
# ./results\907_img_.png
# ./Dataset/reference-890\907_img_.png
# SSIM for 907_img_.png: 0.8687
# ./results\908_img_.png
# ./Dataset/reference-890\908_img_.png
# SSIM for 908_img_.png: 0.8817
# ./results\909_img_.png
# ./Dataset/reference-890\909_img_.png
# SSIM for 909_img_.png: 0.6640
# ./results\90_img_.png
# ./Dataset/reference-890\90_img_.png
# SSIM for 90_img_.png: 0.9086
# ./results\910_img_.png
# ./Dataset/reference-890\910_img_.png
# SSIM for 910_img_.png: 0.4531
# ./results\911_img_.png
# ./Dataset/reference-890\911_img_.png
# SSIM for 911_img_.png: 0.8111
# ./results\912_img_.png
# ./Dataset/reference-890\912_img_.png
# SSIM for 912_img_.png: 0.8260
# ./results\913_img_.png
# ./Dataset/reference-890\913_img_.png
# SSIM for 913_img_.png: 0.6493
# ./results\914_img_.png
# ./Dataset/reference-890\914_img_.png
# SSIM for 914_img_.png: 0.6376
# ./results\915_img_.png
# ./Dataset/reference-890\915_img_.png
# SSIM for 915_img_.png: 0.7896
# ./results\916_img_.png
# ./Dataset/reference-890\916_img_.png
# SSIM for 916_img_.png: 0.9496
# ./results\917_img_.png
# ./Dataset/reference-890\917_img_.png
# SSIM for 917_img_.png: 0.8524
# ./results\918_img_.png
# ./Dataset/reference-890\918_img_.png
# SSIM for 918_img_.png: 0.8652
# ./results\919_img_.png
# ./Dataset/reference-890\919_img_.png
# SSIM for 919_img_.png: 0.8178
# ./results\91_img_.png
# ./Dataset/reference-890\91_img_.png
# SSIM for 91_img_.png: 0.4684
# ./results\920_img_.png
# ./Dataset/reference-890\920_img_.png
# SSIM for 920_img_.png: 0.8636
# ./results\921_img_.png
# ./Dataset/reference-890\921_img_.png
# SSIM for 921_img_.png: 0.8273
# ./results\922_img_.png
# ./Dataset/reference-890\922_img_.png
# SSIM for 922_img_.png: 0.8955
# ./results\923_img_.png
# ./Dataset/reference-890\923_img_.png
# SSIM for 923_img_.png: 0.7371
# ./results\924_img_.png
# ./Dataset/reference-890\924_img_.png
# SSIM for 924_img_.png: 0.6579
# ./results\925_img_.png
# ./Dataset/reference-890\925_img_.png
# SSIM for 925_img_.png: 0.9337
# ./results\926_img_.png
# ./Dataset/reference-890\926_img_.png
# SSIM for 926_img_.png: 0.7560
# ./results\927_img_.png
# ./Dataset/reference-890\927_img_.png
# SSIM for 927_img_.png: 0.6755
# ./results\928_img_.png
# ./Dataset/reference-890\928_img_.png
# SSIM for 928_img_.png: 0.7824
# ./results\929_img_.png
# ./Dataset/reference-890\929_img_.png
# SSIM for 929_img_.png: 0.8241
# ./results\92_img_.png
# ./Dataset/reference-890\92_img_.png
# SSIM for 92_img_.png: 0.9253
# ./results\94_img_.png
# ./Dataset/reference-890\94_img_.png
# SSIM for 94_img_.png: 0.8036
# ./results\9547.png
# ./Dataset/reference-890\9547.png
# SSIM for 9547.png: 0.9410
# ./results\9554.png
# ./Dataset/reference-890\9554.png
# SSIM for 9554.png: 0.8719
# ./results\9557.png
# ./Dataset/reference-890\9557.png
# SSIM for 9557.png: 0.8612
# ./results\9567.png
# ./Dataset/reference-890\9567.png
# SSIM for 9567.png: 0.9056
# ./results\95_img_.png
# ./Dataset/reference-890\95_img_.png
# SSIM for 95_img_.png: 0.8964
# ./results\96_img_.png
# ./Dataset/reference-890\96_img_.png
# SSIM for 96_img_.png: 0.9379
# ./results\97_img_.png
# ./Dataset/reference-890\97_img_.png
# SSIM for 97_img_.png: 0.8434
# ./results\9896.png
# ./Dataset/reference-890\9896.png
# SSIM for 9896.png: 0.7750
# ./results\98_img_.png
# ./Dataset/reference-890\98_img_.png
# SSIM for 98_img_.png: 0.9528
# ./results\9900.png
# ./Dataset/reference-890\9900.png
# SSIM for 9900.png: 0.8063
# ./results\9907.png
# ./Dataset/reference-890\9907.png
# SSIM for 9907.png: 0.8145
# ./results\9947.png
# ./Dataset/reference-890\9947.png
# SSIM for 9947.png: 0.7979
# ./results\99_img_.png
# ./Dataset/reference-890\99_img_.png
# SSIM for 99_img_.png: 0.9401
# ./results\9_img_.png
# ./Dataset/reference-890\9_img_.png
# SSIM for 9_img_.png: 0.6991
# Overall SSIM: 0.8229

# %%
# not needed.
# from skimage.metrics import structural_similarity as ssim


# import cv2


# img1 = cv2.imread("./OutputImages/97_img_.png")


# img2 = cv2.imread("./OutputImages/97_img_.png")


# ssim_score, mapped = ssim(img1, img2, full=True, channel_axis=2)
# print(ssim_score)
# print(mapped)
